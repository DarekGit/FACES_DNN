# %% [markdown]
# <a href="https://colab.research.google.com/github/DarekGit/Documents/blob/master/Praca_Dyplomowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praca dyplomowa

# %% [markdown]
# <html
#
# <head>
#
# <style>
# <!--
#  /* Font Definitions */
# @font-face
# 	{font-family:"ＭＳ 明朝";
# 	mso-font-charset:78;
# 	mso-generic-font-family:auto;
# 	mso-font-pitch:variable;
# 	mso-font-signature:1 134676480 16 0 131072 0;}
# @font-face
# 	{font-family:"ＭＳ 明朝";
# 	mso-font-charset:78;
# 	mso-generic-font-family:auto;
# 	mso-font-pitch:variable;
# 	mso-font-signature:1 134676480 16 0 131072 0;}
# @font-face
# 	{font-family:Cambria;
# 	panose-1:2 4 5 3 5 4 6 3 2 4;
# 	mso-font-charset:0;
# 	mso-generic-font-family:auto;
# 	mso-font-pitch:variable;
# 	mso-font-signature:-536870145 1073743103 0 0 415 0;}
#  /* Style Definitions */
# p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{mso-style-unhide:no;
# 	mso-style-qformat:yes;
# 	mso-style-parent:"";
# 	margin:0cm;
# 	margin-bottom:.0001pt;
# 	mso-pagination:widow-orphan;
# 	font-size:12.0pt;
# 	font-family:Cambria;
# 	mso-ascii-font-family:Cambria;
# 	mso-ascii-theme-font:minor-latin;
# 	mso-fareast-font-family:"ＭＳ 明朝";
# 	mso-fareast-theme-font:minor-fareast;
# 	mso-hansi-font-family:Cambria;
# 	mso-hansi-theme-font:minor-latin;
# 	mso-bidi-font-family:"Times New Roman";
# 	mso-bidi-theme-font:minor-bidi;
# 	mso-ansi-language:CS;}
# a:link, span.MsoHyperlink
# 	{mso-style-priority:99;
# 	color:blue;
# 	mso-themecolor:hyperlink;
# 	text-decoration:underline;
# 	text-underline:single;}
# a:visited, span.MsoHyperlinkFollowed
# 	{mso-style-noshow:yes;
# 	mso-style-priority:99;
# 	color:purple;
# 	mso-themecolor:followedhyperlink;
# 	text-decoration:underline;
# 	text-underline:single;}
# .MsoChpDefault
# 	{mso-style-type:export-only;
# 	mso-default-props:yes;
# 	font-family:Cambria;
# 	mso-ascii-font-family:Cambria;
# 	mso-ascii-theme-font:minor-latin;
# 	mso-fareast-font-family:"ＭＳ 明朝";
# 	mso-fareast-theme-font:minor-fareast;
# 	mso-hansi-font-family:Cambria;
# 	mso-hansi-theme-font:minor-latin;
# 	mso-bidi-font-family:"Times New Roman";
# 	mso-bidi-theme-font:minor-bidi;
# 	mso-ansi-language:CS;}
# @page WordSection1
# 	{size:595.0pt 842.0pt;
# 	margin:70.85pt 70.85pt 70.85pt 70.85pt;
# 	mso-header-margin:35.4pt;
# 	mso-footer-margin:35.4pt;
# 	mso-paper-source:0;}
# div.WordSection1
# 	{page:WordSection1;}
# -->
# </style>
# <!--[if gte mso 10]>
# <style>
#  /* Style Definitions */
# table.MsoNormalTable
# 	{mso-style-name:Standardowy;
# 	mso-tstyle-rowband-size:0;
# 	mso-tstyle-colband-size:0;
# 	mso-style-noshow:yes;
# 	mso-style-priority:99;
# 	mso-style-parent:"";
# 	mso-padding-alt:0cm 5.4pt 0cm 5.4pt;
# 	mso-para-margin:0cm;
# 	mso-para-margin-bottom:.0001pt;
# 	mso-pagination:widow-orphan;
# 	font-size:12.0pt;
# 	font-family:Cambria;
# 	mso-ascii-font-family:Cambria;
# 	mso-ascii-theme-font:minor-latin;
# 	mso-hansi-font-family:Cambria;
# 	mso-hansi-theme-font:minor-latin;
# 	mso-ansi-language:CS;}
# </style>
# <![endif]--><!--[if gte mso 9]><xml>
#  <o:shapedefaults v:ext="edit" spidmax="1026"/>
# </xml><![endif]--><!--[if gte mso 9]><xml>
#  <o:shapelayout v:ext="edit">
#   <o:idmap v:ext="edit" data="1"/>
#  </o:shapelayout></xml><![endif]-->
# </head>
#
# <body lang=PL link=blue vlink=purple style='tab-interval:35.4pt'>
#
# <div class=WordSection1>
#
# <p class=MsoNormal><span lang=CS>Praca dyplomowa została przygotowana w ramach
# studiów podyplomowych Politechniki Warszawskiej<span style="mso-spacerun:yes">
# </span>„Głębokie sieci neruonowe – zastosowania w mediach cyfrowych“.</span></p>
#
# <p class=MsoNormal><span lang=CS><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal><span lang=CS><a href="https://deeplearning.ire.pw.edu.pl">https://deeplearning.ire.pw.edu.pl</a></span></p>
#
# <p class=MsoNormal><span lang=CS><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal><span lang=CS>pod kierownictwem prof. Władysława Skarbka </span></p>
#
# <p class=MsoNormal><span lang=CS>oraz opieką mgr. inż. Grzegorza Gwardysa</span></p>
#
# <p class=MsoNormal><span lang=CS><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal><span lang=CS>Materiał został zebrany w ujęciu
# hronologicznym zgodnie z&nbsp;procesem badań.</span></p>
#
# <p class=MsoNormal><span lang=CS><o:p>&nbsp;</o:p></span></p>
#
#
#
# <p class=MsoNormal><span lang=CS><span style="mso-spacerun:yes"> </span><a
# href="https://www.pw.edu.pl/Rekrutacja/Studia-podyplomowe-i-inne/Studia-podyplomowe-posiadajace-decyzje-JM-Rektora-na-uruchomienie/Wydzial-Elektroniki-i-Technik-Informacyjnych/Glebokie-sieci-neuronowe-zastosowania-w-mediach-cyfrowych">Studia
# rekrutacje</a></span></p>
#
# </div>
#
# </body>
#
# </html>

# %% [markdown]
# ![Book Cover](https://github.com/DarekGit/Documents/blob/master/Figures/Smieszna%20detekcja.png?raw=1)
#
#
# "... czasami tak wychodzi ... "

# %% [markdown]
# ## Spis treści:
#
#
# ### [1. Wstęp - detekcja i rozpoznawanie twarzy](01.00-Wstep.ipynb)
# - [..](01.01-.ipynb)
#
# ### [2. Pierwsze przymiarki do detekcji - FDDB](02.00-FDDB.ipynb)
#
# ### [3. Poszukiwanie modelu do detekcji](03.00-modele.ipynb)
# - [mmdetection](03.01-mmdet.ipynb)
# - [mtcnn](03.02-mtcnn.ipynb)
# - [detectron2](03.01-detectron.ipynb)
#
# ### [4. Datasety](02.00-datasety.ipynb)
# - [WIDER FACE](04.01-.ipynb)
# - [FACES_DD](04.01-.ipynb)
#
# ### [5. Miary](05.00-miary.ipynb)
# - [mAP](05.01-mAP.ipynb)
#
# ### [6. Trenowanie modeli](06.00-trenowanie.ipynb)
# - [...](05.01-.ipynb)
# - [mobilenet](06.01-mobilenet.ipynb)
#
# ### [7. Eksport modeli](07.00-eksport_modeli.ipynb)
# - [ONNX/...](07.01-.ipynb)
#
# ### [8. Rozpoznawanie twarzy](08.00-rozpoznawanie.ipynb)
# - [...](08.01-.ipynb)
#
# ### [9. Podusmowanie](09.00-podsumowanie.ipynb)

# %% [markdown]
# Przykład sieci detectron2 z MobilenetV2
#
# ![Book Cover](https://github.com/DarekGit/Documents/blob/master/Figures/Det2MobilenetV2.png?raw=1)
