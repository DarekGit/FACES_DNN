# %% [markdown]
# <a href="https://colab.research.google.com/github/DarekGit/FACES_DNN/blob/master/notebooks/05_03_01_FDDB_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [Spis Treści](Praca_Dyplomowa.ipynb)

# %% [markdown]
# orównanie modeli

# %% [markdown]
# Instalacja Detectron2, pobranie datasetu i narzędzi

# %%
# install detectron2:

# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -q -e detectron2_repo

# %%
# !wget http://tamaraberg.com/faceDataset/originalPics.tar.gz
# !wget vis-www.cs.umass.edu/fddb/FDDB-folds.tgz
# !mkdir FDDB
# !tar -C FDDB -zxf originalPics.tar.gz > /dev/null
# !tar -C FDDB -zxf FDDB-folds.tgz > /dev/null

# %%
# mobilenet
# !gdown https://drive.google.com/uc?id=1U0SVkSaSio4TBiXvF1QfTZI65WYpXpZ9
# !unzip -qo mobilenet.zip
# !rm -f mobilenet.zip

# Download tools

# !gdown https://drive.google.com/uc?id=1_9ydMZlTNFXBOMl16xsU8FSBmK2PW4lN -O FDDB/tools.py
# !wget -q -O FDDB/mAP.py https://drive.google.com/uc?id=1PtEsobTFah3eiCDbSsYblOGbe2fmkjGR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1U0SVkSaSio4TBiXvF1QfTZI65WYpXpZ9
# To: /content/mobilenet.zip
# 100% 11.8k/11.8k [00:00<00:00, 4.86MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_9ydMZlTNFXBOMl16xsU8FSBmK2PW4lN
# To: /content/FDDB/tools.py
# 100% 4.47k/4.47k [00:00<00:00, 7.45MB/s]

# %% [markdown]
# <font color=yellow> Restart runtime to continue... <b>Crtl+M.</b> </font>

# %%
# !nvidia-smi
from psutil import virtual_memory
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(virtual_memory().total / 1e9))
# Out:
# Thu Jul 30 16:05:41 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.7 gigabytes of available RAM

# %%
import time
from tqdm.notebook import tqdm
import torch, torchvision
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()


import gdown
from google.colab import drive
import os
import cv2
import random
import itertools
import shutil
import glob
import json
import numpy as np
import pandas as pd
from PIL import ImageDraw, Image
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib import collections as mc

from google.colab.patches import cv2_imshow

from detectron2 import model_zoo
import detectron2.utils.comm as comm
from detectron2.engine import DefaultPredictor, DefaultTrainer, HookBase
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_train_loader
from detectron2.structures import BoxMode
from detectron2.data import build_detection_test_loader
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

from mobilenet.utils import  add_mobilenet_config, build_mobilenetv2_fpn_backbone
from FDDB.mAP import mAP, plot_mAP
from FDDB.tools import annotations,output_Files

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
IMAGES_PATH='FDDB/'

# %%
def fddb_rectangular_annotation(IMAGES_PATH=IMAGES_PATH):
  ''' zwraca listę boxy obliczone na podstawie *ellipseList.txt
      i względną ścieżkę do pliku
      
      [{'boxes': array([[184.1439,  38.1979, 355.2429, 285.3645]]),
        'path': '2002/08/11/big/img_591'}]
  '''
  fddb_annotations =  []
  ellipseList = glob.glob(IMAGES_PATH+"FDDB-folds/*ellipseList.txt")
  ellipseList.sort()

  for item in ellipseList:
    with open(item, "r") as file_:
      rows = file_.readlines()
    
    idx = 0
    while (idx < len(rows)):
      tmp = []
      image_name = rows[idx].replace("\n", "")
      number_of_faces = int(rows[idx+1])
      boxes = []

      for i in range(1, number_of_faces+1):
        box = rows[idx+1+i]
        box = [float(item) for item in box.split(' ')[0:5]]
        xmin = float(box[3]- box[1])
        ymin = float(box[4]- box[0])
        xmax = float(xmin + box[1]*2)
        ymax = float(ymin + box[0]*2)
        boxes.append([xmin, ymin, xmax, ymax])
      
      boxes=np.array(boxes)
      fddb_annotations.append({'path':image_name,'boxes':boxes})
      idx += (number_of_faces+2)

  return fddb_annotations

# %%
fddb_annotations = fddb_rectangular_annotation(IMAGES_PATH)

# %%
fddb_annotations[0]
# Out:
# {'boxes': array([[184.1439,  38.1979, 355.2429, 285.3645]]),
#  'path': '2002/08/11/big/img_591'}

# %%
def get_fddb_dict(annotations):
  '''Przerabia annotacje z fddb_rectangular_annotation()
  na słownik wymagany przez detectron2.data.DatasetCatalog

  {'annotations': [{'bbox': [59, 71, 269, 353],
   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
   'category_id': 0,
   'iscrowd': 0,
   'segmentation': [[59, 71, 269, 71, 269, 353, 59, 353]]}],
   'file_name': 'FDDB/2002/07/29/big/img_136.jpg',
   'height': 450,
  'image_id': 18,
  'width': 319}

  '''
  dataset_dicts = []
  for idx, item in enumerate(annotations):
    record = {}
    file_path = IMAGES_PATH+item["path"]+".jpg"

    record["file_name"] = file_path 
    record["image_id"] = idx
    record["height"], record["width"] = cv2.imread(file_path).shape[:2]

    objs = []
    for box in item["boxes"]:
      box = [int(i) for i in box] # int vs float..
      xmin, ymin, xmax, ymax = box
      poly = [(xmin, ymin), (xmax, ymin), (xmax, ymax), (xmin, ymax)]
      poly = list(itertools.chain.from_iterable(poly))

      obj = {
        "bbox": [xmin, ymin, xmax, ymax],
        "bbox_mode": BoxMode.XYXY_ABS,
        "segmentation": [poly],
        "category_id": 0,
        "iscrowd": 0
      }
      objs.append(obj)

    record["annotations"] = objs
    dataset_dicts.append(record)

  return dataset_dicts

# %% [markdown]
# Rejestracja datasetu

# %%
classes = ['face']
for d in ["val"]:
  DatasetCatalog.register("faces_" + d, lambda d=d: get_fddb_dict(fddb_annotations if d == "val" else "null"))
  MetadataCatalog.get("faces_" + d).set(thing_classes = classes)

faces_metadata = MetadataCatalog.get("faces_val")

# %%
faces_metadata
# Out:
# Metadata(name='faces_val', thing_classes=['face'])

# %% [markdown]
# Wizualizacja annotacji na plikach z val

# %%
dataset_dicts = get_fddb_dict(fddb_annotations)
for d in random.sample(dataset_dicts, 1):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=faces_metadata, scale=0.9)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=311x405 at 0x7F0C707B9438>

# %% [markdown]
# Modele do testu

# %%
models = {
    # '800k' - parametry domyślne - jako punkt odniesienia
    '800k': {
        'config': 'FrozenBN',
        'pth': 'https://drive.google.com/uc?id=1-tqNKwZIFmkAbfJ1L2sibIO4PT_MwnVA',
        'weights_name': 'model_0799999.pth'},

    # 'BN_800k' - dodano BN - pokazanie wpływu BN przy małym batchu=2
    'BN_800k': {
        'config': 'BN',
        'pth': 'https://drive.google.com/uc?id=1-kRDjqkMk9qXbNfzVx09VE35YzgkP1AO',
        'weights_name': 'model_0799999.pth'},

    #'BN_Mish_V2_250+F_2_50k' - najlepszy wynik uczenie z Mish BN 250k + 50k z FrozenBN
    'BN_Mish_V2_250+F_2_50k': {
        'config': 'BN_Mish_V2F',
        'pth': 'https://drive.google.com/uc?id=1-I6YSAs9NrORI4cFISfK_-4Yhm1twfDi',
        'weights_name': 'model_0049999.pth'},
    
    # 'BN_Mish_V3_80+30k' - najszybsze uczenie 110k iteracji
    'BN_Mish_V3_80+_30k': {
        'config': 'BN_Mish_V3',
        'pth': 'https://drive.google.com/uc?id=1--bP5VPyqIrfrBxVZ5eLSsupIvBlQ8ef',
        'weights_name': 'model_0029999.pth'},

    # 'R50_C4_270k' - Detectron2 z backbone na R50 C4
    'R50_C4_270k': {
        'config': 'R50_C4',
        'pth': 'https://drive.google.com/uc?id=1-I4m091opkwIRHhvMLftt0eAQp6G0CmJ',
        'weights_name': 'model_0269999.pth'}
    }

# %% [markdown]
# Zestawy z konfiguracja podstawowych (cfg)

# %%
cfg_set = {
    'FrozenBN':'https://drive.google.com/uc?id=1rZFzJaR_g7uYuTguTdbUuCQYD4eXLeqw',
    'BN': 'https://drive.google.com/uc?id=1-doXtwe5iZHoqPzKGc2ZZbxj6Ebhxsn4',
    'BN_V2':'https://drive.google.com/uc?id=1wywB8UAaOO5KZx3IS35kV-rLsvJMIse6',
    'BN_Mish':'https://drive.google.com/uc?id=1-axV3KKg8-YiZZ7uDBh_2v181JoC9Nj3',
    'BN_Mish_V2':'https://drive.google.com/uc?id=1WoESx5RYvpapNicpSrmMoNJeE2GVm3zK',
    'BN_Mish_V3':'https://drive.google.com/uc?id=1-Kgd_2AS4EsD_ZPqP7SxkscyDjP-Qhnr',
    'BN_Mish_V2F':'https://drive.google.com/uc?id=1pCwyYCjIoduro2vIKMZi5HhlpaypH0_x',
    'R50_C4':'https://drive.google.com/uc?id=1-5P5Xyx5GM26p7g89CY-SSX0aluB7H9U',}

# %%
def cfg_write(cfg,cfg_all):
  for key in cfg_all.keys():
    if isinstance(cfg_all[key],dict): 
      cfg_write(cfg[key],cfg_all[key])
    else: cfg[key]=cfg_all[key]
  return cfg

def set_predictor(model_name=None, models_dict=models, cfg_dict=cfg_set ,device='cuda', cfg_DATASETS_TEST=None):
  url = models_dict[model_name]['pth'] 
  out = models_dict[model_name]['weights_name']
  gdown.download(url, out, True)
  # model configuration
  url_cfg = cfg_dict[models_dict[model_name]['config']] 
  gdown.download(url_cfg, "temporary.json", True)
  with open('temporary.json','r') as f:
    cfg_all=json.load(f)
  cfg = get_cfg()
  add_mobilenet_config(cfg)
  cfg = cfg_write(cfg,cfg_all)
  cfg.MODEL.WEIGHTS = models_dict[model_name]['weights_name']
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
  cfg.MODEL.DEVICE=device
  if cfg_DATASETS_TEST is not None:
    cfg.DATASETS.TEST = (cfg_DATASETS_TEST, )

  return DefaultPredictor(cfg), cfg

# %% [markdown]
# Funkcja pomiaru czasu ewaluacji modelu

# %%
def time_measurement(predictor, dataset):
  time_ = []
  for item in tqdm(dataset):
    start_ = time.time()
    img = cv2.imread(item["file_name"])
    outputs = predictor(img)
    diff = time.time() - start_
    time_.append(diff)
  # Total time
  total_time = np.array(time_).sum()
  # Mean time
  mean_diff = np.array(time_).mean()
  # Frames per second 
  fps = 1 / mean_diff
  print("Total time(sec): {:.2f}, Average(sec):{:.2f}, fps:{:.2f}\n".format(total_time, mean_diff, fps))
  return {"total_time": total_time, "mean_diff": mean_diff, "fps": fps}

# %% [markdown]
# Funkcja do ewaluacji modelu na FDDB

# %%
def predict_on_val(dataset, predictor, model_name):
    gbxs=[]
    dbxs=[]
    dset=dataset
    if 'annotations' in dataset[0].keys():  
      dset=[]
      for r in dataset:
        dset.append({'path' : r['file_name'],'marks' : [b['bbox'] for b in r['annotations']],
                     'persons': ['' for b in r['annotations']]})

    for item in tqdm(dset):
        im = cv2.imread(item["path"])
        outputs = predictor(im)
        pbxs = outputs['instances'].pred_boxes.tensor.tolist()
        pconfs = outputs['instances'].scores.tolist()
        dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
        dbxs.append(dbx)
        gbxs.append(item['marks'])
    
    return {'gbxs':gbxs,'dbxs':dbxs,'metric':dset}

# %%
def dict_to_file(dic, path):
    f = open(path,'w')
    f.write(str(dic))
    f.close()

def dict_from_file(filename):
    f = open(filename,'r')
    data=f.read()
    f.close()
    return eval(data)

# %% [markdown]
# Pomiar czasu ewaluacji modeli na zbiorze walidacyjnym

# %%
dataset = get_fddb_dict(fddb_annotations)

# %%
time_measurement_results = {}
for model in models:
  print(model)
  predictor, _ = set_predictor(model)
  time_measurement_results[model] = time_measurement(predictor, dataset=dataset)

print(time_measurement_results)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# Total time(sec): 172.24, Average(sec):0.06, fps:16.52
#
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# Total time(sec): 171.96, Average(sec):0.06, fps:16.55
#
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# Total time(sec): 194.33, Average(sec):0.07, fps:14.64
#
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# Total time(sec): 193.51, Average(sec):0.07, fps:14.70
#
# R50_C4_270k
# WARNING [07/30 14:03:05 d2.modeling.backbone.resnet]: ResNet.make_stage(first_stride=) is deprecated!  Use 'stride_per_block' or 'stride' instead.
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# Total time(sec): 693.68, Average(sec):0.24, fps:4.10
#
# {'800k': {'total_time': 172.2449450492859, 'mean_diff': 0.06054303868164706, 'fps': 16.517175579149427}, 'BN_800k': {'total_time': 171.95506262779236, 'mean_diff': 0.060441146793600124, 'fps': 16.545020289156493}, 'BN_Mish_V2_250+F_2_50k': {'total_time': 194.32584047317505, 'mean_diff': 0.06830433760041302, 'fps': 14.640358652624622}, 'BN_Mish_V3_80+_30k': {'total_time': 193.51394033432007, 'mean_diff': 0.06801895969571883, 'fps': 14.701783215642752}, 'R50_C4_270k': {'total_time': 693.6814067363739, 'mean_diff': 0.24382474753475356, 'fps': 4.1013064100782675}}

# %%
time_measurement_results
# Out:
# {'800k': {'fps': 16.517175579149427,
#   'mean_diff': 0.06054303868164706,
#   'total_time': 172.2449450492859},
#  'BN_800k': {'fps': 16.545020289156493,
#   'mean_diff': 0.060441146793600124,
#   'total_time': 171.95506262779236},
#  'BN_Mish_V2_250+F_2_50k': {'fps': 14.640358652624622,
#   'mean_diff': 0.06830433760041302,
#   'total_time': 194.32584047317505},
#  'BN_Mish_V3_80+_30k': {'fps': 14.701783215642752,
#   'mean_diff': 0.06801895969571883,
#   'total_time': 193.51394033432007},
#  'R50_C4_270k': {'fps': 4.1013064100782675,
#   'mean_diff': 0.24382474753475356,
#   'total_time': 693.6814067363739}}

# %% [markdown]
# Porównanie wyników

# %%
df_time_measurement_results = pd.DataFrame.from_dict(time_measurement_results, orient='index')
df_time_measurement_results
# Out:
#                         total_time  mean_diff        fps
# 800k                    172.244945   0.060543  16.517176
# BN_800k                 171.955063   0.060441  16.545020
# BN_Mish_V2_250+F_2_50k  194.325840   0.068304  14.640359
# BN_Mish_V3_80+_30k      193.513940   0.068019  14.701783
# R50_C4_270k             693.681407   0.243825   4.101306

# %% [markdown]
# Ewaluacja modeli na zbiorze walidacyjnym i mAP liczone funkcją Darka

# %%
FDDB_DATASET = get_fddb_dict(fddb_annotations)

# %%
pred = {}
for model in models:
  print(model)
  predictor, cfg = set_predictor(model)
  pred[model] = predict_on_val(FDDB_DATASET ,predictor, model)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))
# R50_C4_270k
# WARNING [07/30 14:29:25 d2.modeling.backbone.resnet]: ResNet.make_stage(first_stride=) is deprecated!  Use 'stride_per_block' or 'stride' instead.
# HBox(children=(FloatProgress(value=0.0, max=2845.0), HTML(value='')))

# %%
drive.mount('/content/drive')
OUTPUT_DIR_NAME = "OUTPUT_DIR_FDDB"
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)

print(OUTPUT_DIR_PATH)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ./drive/My Drive/OUTPUT_DIR_FDDB

# %%
output_file_name = "FDDB_output_dict"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(pred, output_file)

# %%
output_file_name = "time_measurement_results_dict"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(time_measurement_results, output_file)

# %% [markdown]
# mAP dla testowanych modeli

# %%
def model_mAP(pdict, model_name, title="Detectron2_Wider_Face_mAP_"):
  m,d=mAP(gbxs=pdict[model_name]['gbxs'],dbxs=pdict[model_name]['dbxs'],data=True)
  # plot_mAP(m,d,['All 0.50','All 0.00','large','medium','small'],1,title+model_name+'  conf>0',file=title+model_name)
  plot_mAP(m,d,'All',1,title+model_name+'  conf>0',file=title+model_name)
  return m,d

# %%
all_models_mAP = {}
pred.keys()
# Out:
# dict_keys(['800k', 'BN_800k', 'BN_Mish_V2_250+F_2_50k', 'BN_Mish_V3_80+_30k', 'R50_C4_270k'])

# %%
modelshow = list(pred.keys())[0]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="Detectron2_Wider_Face_mAP_")
# Out:
# Model: 800k
# All 0.50:   AP: 56.75%   Recall: 65.56%   IoU: 0.50
# All 0.55:   AP: 50.87%   Recall: 60.24%   IoU: 0.55
# All 0.60:   AP: 40.74%   Recall: 51.94%   IoU: 0.60
# All 0.65:   AP: 26.71%   Recall: 40.84%   IoU: 0.65
# All 0.70:   AP: 12.05%   Recall: 27.17%   IoU: 0.70
# All 0.75:   AP:  3.19%   Recall: 13.96%   IoU: 0.75
# All 0.80:   AP:  0.38%   Recall:  5.09%   IoU: 0.80
# All 0.85:   AP:  0.03%   Recall:  1.26%   IoU: 0.85
# All 0.90:   AP:  0.00%   Recall:  0.25%   IoU: 0.90
# All 0.95:   AP:  0.00%   Recall:  0.02%   IoU: 0.95
# All 0.00:   AP: 70.33%   Recall: 81.96%   IoU: 0.00
# small   :   AP: 45.39%   Recall: 73.95%   IoU: 0.50
# medium  :   AP: 71.20%   Recall: 76.97%   IoU: 0.50
# large   :   AP: 51.71%   Recall: 57.19%   IoU: 0.50

# %%
modelshow = list(pred.keys())[1]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="Detectron2_Wider_Face_mAP_")
# Out:
# Model: BN_800k
# All 0.50:   AP: 89.78%   Recall: 90.47%   IoU: 0.50
# All 0.55:   AP: 87.63%   Recall: 88.53%   IoU: 0.55
# All 0.60:   AP: 82.71%   Recall: 84.45%   IoU: 0.60
# All 0.65:   AP: 71.61%   Recall: 76.72%   IoU: 0.65
# All 0.70:   AP: 48.56%   Recall: 61.42%   IoU: 0.70
# All 0.75:   AP: 19.35%   Recall: 38.95%   IoU: 0.75
# All 0.80:   AP:  3.42%   Recall: 17.02%   IoU: 0.80
# All 0.85:   AP:  0.32%   Recall:  5.30%   IoU: 0.85
# All 0.90:   AP:  0.01%   Recall:  0.72%   IoU: 0.90
# All 0.95:   AP:  0.00%   Recall:  0.06%   IoU: 0.95
# All 0.00:   AP: 93.68%   Recall: 94.39%   IoU: 0.00
# small   :   AP: 59.64%   Recall: 73.95%   IoU: 0.50
# medium  :   AP: 82.23%   Recall: 83.35%   IoU: 0.50
# large   :   AP: 96.36%   Recall: 96.51%   IoU: 0.50

# %%
modelshow = list(pred.keys())[2]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="Detectron2_Wider_Face_mAP_")
# Out:
# Model: BN_Mish_V2_250+F_2_50k
# All 0.50:   AP: 91.69%   Recall: 92.36%   IoU: 0.50
# All 0.55:   AP: 88.78%   Recall: 89.83%   IoU: 0.55
# All 0.60:   AP: 82.76%   Recall: 85.03%   IoU: 0.60
# All 0.65:   AP: 67.78%   Recall: 74.82%   IoU: 0.65
# All 0.70:   AP: 39.59%   Recall: 55.56%   IoU: 0.70
# All 0.75:   AP: 11.11%   Recall: 29.57%   IoU: 0.75
# All 0.80:   AP:  1.13%   Recall:  9.67%   IoU: 0.80
# All 0.85:   AP:  0.04%   Recall:  1.82%   IoU: 0.85
# All 0.90:   AP:  0.00%   Recall:  0.21%   IoU: 0.90
# All 0.95:   AP:  0.00%   Recall:  0.02%   IoU: 0.95
# All 0.00:   AP: 94.99%   Recall: 95.57%   IoU: 0.00
# small   :   AP: 64.55%   Recall: 82.33%   IoU: 0.50
# medium  :   AP: 85.37%   Recall: 86.54%   IoU: 0.50
# large   :   AP: 96.92%   Recall: 97.05%   IoU: 0.50

# %%
modelshow = list(pred.keys())[3]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="Detectron2_Wider_Face_mAP_")
# Out:
# Model: BN_Mish_V3_80+_30k
# All 0.50:   AP: 91.09%   Recall: 91.72%   IoU: 0.50
# All 0.55:   AP: 88.77%   Recall: 89.71%   IoU: 0.55
# All 0.60:   AP: 83.01%   Recall: 85.26%   IoU: 0.60
# All 0.65:   AP: 71.76%   Recall: 77.55%   IoU: 0.65
# All 0.70:   AP: 47.77%   Recall: 61.79%   IoU: 0.70
# All 0.75:   AP: 17.05%   Recall: 37.11%   IoU: 0.75
# All 0.80:   AP:  2.53%   Recall: 14.72%   IoU: 0.80
# All 0.85:   AP:  0.12%   Recall:  3.31%   IoU: 0.85
# All 0.90:   AP:  0.00%   Recall:  0.41%   IoU: 0.90
# All 0.95:   AP:  0.00%   Recall:  0.00%   IoU: 0.95
# All 0.00:   AP: 94.12%   Recall: 94.68%   IoU: 0.00
# small   :   AP: 60.59%   Recall: 77.67%   IoU: 0.50
# medium  :   AP: 84.32%   Recall: 85.19%   IoU: 0.50
# large   :   AP: 97.04%   Recall: 97.19%   IoU: 0.50

# %%
modelshow = list(pred.keys())[4]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="Detectron2_Wider_Face_mAP_")
# Out:
# Model: R50_C4_270k
# All 0.50:   AP: 93.20%   Recall: 93.73%   IoU: 0.50
# All 0.55:   AP: 90.49%   Recall: 91.28%   IoU: 0.55
# All 0.60:   AP: 84.42%   Recall: 86.42%   IoU: 0.60
# All 0.65:   AP: 69.11%   Recall: 75.83%   IoU: 0.65
# All 0.70:   AP: 38.22%   Recall: 54.90%   IoU: 0.70
# All 0.75:   AP: 11.67%   Recall: 29.78%   IoU: 0.75
# All 0.80:   AP:  1.19%   Recall:  9.26%   IoU: 0.80
# All 0.85:   AP:  0.03%   Recall:  1.22%   IoU: 0.85
# All 0.90:   AP:  0.00%   Recall:  0.06%   IoU: 0.90
# All 0.95:   AP:  0.00%   Recall:  0.00%   IoU: 0.95
# All 0.00:   AP: 96.63%   Recall: 97.02%   IoU: 0.00
# small   :   AP: 65.22%   Recall: 81.40%   IoU: 0.50
# medium  :   AP: 87.91%   Recall: 88.98%   IoU: 0.50
# large   :   AP: 97.76%   Recall: 97.86%   IoU: 0.50

# %% [markdown]
# Zapis wyników

# %%
output_file_name = "all_models_mAP"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(all_models_mAP, output_file)

# %%
modeldict = {}
DD_mAP = {}
for item in all_models_mAP.keys():
  for i in all_models_mAP[item][0].keys():
    modeldict[i] =  {
        "AP" : all_models_mAP[item][0][i][0]*100,
        "Recall" : all_models_mAP[item][0][i][1]*100,
        "IoU" : all_models_mAP[item][0][i][2]*100,
    }
  DD_mAP[item] = modeldict

# %%
output_file_name = "all_models_mAP_t"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(DD_mAP, output_file)

# %% [markdown]
# Ewaluacja na FDDB z wykorzystaniem COCOEvaluator i funkc

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# %%
AP_VAL = {}
drive.mount('/content/drive')
OUTPUT_DIR_NAME = "OUTPUT_DIR_FDDB"
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)

for model in models:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = set_predictor(model, cfg_DATASETS_TEST="faces_val")
  print(cfg.DATASETS.TEST)
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator)
  AP_VAL[model] = evaluator.evaluate()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 800k
# ('faces_val',)
# ./drive/My Drive/OUTPUT_DIR_FDDB/800k
# [07/30 16:09:44 d2.evaluation.coco_evaluation]: 'faces_val' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# [07/30 16:09:44 d2.data.datasets.coco]: Converting annotations of dataset 'faces_val' to COCO format ...)
# [07/30 16:09:50 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [07/30 16:09:51 d2.data.datasets.coco]: Conversion finished, #images: 2845, #annotations: 5171
# [07/30 16:09:51 d2.data.datasets.coco]: Caching COCO format annotations at './drive/My Drive/OUTPUT_DIR_FDDB/800k/faces_val_coco_format.json' ...
# [07/30 16:09:58 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    face    | 5171         |
# |            |              |
# [07/30 16:09:58 d2.data.common]: Serializing 2845 elements to byte tensors and concatenating them all ...
# [07/30 16:09:58 d2.data.common]: Serialized dataset takes 0.86 MiB
# [07/30 16:09:58 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/30 16:09:58 d2.evaluation.evaluator]: Start inference on 2845 images
# [07/30 16:09:59 d2.evaluation.evaluator]: Inference done 11/2845. 0.0511 s / img. ETA=0:02:28
# [07/30 16:10:04 d2.evaluation.evaluator]: Inference done 106/2845. 0.0507 s / img. ETA=0:02:24
# [07/30 16:10:09 d2.evaluation.evaluator]: Inference done 200/2845. 0.0510 s / img. ETA=0:02:20
# [07/30 16:10:14 d2.evaluation.evaluator]: Inference done 293/2845. 0.0512 s / img. ETA=0:02:16
# [07/30 16:10:19 d2.evaluation.evaluator]: Inference done 384/2845. 0.0517 s / img. ETA=0:02:12
# [07/30 16:10:25 d2.evaluation.evaluator]: Inference done 477/2845. 0.0518 s / img. ETA=0:02:07
# [07/30 16:10:30 d2.evaluation.evaluator]: Inference done 569/2845. 0.0518 s / img. ETA=0:02:02
# [07/30 16:10:35 d2.evaluation.evaluator]: Inference done 664/2845. 0.0517 s / img. ETA=0:01:57
# [07/30 16:10:40 d2.evaluation.evaluator]: Inference done 759/2845. 0.0516 s / img. ETA=0:01:52
# [07/30 16:10:45 d2.evaluation.evaluator]: Inference done 854/2845. 0.0515 s / img. ETA=0:01:46
# [07/30 16:10:50 d2.evaluation.evaluator]: Inference done 946/2845. 0.0516 s / img. ETA=0:01:42
# [07/30 16:10:55 d2.evaluation.evaluator]: Inference done 1038/2845. 0.0516 s / img. ETA=0:01:37
# [07/30 16:11:00 d2.evaluation.evaluator]: Inference done 1129/2845. 0.0517 s / img. ETA=0:01:32
# [07/30 16:11:05 d2.evaluation.evaluator]: Inference done 1223/2845. 0.0516 s / img. ETA=0:01:27
# [07/30 16:11:10 d2.evaluation.evaluator]: Inference done 1316/2845. 0.0516 s / img. ETA=0:01:22
# [07/30 16:11:15 d2.evaluation.evaluator]: Inference done 1412/2845. 0.0516 s / img. ETA=0:01:17
# [07/30 16:11:20 d2.evaluation.evaluator]: Inference done 1505/2845. 0.0516 s / img. ETA=0:01:12
# [07/30 16:11:25 d2.evaluation.evaluator]: Inference done 1599/2845. 0.0516 s / img. ETA=0:01:06
# [07/30 16:11:30 d2.evaluation.evaluator]: Inference done 1694/2845. 0.0515 s / img. ETA=0:01:01
# [07/30 16:11:35 d2.evaluation.evaluator]: Inference done 1789/2845. 0.0515 s / img. ETA=0:00:56
# [07/30 16:11:40 d2.evaluation.evaluator]: Inference done 1882/2845. 0.0515 s / img. ETA=0:00:51
# [07/30 16:11:45 d2.evaluation.evaluator]: Inference done 1977/2845. 0.0514 s / img. ETA=0:00:46
# [07/30 16:11:50 d2.evaluation.evaluator]: Inference done 2071/2845. 0.0514 s / img. ETA=0:00:41
# [07/30 16:11:55 d2.evaluation.evaluator]: Inference done 2166/2845. 0.0514 s / img. ETA=0:00:36
# [07/30 16:12:00 d2.evaluation.evaluator]: Inference done 2260/2845. 0.0514 s / img. ETA=0:00:31
# [07/30 16:12:05 d2.evaluation.evaluator]: Inference done 2353/2845. 0.0514 s / img. ETA=0:00:26
# [07/30 16:12:10 d2.evaluation.evaluator]: Inference done 2447/2845. 0.0514 s / img. ETA=0:00:21
# [07/30 16:12:15 d2.evaluation.evaluator]: Inference done 2543/2845. 0.0514 s / img. ETA=0:00:16
# [07/30 16:12:20 d2.evaluation.evaluator]: Inference done 2636/2845. 0.0514 s / img. ETA=0:00:11
# [07/30 16:12:25 d2.evaluation.evaluator]: Inference done 2729/2845. 0.0514 s / img. ETA=0:00:06
# [07/30 16:12:30 d2.evaluation.evaluator]: Inference done 2821/2845. 0.0514 s / img. ETA=0:00:01
# [07/30 16:12:31 d2.evaluation.evaluator]: Total inference time: 0:02:32.362611 (0.053649 s / img per device, on 1 devices)
# [07/30 16:12:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:25 (0.051400 s / img per device, on 1 devices)
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/800k/coco_instances_results.json
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.43 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 19.019 | 57.740 | 3.563  | 13.694 | 25.408 | 17.909 |
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/800k/coco_instances_results.json
# [07/30 16:12:32 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.42 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
# [07/30 16:12:33 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 19.019 | 57.740 | 3.563  | 13.694 | 25.408 | 17.909 |
# BN_800k
# ('faces_val',)
# ./drive/My Drive/OUTPUT_DIR_FDDB/BN_800k
# [07/30 16:12:47 d2.data.common]: Serializing 2845 elements to byte tensors and concatenating them all ...
# [07/30 16:12:47 d2.data.common]: Serialized dataset takes 0.86 MiB
# [07/30 16:12:47 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/30 16:12:47 d2.evaluation.evaluator]: Start inference on 2845 images
# [07/30 16:12:48 d2.evaluation.evaluator]: Inference done 11/2845. 0.0500 s / img. ETA=0:02:25
# [07/30 16:12:53 d2.evaluation.evaluator]: Inference done 103/2845. 0.0522 s / img. ETA=0:02:28
# [07/30 16:12:58 d2.evaluation.evaluator]: Inference done 194/2845. 0.0525 s / img. ETA=0:02:24
# [07/30 16:13:03 d2.evaluation.evaluator]: Inference done 284/2845. 0.0528 s / img. ETA=0:02:20
# [07/30 16:13:08 d2.evaluation.evaluator]: Inference done 377/2845. 0.0526 s / img. ETA=0:02:15
# [07/30 16:13:13 d2.evaluation.evaluator]: Inference done 469/2845. 0.0526 s / img. ETA=0:02:10
# [07/30 16:13:18 d2.evaluation.evaluator]: Inference done 560/2845. 0.0527 s / img. ETA=0:02:05
# [07/30 16:13:23 d2.evaluation.evaluator]: Inference done 652/2845. 0.0527 s / img. ETA=0:02:00
# [07/30 16:13:28 d2.evaluation.evaluator]: Inference done 746/2845. 0.0525 s / img. ETA=0:01:54
# [07/30 16:13:33 d2.evaluation.evaluator]: Inference done 838/2845. 0.0524 s / img. ETA=0:01:49
# [07/30 16:13:38 d2.evaluation.evaluator]: Inference done 930/2845. 0.0525 s / img. ETA=0:01:44
# [07/30 16:13:43 d2.evaluation.evaluator]: Inference done 1021/2845. 0.0525 s / img. ETA=0:01:39
# [07/30 16:13:48 d2.evaluation.evaluator]: Inference done 1113/2845. 0.0525 s / img. ETA=0:01:34
# [07/30 16:13:53 d2.evaluation.evaluator]: Inference done 1207/2845. 0.0524 s / img. ETA=0:01:29
# [07/30 16:13:58 d2.evaluation.evaluator]: Inference done 1300/2845. 0.0524 s / img. ETA=0:01:24
# [07/30 16:14:03 d2.evaluation.evaluator]: Inference done 1392/2845. 0.0524 s / img. ETA=0:01:19
# [07/30 16:14:08 d2.evaluation.evaluator]: Inference done 1484/2845. 0.0524 s / img. ETA=0:01:14
# [07/30 16:14:13 d2.evaluation.evaluator]: Inference done 1578/2845. 0.0523 s / img. ETA=0:01:09
# [07/30 16:14:18 d2.evaluation.evaluator]: Inference done 1670/2845. 0.0523 s / img. ETA=0:01:04
# [07/30 16:14:23 d2.evaluation.evaluator]: Inference done 1762/2845. 0.0523 s / img. ETA=0:00:59
# [07/30 16:14:28 d2.evaluation.evaluator]: Inference done 1855/2845. 0.0523 s / img. ETA=0:00:53
# [07/30 16:14:33 d2.evaluation.evaluator]: Inference done 1946/2845. 0.0523 s / img. ETA=0:00:49
# [07/30 16:14:38 d2.evaluation.evaluator]: Inference done 2038/2845. 0.0523 s / img. ETA=0:00:44
# [07/30 16:14:43 d2.evaluation.evaluator]: Inference done 2129/2845. 0.0524 s / img. ETA=0:00:39
# [07/30 16:14:48 d2.evaluation.evaluator]: Inference done 2222/2845. 0.0524 s / img. ETA=0:00:34
# [07/30 16:14:53 d2.evaluation.evaluator]: Inference done 2315/2845. 0.0523 s / img. ETA=0:00:28
# [07/30 16:14:58 d2.evaluation.evaluator]: Inference done 2406/2845. 0.0524 s / img. ETA=0:00:23
# [07/30 16:15:03 d2.evaluation.evaluator]: Inference done 2497/2845. 0.0524 s / img. ETA=0:00:19
# [07/30 16:15:08 d2.evaluation.evaluator]: Inference done 2588/2845. 0.0524 s / img. ETA=0:00:14
# [07/30 16:15:13 d2.evaluation.evaluator]: Inference done 2680/2845. 0.0524 s / img. ETA=0:00:09
# [07/30 16:15:19 d2.evaluation.evaluator]: Inference done 2770/2845. 0.0524 s / img. ETA=0:00:04
# [07/30 16:15:23 d2.evaluation.evaluator]: Total inference time: 0:02:35.374478 (0.054709 s / img per device, on 1 devices)
# [07/30 16:15:23 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:28 (0.052452 s / img per device, on 1 devices)
# [07/30 16:15:23 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:15:23 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_800k/coco_instances_results.json
# [07/30 16:15:23 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.48 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# [07/30 16:15:23 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.693 | 89.397 | 18.394 | 18.949 | 32.746 | 46.565 |
# [07/30 16:15:24 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:15:24 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_800k/coco_instances_results.json
# [07/30 16:15:24 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.37 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
# [07/30 16:15:24 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.693 | 89.397 | 18.394 | 18.949 | 32.746 | 46.565 |
# BN_Mish_V2_250+F_2_50k
# ('faces_val',)
# ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V2_250+F_2_50k
# [07/30 16:15:38 d2.data.common]: Serializing 2845 elements to byte tensors and concatenating them all ...
# [07/30 16:15:38 d2.data.common]: Serialized dataset takes 0.86 MiB
# [07/30 16:15:38 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/30 16:15:38 d2.evaluation.evaluator]: Start inference on 2845 images
# [07/30 16:15:39 d2.evaluation.evaluator]: Inference done 11/2845. 0.0535 s / img. ETA=0:02:35
# [07/30 16:15:44 d2.evaluation.evaluator]: Inference done 100/2845. 0.0539 s / img. ETA=0:02:34
# [07/30 16:15:49 d2.evaluation.evaluator]: Inference done 189/2845. 0.0541 s / img. ETA=0:02:29
# [07/30 16:15:54 d2.evaluation.evaluator]: Inference done 280/2845. 0.0538 s / img. ETA=0:02:23
# [07/30 16:15:59 d2.evaluation.evaluator]: Inference done 368/2845. 0.0541 s / img. ETA=0:02:19
# [07/30 16:16:04 d2.evaluation.evaluator]: Inference done 457/2845. 0.0541 s / img. ETA=0:02:14
# [07/30 16:16:09 d2.evaluation.evaluator]: Inference done 547/2845. 0.0540 s / img. ETA=0:02:09
# [07/30 16:16:14 d2.evaluation.evaluator]: Inference done 637/2845. 0.0540 s / img. ETA=0:02:04
# [07/30 16:16:19 d2.evaluation.evaluator]: Inference done 727/2845. 0.0540 s / img. ETA=0:01:58
# [07/30 16:16:24 d2.evaluation.evaluator]: Inference done 818/2845. 0.0539 s / img. ETA=0:01:53
# [07/30 16:16:29 d2.evaluation.evaluator]: Inference done 909/2845. 0.0538 s / img. ETA=0:01:48
# [07/30 16:16:34 d2.evaluation.evaluator]: Inference done 998/2845. 0.0538 s / img. ETA=0:01:43
# [07/30 16:16:39 d2.evaluation.evaluator]: Inference done 1088/2845. 0.0538 s / img. ETA=0:01:38
# [07/30 16:16:44 d2.evaluation.evaluator]: Inference done 1179/2845. 0.0537 s / img. ETA=0:01:33
# [07/30 16:16:49 d2.evaluation.evaluator]: Inference done 1269/2845. 0.0538 s / img. ETA=0:01:28
# [07/30 16:16:54 d2.evaluation.evaluator]: Inference done 1360/2845. 0.0537 s / img. ETA=0:01:22
# [07/30 16:16:59 d2.evaluation.evaluator]: Inference done 1451/2845. 0.0537 s / img. ETA=0:01:17
# [07/30 16:17:04 d2.evaluation.evaluator]: Inference done 1542/2845. 0.0537 s / img. ETA=0:01:12
# [07/30 16:17:09 d2.evaluation.evaluator]: Inference done 1632/2845. 0.0537 s / img. ETA=0:01:07
# [07/30 16:17:14 d2.evaluation.evaluator]: Inference done 1724/2845. 0.0536 s / img. ETA=0:01:02
# [07/30 16:17:19 d2.evaluation.evaluator]: Inference done 1814/2845. 0.0536 s / img. ETA=0:00:57
# [07/30 16:17:24 d2.evaluation.evaluator]: Inference done 1906/2845. 0.0536 s / img. ETA=0:00:52
# [07/30 16:17:29 d2.evaluation.evaluator]: Inference done 1997/2845. 0.0535 s / img. ETA=0:00:47
# [07/30 16:17:34 d2.evaluation.evaluator]: Inference done 2087/2845. 0.0535 s / img. ETA=0:00:42
# [07/30 16:17:39 d2.evaluation.evaluator]: Inference done 2178/2845. 0.0535 s / img. ETA=0:00:37
# [07/30 16:17:44 d2.evaluation.evaluator]: Inference done 2269/2845. 0.0535 s / img. ETA=0:00:32
# [07/30 16:17:49 d2.evaluation.evaluator]: Inference done 2359/2845. 0.0535 s / img. ETA=0:00:27
# [07/30 16:17:54 d2.evaluation.evaluator]: Inference done 2450/2845. 0.0535 s / img. ETA=0:00:21
# [07/30 16:17:59 d2.evaluation.evaluator]: Inference done 2541/2845. 0.0535 s / img. ETA=0:00:16
# [07/30 16:18:05 d2.evaluation.evaluator]: Inference done 2632/2845. 0.0535 s / img. ETA=0:00:11
# [07/30 16:18:10 d2.evaluation.evaluator]: Inference done 2721/2845. 0.0535 s / img. ETA=0:00:06
# [07/30 16:18:15 d2.evaluation.evaluator]: Inference done 2813/2845. 0.0535 s / img. ETA=0:00:01
# [07/30 16:18:16 d2.evaluation.evaluator]: Total inference time: 0:02:38.088453 (0.055665 s / img per device, on 1 devices)
# [07/30 16:18:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:31 (0.053473 s / img per device, on 1 devices)
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.36 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.473
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 37.604 | 90.541 | 10.509 | 19.020 | 32.084 | 42.633 |
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [07/30 16:18:17 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.48 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.473
# [07/30 16:18:18 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 37.604 | 90.541 | 10.509 | 19.020 | 32.084 | 42.633 |
# BN_Mish_V3_80+_30k
# ('faces_val',)
# ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V3_80+_30k
# [07/30 16:18:30 d2.data.common]: Serializing 2845 elements to byte tensors and concatenating them all ...
# [07/30 16:18:30 d2.data.common]: Serialized dataset takes 0.86 MiB
# [07/30 16:18:30 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/30 16:18:30 d2.evaluation.evaluator]: Start inference on 2845 images
# [07/30 16:18:31 d2.evaluation.evaluator]: Inference done 11/2845. 0.0528 s / img. ETA=0:02:33
# [07/30 16:18:36 d2.evaluation.evaluator]: Inference done 103/2845. 0.0528 s / img. ETA=0:02:30
# [07/30 16:18:41 d2.evaluation.evaluator]: Inference done 192/2845. 0.0535 s / img. ETA=0:02:27
# [07/30 16:18:46 d2.evaluation.evaluator]: Inference done 283/2845. 0.0535 s / img. ETA=0:02:22
# [07/30 16:18:51 d2.evaluation.evaluator]: Inference done 373/2845. 0.0535 s / img. ETA=0:02:17
# [07/30 16:18:56 d2.evaluation.evaluator]: Inference done 462/2845. 0.0536 s / img. ETA=0:02:12
# [07/30 16:19:01 d2.evaluation.evaluator]: Inference done 552/2845. 0.0536 s / img. ETA=0:02:07
# [07/30 16:19:06 d2.evaluation.evaluator]: Inference done 641/2845. 0.0537 s / img. ETA=0:02:03
# [07/30 16:19:11 d2.evaluation.evaluator]: Inference done 732/2845. 0.0536 s / img. ETA=0:01:57
# [07/30 16:19:16 d2.evaluation.evaluator]: Inference done 823/2845. 0.0536 s / img. ETA=0:01:52
# [07/30 16:19:21 d2.evaluation.evaluator]: Inference done 914/2845. 0.0535 s / img. ETA=0:01:47
# [07/30 16:19:26 d2.evaluation.evaluator]: Inference done 1004/2845. 0.0536 s / img. ETA=0:01:42
# [07/30 16:19:31 d2.evaluation.evaluator]: Inference done 1092/2845. 0.0537 s / img. ETA=0:01:37
# [07/30 16:19:36 d2.evaluation.evaluator]: Inference done 1182/2845. 0.0537 s / img. ETA=0:01:32
# [07/30 16:19:41 d2.evaluation.evaluator]: Inference done 1272/2845. 0.0537 s / img. ETA=0:01:27
# [07/30 16:19:46 d2.evaluation.evaluator]: Inference done 1363/2845. 0.0536 s / img. ETA=0:01:22
# [07/30 16:19:51 d2.evaluation.evaluator]: Inference done 1456/2845. 0.0535 s / img. ETA=0:01:17
# [07/30 16:19:56 d2.evaluation.evaluator]: Inference done 1547/2845. 0.0535 s / img. ETA=0:01:12
# [07/30 16:20:01 d2.evaluation.evaluator]: Inference done 1637/2845. 0.0535 s / img. ETA=0:01:07
# [07/30 16:20:06 d2.evaluation.evaluator]: Inference done 1727/2845. 0.0535 s / img. ETA=0:01:02
# [07/30 16:20:11 d2.evaluation.evaluator]: Inference done 1817/2845. 0.0535 s / img. ETA=0:00:57
# [07/30 16:20:16 d2.evaluation.evaluator]: Inference done 1907/2845. 0.0535 s / img. ETA=0:00:52
# [07/30 16:20:21 d2.evaluation.evaluator]: Inference done 1997/2845. 0.0535 s / img. ETA=0:00:47
# [07/30 16:20:26 d2.evaluation.evaluator]: Inference done 2087/2845. 0.0535 s / img. ETA=0:00:42
# [07/30 16:20:31 d2.evaluation.evaluator]: Inference done 2177/2845. 0.0535 s / img. ETA=0:00:37
# [07/30 16:20:36 d2.evaluation.evaluator]: Inference done 2267/2845. 0.0535 s / img. ETA=0:00:32
# [07/30 16:20:41 d2.evaluation.evaluator]: Inference done 2357/2845. 0.0536 s / img. ETA=0:00:27
# [07/30 16:20:46 d2.evaluation.evaluator]: Inference done 2445/2845. 0.0536 s / img. ETA=0:00:22
# [07/30 16:20:51 d2.evaluation.evaluator]: Inference done 2535/2845. 0.0536 s / img. ETA=0:00:17
# [07/30 16:20:56 d2.evaluation.evaluator]: Inference done 2626/2845. 0.0536 s / img. ETA=0:00:12
# [07/30 16:21:02 d2.evaluation.evaluator]: Inference done 2713/2845. 0.0536 s / img. ETA=0:00:07
# [07/30 16:21:07 d2.evaluation.evaluator]: Inference done 2804/2845. 0.0536 s / img. ETA=0:00:02
# [07/30 16:21:09 d2.evaluation.evaluator]: Total inference time: 0:02:38.673408 (0.055871 s / img per device, on 1 devices)
# [07/30 16:21:09 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:32 (0.053668 s / img per device, on 1 devices)
# [07/30 16:21:09 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:21:09 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V3_80+_30k/coco_instances_results.json
# [07/30 16:21:09 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.43 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.509
# [07/30 16:21:10 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.490 | 90.495 | 15.789 | 18.186 | 32.996 | 46.238 |
# [07/30 16:21:10 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:21:10 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/BN_Mish_V3_80+_30k/coco_instances_results.json
# [07/30 16:21:10 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.33 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.509
# [07/30 16:21:10 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.490 | 90.495 | 15.789 | 18.186 | 32.996 | 46.238 |
# R50_C4_270k
# WARNING [07/30 16:21:21 d2.modeling.backbone.resnet]: ResNet.make_stage(first_stride=) is deprecated!  Use 'stride_per_block' or 'stride' instead.
# ('faces_val',)
# ./drive/My Drive/OUTPUT_DIR_FDDB/R50_C4_270k
# [07/30 16:21:28 d2.data.common]: Serializing 2845 elements to byte tensors and concatenating them all ...
# [07/30 16:21:28 d2.data.common]: Serialized dataset takes 0.86 MiB
# [07/30 16:21:28 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/30 16:21:28 d2.evaluation.evaluator]: Start inference on 2845 images
# [07/30 16:21:31 d2.evaluation.evaluator]: Inference done 11/2845. 0.2278 s / img. ETA=0:10:50
# [07/30 16:21:36 d2.evaluation.evaluator]: Inference done 33/2845. 0.2278 s / img. ETA=0:10:46
# [07/30 16:21:41 d2.evaluation.evaluator]: Inference done 56/2845. 0.2264 s / img. ETA=0:10:38
# [07/30 16:21:47 d2.evaluation.evaluator]: Inference done 78/2845. 0.2262 s / img. ETA=0:10:32
# [07/30 16:21:52 d2.evaluation.evaluator]: Inference done 101/2845. 0.2253 s / img. ETA=0:10:24
# [07/30 16:21:57 d2.evaluation.evaluator]: Inference done 124/2845. 0.2248 s / img. ETA=0:10:17
# [07/30 16:22:02 d2.evaluation.evaluator]: Inference done 146/2845. 0.2253 s / img. ETA=0:10:14
# [07/30 16:22:07 d2.evaluation.evaluator]: Inference done 168/2845. 0.2256 s / img. ETA=0:10:09
# [07/30 16:22:12 d2.evaluation.evaluator]: Inference done 190/2845. 0.2260 s / img. ETA=0:10:06
# [07/30 16:22:17 d2.evaluation.evaluator]: Inference done 212/2845. 0.2264 s / img. ETA=0:10:02
# [07/30 16:22:22 d2.evaluation.evaluator]: Inference done 234/2845. 0.2264 s / img. ETA=0:09:56
# [07/30 16:22:27 d2.evaluation.evaluator]: Inference done 257/2845. 0.2262 s / img. ETA=0:09:51
# [07/30 16:22:33 d2.evaluation.evaluator]: Inference done 280/2845. 0.2258 s / img. ETA=0:09:44
# [07/30 16:22:38 d2.evaluation.evaluator]: Inference done 303/2845. 0.2257 s / img. ETA=0:09:39
# [07/30 16:22:43 d2.evaluation.evaluator]: Inference done 325/2845. 0.2259 s / img. ETA=0:09:34
# [07/30 16:22:48 d2.evaluation.evaluator]: Inference done 347/2845. 0.2260 s / img. ETA=0:09:30
# [07/30 16:22:53 d2.evaluation.evaluator]: Inference done 369/2845. 0.2261 s / img. ETA=0:09:25
# [07/30 16:22:58 d2.evaluation.evaluator]: Inference done 391/2845. 0.2262 s / img. ETA=0:09:20
# [07/30 16:23:03 d2.evaluation.evaluator]: Inference done 413/2845. 0.2262 s / img. ETA=0:09:15
# [07/30 16:23:08 d2.evaluation.evaluator]: Inference done 436/2845. 0.2261 s / img. ETA=0:09:10
# [07/30 16:23:13 d2.evaluation.evaluator]: Inference done 458/2845. 0.2262 s / img. ETA=0:09:05
# [07/30 16:23:18 d2.evaluation.evaluator]: Inference done 480/2845. 0.2263 s / img. ETA=0:09:00
# [07/30 16:23:23 d2.evaluation.evaluator]: Inference done 502/2845. 0.2264 s / img. ETA=0:08:55
# [07/30 16:23:29 d2.evaluation.evaluator]: Inference done 524/2845. 0.2264 s / img. ETA=0:08:50
# [07/30 16:23:34 d2.evaluation.evaluator]: Inference done 546/2845. 0.2265 s / img. ETA=0:08:45
# [07/30 16:23:39 d2.evaluation.evaluator]: Inference done 568/2845. 0.2266 s / img. ETA=0:08:41
# [07/30 16:23:44 d2.evaluation.evaluator]: Inference done 590/2845. 0.2266 s / img. ETA=0:08:36
# [07/30 16:23:49 d2.evaluation.evaluator]: Inference done 612/2845. 0.2266 s / img. ETA=0:08:31
# [07/30 16:23:54 d2.evaluation.evaluator]: Inference done 634/2845. 0.2266 s / img. ETA=0:08:26
# [07/30 16:23:59 d2.evaluation.evaluator]: Inference done 656/2845. 0.2267 s / img. ETA=0:08:21
# [07/30 16:24:04 d2.evaluation.evaluator]: Inference done 678/2845. 0.2267 s / img. ETA=0:08:16
# [07/30 16:24:09 d2.evaluation.evaluator]: Inference done 700/2845. 0.2268 s / img. ETA=0:08:11
# [07/30 16:24:14 d2.evaluation.evaluator]: Inference done 722/2845. 0.2268 s / img. ETA=0:08:06
# [07/30 16:24:19 d2.evaluation.evaluator]: Inference done 744/2845. 0.2268 s / img. ETA=0:08:01
# [07/30 16:24:24 d2.evaluation.evaluator]: Inference done 766/2845. 0.2268 s / img. ETA=0:07:56
# [07/30 16:24:29 d2.evaluation.evaluator]: Inference done 788/2845. 0.2268 s / img. ETA=0:07:51
# [07/30 16:24:34 d2.evaluation.evaluator]: Inference done 810/2845. 0.2268 s / img. ETA=0:07:46
# [07/30 16:24:39 d2.evaluation.evaluator]: Inference done 832/2845. 0.2268 s / img. ETA=0:07:41
# [07/30 16:24:44 d2.evaluation.evaluator]: Inference done 855/2845. 0.2267 s / img. ETA=0:07:35
# [07/30 16:24:50 d2.evaluation.evaluator]: Inference done 878/2845. 0.2266 s / img. ETA=0:07:30
# [07/30 16:24:55 d2.evaluation.evaluator]: Inference done 901/2845. 0.2266 s / img. ETA=0:07:24
# [07/30 16:25:00 d2.evaluation.evaluator]: Inference done 923/2845. 0.2266 s / img. ETA=0:07:19
# [07/30 16:25:05 d2.evaluation.evaluator]: Inference done 945/2845. 0.2267 s / img. ETA=0:07:14
# [07/30 16:25:10 d2.evaluation.evaluator]: Inference done 967/2845. 0.2267 s / img. ETA=0:07:10
# [07/30 16:25:15 d2.evaluation.evaluator]: Inference done 989/2845. 0.2267 s / img. ETA=0:07:05
# [07/30 16:25:20 d2.evaluation.evaluator]: Inference done 1011/2845. 0.2268 s / img. ETA=0:07:00
# [07/30 16:25:25 d2.evaluation.evaluator]: Inference done 1033/2845. 0.2268 s / img. ETA=0:06:55
# [07/30 16:25:30 d2.evaluation.evaluator]: Inference done 1055/2845. 0.2268 s / img. ETA=0:06:50
# [07/30 16:25:35 d2.evaluation.evaluator]: Inference done 1077/2845. 0.2268 s / img. ETA=0:06:45
# [07/30 16:25:41 d2.evaluation.evaluator]: Inference done 1099/2845. 0.2269 s / img. ETA=0:06:40
# [07/30 16:25:46 d2.evaluation.evaluator]: Inference done 1121/2845. 0.2269 s / img. ETA=0:06:35
# [07/30 16:25:51 d2.evaluation.evaluator]: Inference done 1143/2845. 0.2269 s / img. ETA=0:06:30
# [07/30 16:25:56 d2.evaluation.evaluator]: Inference done 1165/2845. 0.2269 s / img. ETA=0:06:25
# [07/30 16:26:01 d2.evaluation.evaluator]: Inference done 1187/2845. 0.2269 s / img. ETA=0:06:20
# [07/30 16:26:06 d2.evaluation.evaluator]: Inference done 1209/2845. 0.2269 s / img. ETA=0:06:14
# [07/30 16:26:11 d2.evaluation.evaluator]: Inference done 1232/2845. 0.2269 s / img. ETA=0:06:09
# [07/30 16:26:16 d2.evaluation.evaluator]: Inference done 1254/2845. 0.2269 s / img. ETA=0:06:04
# [07/30 16:26:21 d2.evaluation.evaluator]: Inference done 1276/2845. 0.2269 s / img. ETA=0:05:59
# [07/30 16:26:26 d2.evaluation.evaluator]: Inference done 1298/2845. 0.2269 s / img. ETA=0:05:54
# [07/30 16:26:31 d2.evaluation.evaluator]: Inference done 1321/2845. 0.2269 s / img. ETA=0:05:49
# [07/30 16:26:36 d2.evaluation.evaluator]: Inference done 1343/2845. 0.2269 s / img. ETA=0:05:44
# [07/30 16:26:41 d2.evaluation.evaluator]: Inference done 1365/2845. 0.2269 s / img. ETA=0:05:39
# [07/30 16:26:47 d2.evaluation.evaluator]: Inference done 1387/2845. 0.2269 s / img. ETA=0:05:34
# [07/30 16:26:52 d2.evaluation.evaluator]: Inference done 1409/2845. 0.2269 s / img. ETA=0:05:29
# [07/30 16:26:57 d2.evaluation.evaluator]: Inference done 1431/2845. 0.2269 s / img. ETA=0:05:24
# [07/30 16:27:02 d2.evaluation.evaluator]: Inference done 1453/2845. 0.2269 s / img. ETA=0:05:19
# [07/30 16:27:07 d2.evaluation.evaluator]: Inference done 1475/2845. 0.2269 s / img. ETA=0:05:14
# [07/30 16:27:12 d2.evaluation.evaluator]: Inference done 1497/2845. 0.2269 s / img. ETA=0:05:08
# [07/30 16:27:17 d2.evaluation.evaluator]: Inference done 1520/2845. 0.2269 s / img. ETA=0:05:03
# [07/30 16:27:22 d2.evaluation.evaluator]: Inference done 1543/2845. 0.2269 s / img. ETA=0:04:58
# [07/30 16:27:27 d2.evaluation.evaluator]: Inference done 1566/2845. 0.2268 s / img. ETA=0:04:52
# [07/30 16:27:32 d2.evaluation.evaluator]: Inference done 1588/2845. 0.2268 s / img. ETA=0:04:47
# [07/30 16:27:38 d2.evaluation.evaluator]: Inference done 1610/2845. 0.2268 s / img. ETA=0:04:42
# [07/30 16:27:43 d2.evaluation.evaluator]: Inference done 1633/2845. 0.2268 s / img. ETA=0:04:37
# [07/30 16:27:48 d2.evaluation.evaluator]: Inference done 1655/2845. 0.2268 s / img. ETA=0:04:32
# [07/30 16:27:53 d2.evaluation.evaluator]: Inference done 1677/2845. 0.2268 s / img. ETA=0:04:27
# [07/30 16:27:58 d2.evaluation.evaluator]: Inference done 1700/2845. 0.2268 s / img. ETA=0:04:22
# [07/30 16:28:03 d2.evaluation.evaluator]: Inference done 1722/2845. 0.2268 s / img. ETA=0:04:17
# [07/30 16:28:08 d2.evaluation.evaluator]: Inference done 1745/2845. 0.2267 s / img. ETA=0:04:11
# [07/30 16:28:13 d2.evaluation.evaluator]: Inference done 1767/2845. 0.2268 s / img. ETA=0:04:06
# [07/30 16:28:18 d2.evaluation.evaluator]: Inference done 1789/2845. 0.2268 s / img. ETA=0:04:01
# [07/30 16:28:24 d2.evaluation.evaluator]: Inference done 1811/2845. 0.2268 s / img. ETA=0:03:56
# [07/30 16:28:29 d2.evaluation.evaluator]: Inference done 1834/2845. 0.2268 s / img. ETA=0:03:51
# [07/30 16:28:34 d2.evaluation.evaluator]: Inference done 1856/2845. 0.2268 s / img. ETA=0:03:46
# [07/30 16:28:39 d2.evaluation.evaluator]: Inference done 1879/2845. 0.2267 s / img. ETA=0:03:41
# [07/30 16:28:44 d2.evaluation.evaluator]: Inference done 1901/2845. 0.2267 s / img. ETA=0:03:36
# [07/30 16:28:49 d2.evaluation.evaluator]: Inference done 1923/2845. 0.2267 s / img. ETA=0:03:31
# [07/30 16:28:54 d2.evaluation.evaluator]: Inference done 1945/2845. 0.2267 s / img. ETA=0:03:26
# [07/30 16:28:59 d2.evaluation.evaluator]: Inference done 1967/2845. 0.2267 s / img. ETA=0:03:21
# [07/30 16:29:04 d2.evaluation.evaluator]: Inference done 1989/2845. 0.2267 s / img. ETA=0:03:16
# [07/30 16:29:09 d2.evaluation.evaluator]: Inference done 2011/2845. 0.2267 s / img. ETA=0:03:10
# [07/30 16:29:14 d2.evaluation.evaluator]: Inference done 2033/2845. 0.2268 s / img. ETA=0:03:05
# [07/30 16:29:19 d2.evaluation.evaluator]: Inference done 2055/2845. 0.2267 s / img. ETA=0:03:00
# [07/30 16:29:24 d2.evaluation.evaluator]: Inference done 2077/2845. 0.2267 s / img. ETA=0:02:55
# [07/30 16:29:29 d2.evaluation.evaluator]: Inference done 2100/2845. 0.2267 s / img. ETA=0:02:50
# [07/30 16:29:35 d2.evaluation.evaluator]: Inference done 2122/2845. 0.2267 s / img. ETA=0:02:45
# [07/30 16:29:40 d2.evaluation.evaluator]: Inference done 2144/2845. 0.2267 s / img. ETA=0:02:40
# [07/30 16:29:45 d2.evaluation.evaluator]: Inference done 2166/2845. 0.2267 s / img. ETA=0:02:35
# [07/30 16:29:50 d2.evaluation.evaluator]: Inference done 2189/2845. 0.2266 s / img. ETA=0:02:30
# [07/30 16:29:55 d2.evaluation.evaluator]: Inference done 2211/2845. 0.2266 s / img. ETA=0:02:25
# [07/30 16:30:00 d2.evaluation.evaluator]: Inference done 2233/2845. 0.2266 s / img. ETA=0:02:20
# [07/30 16:30:05 d2.evaluation.evaluator]: Inference done 2256/2845. 0.2266 s / img. ETA=0:02:14
# [07/30 16:30:10 d2.evaluation.evaluator]: Inference done 2278/2845. 0.2266 s / img. ETA=0:02:09
# [07/30 16:30:15 d2.evaluation.evaluator]: Inference done 2300/2845. 0.2266 s / img. ETA=0:02:04
# [07/30 16:30:20 d2.evaluation.evaluator]: Inference done 2322/2845. 0.2267 s / img. ETA=0:01:59
# [07/30 16:30:25 d2.evaluation.evaluator]: Inference done 2344/2845. 0.2267 s / img. ETA=0:01:54
# [07/30 16:30:30 d2.evaluation.evaluator]: Inference done 2366/2845. 0.2266 s / img. ETA=0:01:49
# [07/30 16:30:35 d2.evaluation.evaluator]: Inference done 2388/2845. 0.2267 s / img. ETA=0:01:44
# [07/30 16:30:40 d2.evaluation.evaluator]: Inference done 2410/2845. 0.2267 s / img. ETA=0:01:39
# [07/30 16:30:45 d2.evaluation.evaluator]: Inference done 2432/2845. 0.2267 s / img. ETA=0:01:34
# [07/30 16:30:51 d2.evaluation.evaluator]: Inference done 2454/2845. 0.2267 s / img. ETA=0:01:29
# [07/30 16:30:56 d2.evaluation.evaluator]: Inference done 2476/2845. 0.2267 s / img. ETA=0:01:24
# [07/30 16:31:01 d2.evaluation.evaluator]: Inference done 2498/2845. 0.2267 s / img. ETA=0:01:19
# [07/30 16:31:06 d2.evaluation.evaluator]: Inference done 2520/2845. 0.2267 s / img. ETA=0:01:14
# [07/30 16:31:11 d2.evaluation.evaluator]: Inference done 2542/2845. 0.2267 s / img. ETA=0:01:09
# [07/30 16:31:16 d2.evaluation.evaluator]: Inference done 2564/2845. 0.2267 s / img. ETA=0:01:04
# [07/30 16:31:21 d2.evaluation.evaluator]: Inference done 2586/2845. 0.2267 s / img. ETA=0:00:59
# [07/30 16:31:26 d2.evaluation.evaluator]: Inference done 2608/2845. 0.2267 s / img. ETA=0:00:54
# [07/30 16:31:31 d2.evaluation.evaluator]: Inference done 2630/2845. 0.2267 s / img. ETA=0:00:49
# [07/30 16:31:36 d2.evaluation.evaluator]: Inference done 2652/2845. 0.2268 s / img. ETA=0:00:44
# [07/30 16:31:41 d2.evaluation.evaluator]: Inference done 2675/2845. 0.2267 s / img. ETA=0:00:38
# [07/30 16:31:46 d2.evaluation.evaluator]: Inference done 2697/2845. 0.2267 s / img. ETA=0:00:33
# [07/30 16:31:51 d2.evaluation.evaluator]: Inference done 2719/2845. 0.2267 s / img. ETA=0:00:28
# [07/30 16:31:57 d2.evaluation.evaluator]: Inference done 2742/2845. 0.2267 s / img. ETA=0:00:23
# [07/30 16:32:02 d2.evaluation.evaluator]: Inference done 2764/2845. 0.2267 s / img. ETA=0:00:18
# [07/30 16:32:07 d2.evaluation.evaluator]: Inference done 2786/2845. 0.2267 s / img. ETA=0:00:13
# [07/30 16:32:12 d2.evaluation.evaluator]: Inference done 2809/2845. 0.2267 s / img. ETA=0:00:08
# [07/30 16:32:17 d2.evaluation.evaluator]: Inference done 2831/2845. 0.2267 s / img. ETA=0:00:03
# [07/30 16:32:20 d2.evaluation.evaluator]: Total inference time: 0:10:50.314157 (0.228984 s / img per device, on 1 devices)
# [07/30 16:32:20 d2.evaluation.evaluator]: Total inference pure compute time: 0:10:43 (0.226682 s / img per device, on 1 devices)
# [07/30 16:32:20 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:32:20 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/R50_C4_270k/coco_instances_results.json
# [07/30 16:32:20 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.50 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.479
# [07/30 16:32:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 38.158 | 92.549 | 11.088 | 17.926 | 31.679 | 43.193 |
# [07/30 16:32:21 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/30 16:32:21 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_FDDB/R50_C4_270k/coco_instances_results.json
# [07/30 16:32:21 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.37 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.479
# [07/30 16:32:22 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 38.158 | 92.549 | 11.088 | 17.926 | 31.679 | 43.193 |

# %%
output_file_name = "AP_COCOEvaluator"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(AP_VAL, output_file)

# %% [markdown]
# Porównanie wyników

# %%
AP_FDDB = {}
for item in AP_VAL.keys():
  AP_FDDB[item] = AP_VAL[item]['bbox']

df_AP_FDDB = pd.DataFrame.from_dict(AP_FDDB, orient='index')

# %%
 df_AP_FDDB
# Out:
#                                AP       AP50  ...        APm        APl
# 800k                    19.019075  57.739784  ...  25.407776  17.908660
# BN_800k                 39.692626  89.397019  ...  32.746256  46.565123
# BN_Mish_V2_250+F_2_50k  37.604153  90.541335  ...  32.083840  42.632895
# BN_Mish_V3_80+_30k      39.490323  90.495200  ...  32.996425  46.237979
# R50_C4_270k             38.157942  92.548836  ...  31.679492  43.192683
#
# [5 rows x 6 columns]
