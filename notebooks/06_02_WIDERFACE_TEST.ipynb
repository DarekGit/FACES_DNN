# %% [markdown]
# <a href="https://colab.research.google.com/github/DarekGit/FACES_DNN/blob/master/notebooks/06_02_WIDERFACE_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [Spis treści](https://github.com/DarekGit/FACES_DNN/blob/master/notebooks/Praca_Dyplomowa.ipynb)

# %% [markdown]
# ## [6. Porównanie modeli](06_00_Porownanie.ipynb)

# %% [markdown]
# ### 6.2. Ewaluacja modeli na zbiorze walidacyjnym WIDER FACE

# %% [markdown]
# Instalacja Detectron2, pobranie datasetu i narzędzi

# %%
import os

os.makedirs('WIDER/', exist_ok=True)

# Download WIDER FACE VAL
# !gdown https://drive.google.com/uc?id=1-5A_pa_jDS7gk8mHVCBB7ApV5KN8jWDr -O WIDER/tempv.zip
# !unzip -q WIDER/tempv.zip -d WIDER
# !rm WIDER/tempv.zip  

# Download WIDER FACE test
# !gdown https://drive.google.com/uc?id=1tTpUJZEQMKDVxKT6100V5FwDuGX_8sDi -O WIDER/tempt.zip
# !unzip -q WIDER/tempt.zip -d WIDER
# !rm WIDER/tempt.zip

# Download face annotations (wider_face_split.zip)
# !wget mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/bbx_annotation/wider_face_split.zip -O WIDER/wider_face_split.zip
# !unzip -q WIDER/wider_face_split.zip -d WIDER
# !rm WIDER/wider_face_split.zip

### WIDER FACE - Examples and formats of the submissions
# !wget mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/example/Submission_example.zip -O WIDER/Submission_example.zip
# !unzip -q WIDER/Submission_example.zip -d WIDER
# !rm WIDER/Submission_example.zip

# eval_tools

# !wget shuoyang1213.me/WIDERFACE/support/eval_script/eval_tools.zip
# !unzip eval_tools.zip

# Download tools

# !gdown https://drive.google.com/uc?id=1_9ydMZlTNFXBOMl16xsU8FSBmK2PW4lN -O WIDER/tools.py
# !wget -q -O WIDER/mAP.py https://drive.google.com/uc?id=1PtEsobTFah3eiCDbSsYblOGbe2fmkjGR

# mobilenet
# !gdown https://drive.google.com/uc?id=1U0SVkSaSio4TBiXvF1QfTZI65WYpXpZ9
# !unzip -qo mobilenet.zip
# !rm -f mobilenet.zip

# install detectron2:

# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -q -e detectron2_repo

# %% [markdown]
# Restart runtime to continue...

# %%
# !nvidia-smi
from psutil import virtual_memory
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(virtual_memory().total / 1e9))
# Out:
# Thu Aug 20 20:43:54 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 27.4 gigabytes of available RAM

# %%
# !pip install facenet-pytorch
from facenet_pytorch import MTCNN

# %%
import time
from tqdm.notebook import tqdm
import torch, torchvision
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()


import gdown
from google.colab import drive
import os
import cv2
import random
import itertools
import shutil
import glob
import json
import numpy as np
import pandas as pd
from PIL import ImageDraw, Image
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib import collections as mc

from google.colab.patches import cv2_imshow

from detectron2 import model_zoo
import detectron2.utils.comm as comm
from detectron2.engine import DefaultPredictor, DefaultTrainer, HookBase
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_train_loader
from detectron2.structures import BoxMode
from detectron2.data import build_detection_test_loader
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

from mobilenet.utils import  add_mobilenet_config, build_mobilenetv2_fpn_backbone
from WIDER.mAP import mAP, plot_mAP
from WIDER.tools import annotations,output_Files

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %% [markdown]
# Zapis danych na Google drive

# %%
OUTPUT_DIR_NAME = "WIDERFACE_OUTPUT_DIR"
drive.mount('/content/drive')
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)
  print("\ncfg.OUTPUT_DIR =",OUTPUT_DIR_PATH) 
else: 
  print("\ncfg.OUTPUT_DIR =",OUTPUT_DIR_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# cfg.OUTPUT_DIR = ./drive/My Drive/WIDERFACE_OUTPUT_DIR

# %% [markdown]
# ## Modele do testu

# %% [markdown]
# MobileNetV2

# %%
models_mnv2 = {
    # '800k' - parametry domyślne - jako punkt odniesienia
    '800k': {
        'config': 'FrozenBN',
        'pth': 'https://drive.google.com/uc?id=1-tqNKwZIFmkAbfJ1L2sibIO4PT_MwnVA',
        'weights_name': 'model_0799999.pth'},

    # 'BN_800k' - dodano BN - pokazanie wpływu BN przy małym batchu=2
    'BN_800k': {
        'config': 'BN',
        'pth': 'https://drive.google.com/uc?id=1-kRDjqkMk9qXbNfzVx09VE35YzgkP1AO',
        'weights_name': 'model_0799999.pth'},

    #'BN_Mish_V2_250+F_2_50k' - najlepszy wynik uczenie z Mish BN 250k + 50k z FrozenBN
    'BN_Mish_V2_250+F_2_50k': {
        'config': 'BN_Mish_V2F',
        'pth': 'https://drive.google.com/uc?id=1-I6YSAs9NrORI4cFISfK_-4Yhm1twfDi',
        'weights_name': 'model_0049999.pth'},
    
    # 'BN_Mish_V3_80+30k' - najszybsze uczenie 110k iteracji
    'BN_Mish_V3_80+_30k': {
        'config': 'BN_Mish_V3',
        'pth': 'https://drive.google.com/uc?id=1--bP5VPyqIrfrBxVZ5eLSsupIvBlQ8ef',
        'weights_name': 'model_0029999.pth'},
    }

# %% [markdown]
# Faster R-CNN

# %%
faster_rcnn_model = {
    'faster_rcnn_R_50_FPN_3x' : {
        'config': 'https://drive.google.com/uc?id=173XKeFyCXK909QA652WpEhQ3imlyDFKX',
        'config_file' : "faster_rcnn_R_50_FPN_3x.yaml",
        'pth': 'https://drive.google.com/uc?id=1-XGz6HOqJQWmDCJiJDbBl-FnK7ZxZu5z',
        'weights_name': 'model_0269999.pth' 
    },
    'scratch_faster_rcnn_R_50_FPN_gn' : {
        'config': 'https://drive.google.com/uc?id=1-IX6Dshhs-rin7m1lGtTl1xNaUQXK3kN',
        'config_file' : "scratch_faster_rcnn_R_50_FPN_gn.yaml",
        'pth': 'https://drive.google.com/uc?id=1-dqOloknew4wN0cD5xcFhbRlrA8rSHGt',
        'weights_name': 'model_0539999.pth' 
    }
}

# %% [markdown]
# MTCNN

# %%
mtcnn = MTCNN(image_size=224, margin=0, keep_all=True, device=device)

# %% [markdown]
# ## Zestawy konfiguracji podstawowych dla modeli opartych na MobileNetV2

# %%
cfg_set = {
    'FrozenBN':'https://drive.google.com/uc?id=1rZFzJaR_g7uYuTguTdbUuCQYD4eXLeqw',
    'BN': 'https://drive.google.com/uc?id=1-doXtwe5iZHoqPzKGc2ZZbxj6Ebhxsn4',
    'BN_V2':'https://drive.google.com/uc?id=1wywB8UAaOO5KZx3IS35kV-rLsvJMIse6',
    'BN_Mish':'https://drive.google.com/uc?id=1-axV3KKg8-YiZZ7uDBh_2v181JoC9Nj3',
    'BN_Mish_V2':'https://drive.google.com/uc?id=1WoESx5RYvpapNicpSrmMoNJeE2GVm3zK',
    'BN_Mish_V3':'https://drive.google.com/uc?id=1-Kgd_2AS4EsD_ZPqP7SxkscyDjP-Qhnr',
    'BN_Mish_V2F':'https://drive.google.com/uc?id=1pCwyYCjIoduro2vIKMZi5HhlpaypH0_x',
    'R50_C4':'https://drive.google.com/uc?id=1-5P5Xyx5GM26p7g89CY-SSX0aluB7H9U',}

# %% [markdown]
# ## DefaultPredictor dla modeli opartych na MobileNetV2

# %%
def cfg_write(cfg,cfg_all):
  for key in cfg_all.keys():
    if isinstance(cfg_all[key],dict): 
      cfg_write(cfg[key],cfg_all[key])
    else: cfg[key]=cfg_all[key]
  return cfg

def set_predictor(model_name=None, models_dict=models_mnv2, cfg_dict=cfg_set ,device='cuda', cfg_DATASETS_TEST=None):
  url = models_dict[model_name]['pth'] 
  out = models_dict[model_name]['weights_name']
  gdown.download(url, out, True)
  # model configuration
  url_cfg = cfg_dict[models_dict[model_name]['config']] 
  gdown.download(url_cfg, "temporary.json", True)
  with open('temporary.json','r') as f:
    cfg_all=json.load(f)
  cfg = get_cfg()
  add_mobilenet_config(cfg)
  cfg = cfg_write(cfg,cfg_all)
  cfg.MODEL.WEIGHTS = models_dict[model_name]['weights_name']
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
  cfg.MODEL.DEVICE=device
  if cfg_DATASETS_TEST is not None:
    cfg.DATASETS.TEST = (cfg_DATASETS_TEST, )

  return DefaultPredictor(cfg), cfg

# %% [markdown]
# ## DefaultPredictor dla Faster-RCNN

# %%
def faster_predictor(model_name=None, models_dict=faster_rcnn_model, cfg_DATASETS_TEST=None):
  url = models_dict[model_name]['pth'] 
  out = models_dict[model_name]['weights_name']
  gdown.download(url, out, True)
  config = models_dict[model_name]['config']
  config_file = models_dict[model_name]['config_file']
  gdown.download(config, config_file, True)

  cfg = get_cfg()

  cfg.merge_from_file(config_file)
  cfg.MODEL.WEIGHTS = out
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
  cfg.MODEL.DEVICE='cuda'
  if cfg_DATASETS_TEST is not None:
    cfg.DATASETS.TEST = (cfg_DATASETS_TEST, )
  return DefaultPredictor(cfg), cfg

# %% [markdown]
# ## Funkcja pomiaru czasu ewaluacji modelu

# %%
def time_measurement(predictor, dataset):
  time_ = []
  for item in tqdm(dataset):
    start_ = time.time()
    img = cv2.imread(item["file_name"])
    if str(predictor) == "mtcnn":
      outputs = mtcnn.detect(img)
    else :
      outputs = predictor(img)
    diff = time.time() - start_
    time_.append(diff)
  # Total time
  total_time = np.array(time_).sum()
  # Mean time
  mean_diff = np.array(time_).mean()
  # Frames per second 
  fps = 1 / mean_diff
  print("Total time(sec): {:.2f}, Average(sec):{:.2f}, fps:{:.2f}\n".format(total_time, mean_diff, fps))
  return {"total_time": total_time, "mean_diff": mean_diff, "fps": fps}

# %% [markdown]
# ## Funkcja do ewaluacji modelu na zbiorze walidacyjnym WIDER FACE

# %%
def predict_on_val(dataset, predictor, model_name):
    gbxs=[]
    dbxs=[]
    dset=dataset
    if 'annotations' in dataset[0].keys():  
      dset=[]
      for r in dataset:
        dset.append({'path' : r['file_name'],'marks' : [b['bbox'] for b in r['annotations']],
                     'persons': ['' for b in r['annotations']]})

    for item in tqdm(dset):
        im = cv2.imread(item["path"])
        outputs = predictor(im)
        pbxs = outputs['instances'].pred_boxes.tensor.tolist()
        pconfs = outputs['instances'].scores.tolist()
        dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
        dbxs.append(dbx)
        gbxs.append(item['marks'])
    
    return {'gbxs':gbxs,'dbxs':dbxs,'metric':dset}

# %% [markdown]
# ## Funkcja do ewaluacji MTCNN na zbiorze walidacyjnym

# %%
def mtcnn_detect(dataset, model, model_name = "MTCNN"):
    gbxs=[]
    dbxs=[]
    dset=dataset
    if 'annotations' in dataset[0].keys():  
      dset=[]
      for r in dataset:
        dset.append({'path' : r['file_name'],'marks' : [b['bbox'] for b in r['annotations']],
                     'persons': ['' for b in r['annotations']]})

    for item in tqdm(dset):
        im = cv2.imread(item["path"])
        pbxs, pconfs  = model.detect(im)

        if type(pbxs)!=np.ndarray: 
          pbxs=[]
          pconfs=[]

        dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
        dbxs.append(dbx)
        gbxs.append(item['marks'])
    
    return {'gbxs':gbxs,'dbxs':dbxs,'metric':dset}

# %% [markdown]
# ## Funkcje do ewaluacji modelu na zbiorze testowym WIDER FACE i umożliwiające zapis wyników do pliku

# %%
def read_wider_face_test_filelist(path='WIDER/wider_face_split/'):
  full_path = path+"wider_face_test_filelist.txt"
  if os.path.exists(full_path):
    test_files = []
    with open(full_path, 'r') as f:
      for row in f:
        test_files.append(row.split('\n')[0])
    return test_files

# %%
def predict_on_test(file_list, predictor, model_name, path="WIDER/WIDER_test/images/"):
  output_list = []
  for item in tqdm(file_list):
    if os.path.exists(path+item):
      record = {}
      img = cv2.imread(path+item)
      outputs = predictor(img)
      pbxs = outputs['instances'].pred_boxes.tensor.tolist()
      pconfs = outputs['instances'].scores.tolist()
      dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
      record['file_name'] = item
      record['faces'] = len(dbx)
      record["bbox"] = dbx
    output_list.append(record)
  return output_list

# %%
def save_predictions_to_files(preds, model_name, wider_path = 'WIDER/WIDER_test/'):
  """The function saves the results as shown in the example 
  mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/example/Submission_example.zip
  """
  if not os.path.isdir(wider_path+model_name): # 
    os.makedirs(wider_path+model_name)
  for item in tqdm(preds):
    subdirectory = os.path.split(item["file_name"])[0]
    if not os.path.isdir(wider_path+model_name+"/"+subdirectory):
      os.makedirs(wider_path+model_name+"/"+subdirectory)
    output_file = os.path.split(item["file_name"])[1][:-4]
    output_file = wider_path+model_name+"/"+subdirectory+"/"+output_file
    with open(output_file + '.txt', 'w') as f:
      f.write(output_file + os.linesep)
      f.write(str(item["faces"]) + os.linesep)
      for row in item['bbox']:
        row[-1] = round(row[-1],3)
        f.write(" ".join([str(i) for i in row]) + os.linesep)

# %%
def dict_to_file(dic, path):
    f = open(path,'w')
    f.write(str(dic))
    f.close()

def dict_from_file(filename):
    f = open(filename,'r')
    data=f.read()
    f.close()
    return eval(data)

# %% [markdown]
# ## Pomiar czasu interferencji modeli na zbiorze walidacyjnym

# %%
WIDERFACE_VAL = annotations('val')

# %%
time_measurement_results = {}
for model in models_mnv2:
  print(model)
  predictor, _ = set_predictor(model)
  time_measurement_results[model] = time_measurement(predictor, dataset=WIDERFACE_VAL)

print(time_measurement_results)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 248.57, Average(sec):0.08, fps:12.98
#
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 244.90, Average(sec):0.08, fps:13.17
#
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 314.01, Average(sec):0.10, fps:10.27
#
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 311.97, Average(sec):0.10, fps:10.34
#
# {'800k': {'total_time': 248.56552147865295, 'mean_diff': 0.07705068861706539, 'fps': 12.978469342044496}, 'BN_800k': {'total_time': 244.89701414108276, 'mean_diff': 0.0759135195725613, 'fps': 13.172884166491034}, 'BN_Mish_V2_250+F_2_50k': {'total_time': 314.00685453414917, 'mean_diff': 0.09733628472850253, 'fps': 10.27366107910604}, 'BN_Mish_V3_80+_30k': {'total_time': 311.9675250053406, 'mean_diff': 0.09670413050382536, 'fps': 10.340819929717922}}

# %%
for model in faster_rcnn_model:
  print(model)
  predictor, _ = faster_predictor(model)
  time_measurement_results[model] = time_measurement(predictor, dataset=WIDERFACE_VAL)
# Out:
# faster_rcnn_R_50_FPN_3x
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 307.45, Average(sec):0.10, fps:10.49
#
# scratch_faster_rcnn_R_50_FPN_gn
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 332.27, Average(sec):0.10, fps:9.71

# %%
time_measurement_results["MTCNN"] = time_measurement(mtcnn, dataset=WIDERFACE_VAL)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 329.38, Average(sec):0.10, fps:9.79

# %%
time_measurement_results
# Out:
# {'800k': {'fps': 12.978469342044496,
#   'mean_diff': 0.07705068861706539,
#   'total_time': 248.56552147865295},
#  'BN_800k': {'fps': 13.172884166491034,
#   'mean_diff': 0.0759135195725613,
#   'total_time': 244.89701414108276},
#  'BN_Mish_V2_250+F_2_50k': {'fps': 10.27366107910604,
#   'mean_diff': 0.09733628472850253,
#   'total_time': 314.00685453414917},
#  'BN_Mish_V3_80+_30k': {'fps': 10.340819929717922,
#   'mean_diff': 0.09670413050382536,
#   'total_time': 311.9675250053406},
#  'MTCNN': {'fps': 9.794156230663534,
#   'mean_diff': 0.10210169987580973,
#   'total_time': 329.3800837993622},
#  'faster_rcnn_R_50_FPN_3x': {'fps': 10.492657361001115,
#   'mean_diff': 0.09530474174414373,
#   'total_time': 307.45309686660767},
#  'scratch_faster_rcnn_R_50_FPN_gn': {'fps': 9.708874541128022,
#   'mean_diff': 0.10299855001358534,
#   'total_time': 332.2733223438263}}

# %% [markdown]
# Porównanie wyników

# %%
df_time_measurement_results = pd.DataFrame.from_dict(time_measurement_results, orient='index').sort_values(by=['total_time'])
df_time_measurement_results
# Out:
#                                  total_time  mean_diff        fps
# BN_800k                          244.897014   0.075914  13.172884
# 800k                             248.565521   0.077051  12.978469
# faster_rcnn_R_50_FPN_3x          307.453097   0.095305  10.492657
# BN_Mish_V3_80+_30k               311.967525   0.096704  10.340820
# BN_Mish_V2_250+F_2_50k           314.006855   0.097336  10.273661
# MTCNN                            329.380084   0.102102   9.794156
# scratch_faster_rcnn_R_50_FPN_gn  332.273322   0.102999   9.708875

# %% [markdown]
# Zapis wyników

# %%
time_measurement_results = df_time_measurement_results.to_json(orient="table")

output_file_name = "time_measurement_results.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(time_measurement_results, f, indent=4)

# %% [markdown]
# ## Ewaluacja modeli na zbiorze walidacyjnym i mAP liczone funkcją Darka

# %%
WIDERFACE_VAL = annotations('val')

# %%
pred = {}
for model in models_mnv2:
  print(model)
  predictor, cfg = set_predictor(model)
  pred[model] = predict_on_val(WIDERFACE_VAL ,predictor, model)
  # save to Google drive 
  output_file_name = f"unified_mAP_{model}"
  output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
  dict_to_file(pred[model], output_file)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %%
for model in faster_rcnn_model:
  print(model)
  predictor, cfg = faster_predictor(model)
  pred[model] = predict_on_val(WIDERFACE_VAL ,predictor, model)
    
  # save to Google drive 
  output_file_name = f"unified_mAP_{model}"
  output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
  dict_to_file(pred[model], output_file)
# Out:
# faster_rcnn_R_50_FPN_3x
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# scratch_faster_rcnn_R_50_FPN_gn
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %%
model = "MTCNN"
pred[model] = mtcnn_detect(WIDERFACE_VAL , mtcnn , model)
output_file_name = f"unified_mAP_{model}"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(pred[model], output_file)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %% [markdown]
# ## Wykresy mAP dla testowanych modeli

# %%
def model_mAP(pdict, model_name, title=""):
  m, d = mAP(gbxs=pdict[model_name]['gbxs'], dbxs=pdict[model_name]['dbxs'], data=True)
  output_file_name = f"unified_mAP_{title}_{model_name}"
  plot_mAP(m,d,['All 0.50','mAP','large','medium','small'],1,title+model_name,file=f"unified_mAP_{title}_{model_name}")
  return m,d

# %%
all_models_mAP = {}
pred.keys()
# Out:
# dict_keys(['800k', 'BN_800k', 'BN_Mish_V2_250+F_2_50k', 'BN_Mish_V3_80+_30k', 'faster_rcnn_R_50_FPN_3x', 'scratch_faster_rcnn_R_50_FPN_gn', 'MTCNN'])

# %% [markdown]
# ## Model: 800k

# %%
modelshow = list(pred.keys())[0]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: 800k
# All 0.50:   AP: 43.35%   Recall: 45.21%   IoU: 0.5
# large   :   AP: 68.67%   Recall: 70.94%   IoU: 0.5
# medium  :   AP: 74.95%   Recall: 76.37%   IoU: 0.5
# small   :   AP: 31.04%   Recall: 33.19%   IoU: 0.5
# mAP     :   AP: 23.83%   Recall: 26.97%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_800k

# %%
modelshow = list(pred.keys())[1]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_800k
# All 0.50:   AP: 50.31%   Recall: 51.33%   IoU: 0.5
# large   :   AP: 90.83%   Recall: 91.30%   IoU: 0.5
# medium  :   AP: 83.83%   Recall: 84.47%   IoU: 0.5
# small   :   AP: 36.10%   Recall: 37.50%   IoU: 0.5
# mAP     :   AP: 28.49%   Recall: 31.47%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_Mish_V2_250+F_2_50k

# %%
modelshow = list(pred.keys())[2]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_Mish_V2_250+F_2_50k
# All 0.50:   AP: 55.34%   Recall: 56.37%   IoU: 0.5
# large   :   AP: 93.72%   Recall: 93.98%   IoU: 0.5
# medium  :   AP: 87.79%   Recall: 88.30%   IoU: 0.5
# small   :   AP: 41.59%   Recall: 43.11%   IoU: 0.5
# mAP     :   AP: 31.21%   Recall: 34.48%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_Mish_V3_80+_30k

# %%
modelshow = list(pred.keys())[3]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_Mish_V3_80+_30k
# All 0.50:   AP: 52.61%   Recall: 53.39%   IoU: 0.5
# large   :   AP: 92.25%   Recall: 92.53%   IoU: 0.5
# medium  :   AP: 85.83%   Recall: 86.27%   IoU: 0.5
# small   :   AP: 38.57%   Recall: 39.71%   IoU: 0.5
# mAP     :   AP: 29.95%   Recall: 33.14%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: faster_rcnn_R_50_FPN_3x

# %%
modelshow = list(pred.keys())[4]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: faster_rcnn_R_50_FPN_3x
# All 0.50:   AP: 50.92%   Recall: 52.26%   IoU: 0.5
# large   :   AP: 95.18%   Recall: 95.42%   IoU: 0.5
# medium  :   AP: 87.23%   Recall: 87.79%   IoU: 0.5
# small   :   AP: 35.15%   Recall: 37.40%   IoU: 0.5
# mAP     :   AP: 28.73%   Recall: 31.90%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: scratch_faster_rcnn_R_50_FPN_gn

# %%
modelshow = list(pred.keys())[5]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: scratch_faster_rcnn_R_50_FPN_gn
# All 0.50:   AP: 58.03%   Recall: 59.27%   IoU: 0.5
# large   :   AP: 92.46%   Recall: 92.87%   IoU: 0.5
# medium  :   AP: 87.53%   Recall: 88.17%   IoU: 0.5
# small   :   AP: 45.43%   Recall: 47.31%   IoU: 0.5
# mAP     :   AP: 32.45%   Recall: 36.76%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: MTCNN

# %%
modelshow = list(pred.keys())[6]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: MTCNN
# All 0.50:   AP: 22.86%   Recall: 23.11%   IoU: 0.5
# large   :   AP: 61.74%   Recall: 62.11%   IoU: 0.5
# medium  :   AP: 51.87%   Recall: 52.18%   IoU: 0.5
# small   :   AP: 10.38%   Recall: 10.64%   IoU: 0.5
# mAP     :   AP: 13.33%   Recall: 15.03%   IoU: 0.5 - 0.95

# %%
# !mv unified_mAP*.png ./drive/'My Drive'/WIDERFACE_OUTPUT_DIR/

# %% [markdown]
# Zapis wyników

# %%
output_file_name = "all_models_mAP"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(all_models_mAP, output_file)

# %%
modeldict = {}
DD_mAP = {}

for item in all_models_mAP.keys():
  for i in all_models_mAP[item][0].keys():
    modeldict[i] =  {
        "AP" : all_models_mAP[item][0][i][0],
        "Recall" : all_models_mAP[item][0][i][1],
        "IoU" : all_models_mAP[item][0][i][2],
    }
  DD_mAP[item] = modeldict

# %%
output_file_name = "DD_mAP_all_models"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(DD_mAP, output_file)

# %%
from collections import OrderedDict

DD_mAP2 = OrderedDict()

for item in all_models_mAP.keys():
  DD_mAP2[item] = ({i:all_models_mAP[item][0][i][0] for i in ['mAP', 'All 0.50','large','medium','small']})

df_unified_mAP = pd.DataFrame.from_dict(DD_mAP2, orient='index').sort_values(by=['All 0.50'], ascending=False)
df_unified_mAP
# Out:
#                                       mAP  All 0.50  ...    medium     small
# scratch_faster_rcnn_R_50_FPN_gn  0.324501  0.580318  ...  0.875298  0.454291
# BN_Mish_V2_250+F_2_50k           0.312105  0.553373  ...  0.877947  0.415864
# BN_Mish_V3_80+_30k               0.299488  0.526117  ...  0.858282  0.385726
# faster_rcnn_R_50_FPN_3x          0.287271  0.509173  ...  0.872292  0.351544
# BN_800k                          0.284875  0.503125  ...  0.838339  0.361031
# 800k                             0.238252  0.433512  ...  0.749513  0.310390
# MTCNN                            0.133329  0.228585  ...  0.518723  0.103795
#
# [7 rows x 5 columns]

# %%
df_unified_mAP_results = df_unified_mAP.to_json(orient="table")

output_file_name = "unified_mAP_dataframe.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(df_unified_mAP_results, f, indent=4)

# %%
with open(output_file) as data_file:
    data_loaded = json.load(data_file)
pd.read_json(data_loaded, orient="table" )
# Out:
#                                       mAP  All 0.50  ...    medium     small
# scratch_faster_rcnn_R_50_FPN_gn  0.324501  0.580318  ...  0.875298  0.454291
# BN_Mish_V2_250+F_2_50k           0.312105  0.553373  ...  0.877947  0.415864
# BN_Mish_V3_80+_30k               0.299488  0.526117  ...  0.858282  0.385726
# faster_rcnn_R_50_FPN_3x          0.287271  0.509173  ...  0.872292  0.351544
# BN_800k                          0.284875  0.503125  ...  0.838339  0.361031
# 800k                             0.238252  0.433512  ...  0.749513  0.310390
# MTCNN                            0.133329  0.228585  ...  0.518723  0.103795
#
# [7 rows x 5 columns]

# %% [markdown]
# # Ewaluacja na WIDER FACE z wykorzystaniem COCOEvaluator i inference_on_dataset

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# %%
val = annotations('val')
test = annotations('test')

# %%
for d in ["test", "val"]:
  DatasetCatalog.register("face_" + d, lambda d=d: test if d == "test" else val)
  MetadataCatalog.get("face_" + d).set(thing_classes = ['face'])

faces_metadata = MetadataCatalog.get("face_test")

# %%
dataset_dicts = annotations('val')
for d in random.sample(dataset_dicts, 1):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=faces_metadata, scale=0.9)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=921x628 at 0x7F3C27AD3358>

# %%
AP_VAL = {}
drive.mount('/content/drive')
OUTPUT_DIR_NAME = "OUTPUT_DIR_VAL"
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)

for model in models_mnv2:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = set_predictor(model, cfg_DATASETS_TEST="face_val")
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator)
  AP_VAL[model] = evaluator.evaluate()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 800k
# ./drive/My Drive/OUTPUT_DIR_VAL/800k
# [08/20 22:40:30 d2.evaluation.coco_evaluation]: 'face_val' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# WARNING [08/20 22:40:31 d2.data.datasets.coco]: Using previously cached COCO format annotations at './drive/My Drive/OUTPUT_DIR_VAL/800k/face_val_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [08/20 22:40:31 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    face    | 39708        |
# |            |              |
# [08/20 22:40:31 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:40:31 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:40:31 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:40:31 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:40:32 d2.evaluation.evaluator]: Inference done 11/3226. 0.0456 s / img. ETA=0:02:30
# [08/20 22:40:37 d2.evaluation.evaluator]: Inference done 121/3226. 0.0445 s / img. ETA=0:02:22
# [08/20 22:40:42 d2.evaluation.evaluator]: Inference done 229/3226. 0.0448 s / img. ETA=0:02:18
# [08/20 22:40:47 d2.evaluation.evaluator]: Inference done 337/3226. 0.0449 s / img. ETA=0:02:13
# [08/20 22:40:52 d2.evaluation.evaluator]: Inference done 445/3226. 0.0450 s / img. ETA=0:02:09
# [08/20 22:40:57 d2.evaluation.evaluator]: Inference done 553/3226. 0.0450 s / img. ETA=0:02:04
# [08/20 22:41:02 d2.evaluation.evaluator]: Inference done 660/3226. 0.0451 s / img. ETA=0:01:59
# [08/20 22:41:07 d2.evaluation.evaluator]: Inference done 769/3226. 0.0450 s / img. ETA=0:01:54
# [08/20 22:41:12 d2.evaluation.evaluator]: Inference done 877/3226. 0.0450 s / img. ETA=0:01:49
# [08/20 22:41:17 d2.evaluation.evaluator]: Inference done 985/3226. 0.0450 s / img. ETA=0:01:44
# [08/20 22:41:22 d2.evaluation.evaluator]: Inference done 1094/3226. 0.0450 s / img. ETA=0:01:38
# [08/20 22:41:27 d2.evaluation.evaluator]: Inference done 1202/3226. 0.0450 s / img. ETA=0:01:33
# [08/20 22:41:32 d2.evaluation.evaluator]: Inference done 1310/3226. 0.0450 s / img. ETA=0:01:28
# [08/20 22:41:37 d2.evaluation.evaluator]: Inference done 1418/3226. 0.0450 s / img. ETA=0:01:23
# [08/20 22:41:42 d2.evaluation.evaluator]: Inference done 1529/3226. 0.0449 s / img. ETA=0:01:18
# [08/20 22:41:47 d2.evaluation.evaluator]: Inference done 1638/3226. 0.0449 s / img. ETA=0:01:13
# [08/20 22:41:52 d2.evaluation.evaluator]: Inference done 1745/3226. 0.0449 s / img. ETA=0:01:08
# [08/20 22:41:57 d2.evaluation.evaluator]: Inference done 1853/3226. 0.0449 s / img. ETA=0:01:03
# [08/20 22:42:02 d2.evaluation.evaluator]: Inference done 1962/3226. 0.0449 s / img. ETA=0:00:58
# [08/20 22:42:07 d2.evaluation.evaluator]: Inference done 2069/3226. 0.0449 s / img. ETA=0:00:53
# [08/20 22:42:12 d2.evaluation.evaluator]: Inference done 2177/3226. 0.0449 s / img. ETA=0:00:48
# [08/20 22:42:17 d2.evaluation.evaluator]: Inference done 2286/3226. 0.0449 s / img. ETA=0:00:43
# [08/20 22:42:23 d2.evaluation.evaluator]: Inference done 2393/3226. 0.0449 s / img. ETA=0:00:38
# [08/20 22:42:28 d2.evaluation.evaluator]: Inference done 2500/3226. 0.0449 s / img. ETA=0:00:33
# [08/20 22:42:33 d2.evaluation.evaluator]: Inference done 2608/3226. 0.0449 s / img. ETA=0:00:28
# [08/20 22:42:38 d2.evaluation.evaluator]: Inference done 2716/3226. 0.0450 s / img. ETA=0:00:23
# [08/20 22:42:43 d2.evaluation.evaluator]: Inference done 2825/3226. 0.0449 s / img. ETA=0:00:18
# [08/20 22:42:48 d2.evaluation.evaluator]: Inference done 2933/3226. 0.0449 s / img. ETA=0:00:13
# [08/20 22:42:53 d2.evaluation.evaluator]: Inference done 3039/3226. 0.0449 s / img. ETA=0:00:08
# [08/20 22:42:58 d2.evaluation.evaluator]: Inference done 3147/3226. 0.0449 s / img. ETA=0:00:03
# [08/20 22:43:01 d2.evaluation.evaluator]: Total inference time: 0:02:29.699876 (0.046476 s / img per device, on 1 devices)
# [08/20 22:43:01 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:24 (0.044968 s / img per device, on 1 devices)
# [08/20 22:43:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:43:02 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/800k/coco_instances_results.json
# [08/20 22:43:03 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.77 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# [08/20 22:43:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 23.101 | 42.814 | 22.892 | 14.973 | 45.492 | 40.228 |
# [08/20 22:43:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:43:04 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/800k/coco_instances_results.json
# [08/20 22:43:04 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.70 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# [08/20 22:43:05 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 23.101 | 42.814 | 22.892 | 14.973 | 45.492 | 40.228 |
# BN_800k
# ./drive/My Drive/OUTPUT_DIR_VAL/BN_800k
# [08/20 22:43:09 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:43:09 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:43:09 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:43:09 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:43:10 d2.evaluation.evaluator]: Inference done 11/3226. 0.0454 s / img. ETA=0:02:29
# [08/20 22:43:15 d2.evaluation.evaluator]: Inference done 119/3226. 0.0449 s / img. ETA=0:02:23
# [08/20 22:43:20 d2.evaluation.evaluator]: Inference done 226/3226. 0.0452 s / img. ETA=0:02:20
# [08/20 22:43:25 d2.evaluation.evaluator]: Inference done 333/3226. 0.0453 s / img. ETA=0:02:15
# [08/20 22:43:30 d2.evaluation.evaluator]: Inference done 440/3226. 0.0454 s / img. ETA=0:02:10
# [08/20 22:43:35 d2.evaluation.evaluator]: Inference done 547/3226. 0.0454 s / img. ETA=0:02:05
# [08/20 22:43:40 d2.evaluation.evaluator]: Inference done 653/3226. 0.0454 s / img. ETA=0:02:00
# [08/20 22:43:45 d2.evaluation.evaluator]: Inference done 762/3226. 0.0454 s / img. ETA=0:01:55
# [08/20 22:43:50 d2.evaluation.evaluator]: Inference done 868/3226. 0.0454 s / img. ETA=0:01:50
# [08/20 22:43:55 d2.evaluation.evaluator]: Inference done 975/3226. 0.0454 s / img. ETA=0:01:45
# [08/20 22:44:00 d2.evaluation.evaluator]: Inference done 1083/3226. 0.0454 s / img. ETA=0:01:40
# [08/20 22:44:05 d2.evaluation.evaluator]: Inference done 1191/3226. 0.0454 s / img. ETA=0:01:35
# [08/20 22:44:10 d2.evaluation.evaluator]: Inference done 1298/3226. 0.0454 s / img. ETA=0:01:30
# [08/20 22:44:15 d2.evaluation.evaluator]: Inference done 1405/3226. 0.0454 s / img. ETA=0:01:25
# [08/20 22:44:20 d2.evaluation.evaluator]: Inference done 1516/3226. 0.0452 s / img. ETA=0:01:19
# [08/20 22:44:25 d2.evaluation.evaluator]: Inference done 1625/3226. 0.0452 s / img. ETA=0:01:14
# [08/20 22:44:30 d2.evaluation.evaluator]: Inference done 1732/3226. 0.0452 s / img. ETA=0:01:09
# [08/20 22:44:35 d2.evaluation.evaluator]: Inference done 1839/3226. 0.0452 s / img. ETA=0:01:04
# [08/20 22:44:40 d2.evaluation.evaluator]: Inference done 1947/3226. 0.0452 s / img. ETA=0:00:59
# [08/20 22:44:45 d2.evaluation.evaluator]: Inference done 2053/3226. 0.0452 s / img. ETA=0:00:54
# [08/20 22:44:50 d2.evaluation.evaluator]: Inference done 2161/3226. 0.0452 s / img. ETA=0:00:49
# [08/20 22:44:55 d2.evaluation.evaluator]: Inference done 2269/3226. 0.0452 s / img. ETA=0:00:44
# [08/20 22:45:00 d2.evaluation.evaluator]: Inference done 2376/3226. 0.0453 s / img. ETA=0:00:39
# [08/20 22:45:05 d2.evaluation.evaluator]: Inference done 2483/3226. 0.0453 s / img. ETA=0:00:34
# [08/20 22:45:10 d2.evaluation.evaluator]: Inference done 2589/3226. 0.0453 s / img. ETA=0:00:29
# [08/20 22:45:15 d2.evaluation.evaluator]: Inference done 2696/3226. 0.0453 s / img. ETA=0:00:24
# [08/20 22:45:20 d2.evaluation.evaluator]: Inference done 2804/3226. 0.0453 s / img. ETA=0:00:19
# [08/20 22:45:26 d2.evaluation.evaluator]: Inference done 2912/3226. 0.0453 s / img. ETA=0:00:14
# [08/20 22:45:31 d2.evaluation.evaluator]: Inference done 3017/3226. 0.0453 s / img. ETA=0:00:09
# [08/20 22:45:36 d2.evaluation.evaluator]: Inference done 3125/3226. 0.0453 s / img. ETA=0:00:04
# [08/20 22:45:40 d2.evaluation.evaluator]: Total inference time: 0:02:30.822333 (0.046825 s / img per device, on 1 devices)
# [08/20 22:45:40 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:25 (0.045306 s / img per device, on 1 devices)
# [08/20 22:45:41 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:45:41 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_800k/coco_instances_results.json
# [08/20 22:45:42 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.75 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.08 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.649
# [08/20 22:45:43 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.766 | 49.522 | 28.706 | 17.278 | 52.528 | 60.480 |
# [08/20 22:45:43 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:45:43 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_800k/coco_instances_results.json
# [08/20 22:45:44 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.73 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.08 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.649
# [08/20 22:45:45 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.766 | 49.522 | 28.706 | 17.278 | 52.528 | 60.480 |
# BN_Mish_V2_250+F_2_50k
# ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V2_250+F_2_50k
# [08/20 22:45:49 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:45:49 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:45:49 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:45:49 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:45:50 d2.evaluation.evaluator]: Inference done 11/3226. 0.0499 s / img. ETA=0:02:43
# [08/20 22:45:55 d2.evaluation.evaluator]: Inference done 111/3226. 0.0491 s / img. ETA=0:02:37
# [08/20 22:46:00 d2.evaluation.evaluator]: Inference done 209/3226. 0.0494 s / img. ETA=0:02:33
# [08/20 22:46:05 d2.evaluation.evaluator]: Inference done 306/3226. 0.0497 s / img. ETA=0:02:29
# [08/20 22:46:10 d2.evaluation.evaluator]: Inference done 405/3226. 0.0496 s / img. ETA=0:02:23
# [08/20 22:46:15 d2.evaluation.evaluator]: Inference done 504/3226. 0.0496 s / img. ETA=0:02:18
# [08/20 22:46:20 d2.evaluation.evaluator]: Inference done 602/3226. 0.0496 s / img. ETA=0:02:13
# [08/20 22:46:25 d2.evaluation.evaluator]: Inference done 701/3226. 0.0496 s / img. ETA=0:02:08
# [08/20 22:46:30 d2.evaluation.evaluator]: Inference done 800/3226. 0.0495 s / img. ETA=0:02:03
# [08/20 22:46:35 d2.evaluation.evaluator]: Inference done 897/3226. 0.0496 s / img. ETA=0:01:58
# [08/20 22:46:40 d2.evaluation.evaluator]: Inference done 996/3226. 0.0496 s / img. ETA=0:01:53
# [08/20 22:46:45 d2.evaluation.evaluator]: Inference done 1096/3226. 0.0495 s / img. ETA=0:01:48
# [08/20 22:46:50 d2.evaluation.evaluator]: Inference done 1195/3226. 0.0495 s / img. ETA=0:01:43
# [08/20 22:46:55 d2.evaluation.evaluator]: Inference done 1294/3226. 0.0495 s / img. ETA=0:01:38
# [08/20 22:47:00 d2.evaluation.evaluator]: Inference done 1392/3226. 0.0495 s / img. ETA=0:01:33
# [08/20 22:47:05 d2.evaluation.evaluator]: Inference done 1493/3226. 0.0494 s / img. ETA=0:01:28
# [08/20 22:47:10 d2.evaluation.evaluator]: Inference done 1594/3226. 0.0494 s / img. ETA=0:01:22
# [08/20 22:47:15 d2.evaluation.evaluator]: Inference done 1693/3226. 0.0494 s / img. ETA=0:01:17
# [08/20 22:47:20 d2.evaluation.evaluator]: Inference done 1792/3226. 0.0494 s / img. ETA=0:01:12
# [08/20 22:47:25 d2.evaluation.evaluator]: Inference done 1891/3226. 0.0494 s / img. ETA=0:01:07
# [08/20 22:47:30 d2.evaluation.evaluator]: Inference done 1990/3226. 0.0494 s / img. ETA=0:01:02
# [08/20 22:47:35 d2.evaluation.evaluator]: Inference done 2087/3226. 0.0494 s / img. ETA=0:00:57
# [08/20 22:47:40 d2.evaluation.evaluator]: Inference done 2186/3226. 0.0494 s / img. ETA=0:00:52
# [08/20 22:47:45 d2.evaluation.evaluator]: Inference done 2285/3226. 0.0494 s / img. ETA=0:00:47
# [08/20 22:47:50 d2.evaluation.evaluator]: Inference done 2382/3226. 0.0494 s / img. ETA=0:00:42
# [08/20 22:47:55 d2.evaluation.evaluator]: Inference done 2480/3226. 0.0494 s / img. ETA=0:00:37
# [08/20 22:48:00 d2.evaluation.evaluator]: Inference done 2580/3226. 0.0494 s / img. ETA=0:00:32
# [08/20 22:48:05 d2.evaluation.evaluator]: Inference done 2678/3226. 0.0494 s / img. ETA=0:00:27
# [08/20 22:48:10 d2.evaluation.evaluator]: Inference done 2777/3226. 0.0494 s / img. ETA=0:00:22
# [08/20 22:48:15 d2.evaluation.evaluator]: Inference done 2877/3226. 0.0494 s / img. ETA=0:00:17
# [08/20 22:48:20 d2.evaluation.evaluator]: Inference done 2975/3226. 0.0494 s / img. ETA=0:00:12
# [08/20 22:48:25 d2.evaluation.evaluator]: Inference done 3074/3226. 0.0494 s / img. ETA=0:00:07
# [08/20 22:48:30 d2.evaluation.evaluator]: Inference done 3171/3226. 0.0494 s / img. ETA=0:00:02
# [08/20 22:48:33 d2.evaluation.evaluator]: Total inference time: 0:02:43.843014 (0.050867 s / img per device, on 1 devices)
# [08/20 22:48:33 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:39 (0.049451 s / img per device, on 1 devices)
# [08/20 22:48:34 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:48:34 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [08/20 22:48:35 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.80 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.680
# [08/20 22:48:36 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 30.203 | 54.446 | 31.129 | 19.484 | 55.289 | 63.486 |
# [08/20 22:48:36 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:48:36 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [08/20 22:48:36 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.79 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.680
# [08/20 22:48:37 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 30.203 | 54.446 | 31.129 | 19.484 | 55.289 | 63.486 |
# BN_Mish_V3_80+_30k
# ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V3_80+_30k
# [08/20 22:48:40 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:48:40 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:48:40 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:48:40 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:48:41 d2.evaluation.evaluator]: Inference done 11/3226. 0.0502 s / img. ETA=0:02:44
# [08/20 22:48:46 d2.evaluation.evaluator]: Inference done 111/3226. 0.0489 s / img. ETA=0:02:36
# [08/20 22:48:51 d2.evaluation.evaluator]: Inference done 209/3226. 0.0493 s / img. ETA=0:02:32
# [08/20 22:48:56 d2.evaluation.evaluator]: Inference done 307/3226. 0.0496 s / img. ETA=0:02:28
# [08/20 22:49:01 d2.evaluation.evaluator]: Inference done 407/3226. 0.0495 s / img. ETA=0:02:23
# [08/20 22:49:06 d2.evaluation.evaluator]: Inference done 505/3226. 0.0495 s / img. ETA=0:02:18
# [08/20 22:49:11 d2.evaluation.evaluator]: Inference done 603/3226. 0.0495 s / img. ETA=0:02:13
# [08/20 22:49:16 d2.evaluation.evaluator]: Inference done 703/3226. 0.0494 s / img. ETA=0:02:08
# [08/20 22:49:21 d2.evaluation.evaluator]: Inference done 802/3226. 0.0494 s / img. ETA=0:02:03
# [08/20 22:49:26 d2.evaluation.evaluator]: Inference done 899/3226. 0.0495 s / img. ETA=0:01:58
# [08/20 22:49:31 d2.evaluation.evaluator]: Inference done 998/3226. 0.0495 s / img. ETA=0:01:53
# [08/20 22:49:36 d2.evaluation.evaluator]: Inference done 1098/3226. 0.0495 s / img. ETA=0:01:48
# [08/20 22:49:41 d2.evaluation.evaluator]: Inference done 1197/3226. 0.0494 s / img. ETA=0:01:43
# [08/20 22:49:46 d2.evaluation.evaluator]: Inference done 1295/3226. 0.0495 s / img. ETA=0:01:38
# [08/20 22:49:51 d2.evaluation.evaluator]: Inference done 1394/3226. 0.0495 s / img. ETA=0:01:33
# [08/20 22:49:56 d2.evaluation.evaluator]: Inference done 1496/3226. 0.0494 s / img. ETA=0:01:27
# [08/20 22:50:01 d2.evaluation.evaluator]: Inference done 1598/3226. 0.0493 s / img. ETA=0:01:22
# [08/20 22:50:06 d2.evaluation.evaluator]: Inference done 1697/3226. 0.0493 s / img. ETA=0:01:17
# [08/20 22:50:11 d2.evaluation.evaluator]: Inference done 1796/3226. 0.0493 s / img. ETA=0:01:12
# [08/20 22:50:16 d2.evaluation.evaluator]: Inference done 1895/3226. 0.0493 s / img. ETA=0:01:07
# [08/20 22:50:21 d2.evaluation.evaluator]: Inference done 1995/3226. 0.0493 s / img. ETA=0:01:02
# [08/20 22:50:26 d2.evaluation.evaluator]: Inference done 2093/3226. 0.0493 s / img. ETA=0:00:57
# [08/20 22:50:31 d2.evaluation.evaluator]: Inference done 2193/3226. 0.0493 s / img. ETA=0:00:52
# [08/20 22:50:36 d2.evaluation.evaluator]: Inference done 2293/3226. 0.0493 s / img. ETA=0:00:47
# [08/20 22:50:41 d2.evaluation.evaluator]: Inference done 2391/3226. 0.0493 s / img. ETA=0:00:42
# [08/20 22:50:46 d2.evaluation.evaluator]: Inference done 2489/3226. 0.0493 s / img. ETA=0:00:37
# [08/20 22:50:51 d2.evaluation.evaluator]: Inference done 2588/3226. 0.0493 s / img. ETA=0:00:32
# [08/20 22:50:56 d2.evaluation.evaluator]: Inference done 2687/3226. 0.0493 s / img. ETA=0:00:27
# [08/20 22:51:01 d2.evaluation.evaluator]: Inference done 2786/3226. 0.0493 s / img. ETA=0:00:22
# [08/20 22:51:06 d2.evaluation.evaluator]: Inference done 2885/3226. 0.0493 s / img. ETA=0:00:17
# [08/20 22:51:11 d2.evaluation.evaluator]: Inference done 2984/3226. 0.0493 s / img. ETA=0:00:12
# [08/20 22:51:17 d2.evaluation.evaluator]: Inference done 3084/3226. 0.0493 s / img. ETA=0:00:07
# [08/20 22:51:22 d2.evaluation.evaluator]: Inference done 3182/3226. 0.0493 s / img. ETA=0:00:02
# [08/20 22:51:24 d2.evaluation.evaluator]: Total inference time: 0:02:43.327403 (0.050707 s / img per device, on 1 devices)
# [08/20 22:51:24 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:38 (0.049315 s / img per device, on 1 devices)
# [08/20 22:51:25 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:51:25 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V3_80+_30k/coco_instances_results.json
# [08/20 22:51:25 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.74 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.08 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.668
# [08/20 22:51:26 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 29.157 | 51.745 | 30.291 | 18.596 | 53.954 | 62.017 |
# [08/20 22:51:27 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:51:27 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/BN_Mish_V3_80+_30k/coco_instances_results.json
# [08/20 22:51:27 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.72 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.668
# [08/20 22:51:28 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 29.157 | 51.745 | 30.291 | 18.596 | 53.954 | 62.017 |

# %%
for model in faster_rcnn_model:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = faster_predictor(model, cfg_DATASETS_TEST="face_val")
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator)
  AP_VAL[model] = evaluator.evaluate()
# Out:
# faster_rcnn_R_50_FPN_3x
# ./drive/My Drive/OUTPUT_DIR_VAL/faster_rcnn_R_50_FPN_3x
# [08/20 22:55:40 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:55:40 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:55:40 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:55:40 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:55:41 d2.evaluation.evaluator]: Inference done 11/3226. 0.0658 s / img. ETA=0:03:34
# [08/20 22:55:46 d2.evaluation.evaluator]: Inference done 87/3226. 0.0647 s / img. ETA=0:03:27
# [08/20 22:55:51 d2.evaluation.evaluator]: Inference done 162/3226. 0.0651 s / img. ETA=0:03:23
# [08/20 22:55:56 d2.evaluation.evaluator]: Inference done 237/3226. 0.0653 s / img. ETA=0:03:19
# [08/20 22:56:01 d2.evaluation.evaluator]: Inference done 311/3226. 0.0656 s / img. ETA=0:03:15
# [08/20 22:56:06 d2.evaluation.evaluator]: Inference done 386/3226. 0.0655 s / img. ETA=0:03:10
# [08/20 22:56:11 d2.evaluation.evaluator]: Inference done 462/3226. 0.0654 s / img. ETA=0:03:04
# [08/20 22:56:16 d2.evaluation.evaluator]: Inference done 537/3226. 0.0655 s / img. ETA=0:02:59
# [08/20 22:56:21 d2.evaluation.evaluator]: Inference done 611/3226. 0.0656 s / img. ETA=0:02:55
# [08/20 22:56:26 d2.evaluation.evaluator]: Inference done 687/3226. 0.0656 s / img. ETA=0:02:50
# [08/20 22:56:32 d2.evaluation.evaluator]: Inference done 764/3226. 0.0654 s / img. ETA=0:02:44
# [08/20 22:56:37 d2.evaluation.evaluator]: Inference done 838/3226. 0.0655 s / img. ETA=0:02:39
# [08/20 22:56:42 d2.evaluation.evaluator]: Inference done 912/3226. 0.0656 s / img. ETA=0:02:35
# [08/20 22:56:47 d2.evaluation.evaluator]: Inference done 987/3226. 0.0655 s / img. ETA=0:02:29
# [08/20 22:56:52 d2.evaluation.evaluator]: Inference done 1063/3226. 0.0655 s / img. ETA=0:02:24
# [08/20 22:56:57 d2.evaluation.evaluator]: Inference done 1139/3226. 0.0654 s / img. ETA=0:02:19
# [08/20 22:57:02 d2.evaluation.evaluator]: Inference done 1214/3226. 0.0655 s / img. ETA=0:02:14
# [08/20 22:57:07 d2.evaluation.evaluator]: Inference done 1290/3226. 0.0654 s / img. ETA=0:02:09
# [08/20 22:57:12 d2.evaluation.evaluator]: Inference done 1365/3226. 0.0654 s / img. ETA=0:02:04
# [08/20 22:57:17 d2.evaluation.evaluator]: Inference done 1441/3226. 0.0654 s / img. ETA=0:01:59
# [08/20 22:57:22 d2.evaluation.evaluator]: Inference done 1520/3226. 0.0652 s / img. ETA=0:01:53
# [08/20 22:57:27 d2.evaluation.evaluator]: Inference done 1597/3226. 0.0652 s / img. ETA=0:01:48
# [08/20 22:57:32 d2.evaluation.evaluator]: Inference done 1673/3226. 0.0652 s / img. ETA=0:01:43
# [08/20 22:57:37 d2.evaluation.evaluator]: Inference done 1748/3226. 0.0652 s / img. ETA=0:01:38
# [08/20 22:57:42 d2.evaluation.evaluator]: Inference done 1823/3226. 0.0652 s / img. ETA=0:01:33
# [08/20 22:57:47 d2.evaluation.evaluator]: Inference done 1899/3226. 0.0652 s / img. ETA=0:01:28
# [08/20 22:57:52 d2.evaluation.evaluator]: Inference done 1975/3226. 0.0652 s / img. ETA=0:01:23
# [08/20 22:57:57 d2.evaluation.evaluator]: Inference done 2050/3226. 0.0652 s / img. ETA=0:01:18
# [08/20 22:58:02 d2.evaluation.evaluator]: Inference done 2125/3226. 0.0652 s / img. ETA=0:01:13
# [08/20 22:58:07 d2.evaluation.evaluator]: Inference done 2201/3226. 0.0652 s / img. ETA=0:01:08
# [08/20 22:58:12 d2.evaluation.evaluator]: Inference done 2277/3226. 0.0652 s / img. ETA=0:01:03
# [08/20 22:58:17 d2.evaluation.evaluator]: Inference done 2351/3226. 0.0652 s / img. ETA=0:00:58
# [08/20 22:58:22 d2.evaluation.evaluator]: Inference done 2425/3226. 0.0653 s / img. ETA=0:00:53
# [08/20 22:58:27 d2.evaluation.evaluator]: Inference done 2500/3226. 0.0653 s / img. ETA=0:00:48
# [08/20 22:58:32 d2.evaluation.evaluator]: Inference done 2577/3226. 0.0652 s / img. ETA=0:00:43
# [08/20 22:58:37 d2.evaluation.evaluator]: Inference done 2653/3226. 0.0652 s / img. ETA=0:00:38
# [08/20 22:58:42 d2.evaluation.evaluator]: Inference done 2728/3226. 0.0653 s / img. ETA=0:00:33
# [08/20 22:58:47 d2.evaluation.evaluator]: Inference done 2804/3226. 0.0653 s / img. ETA=0:00:28
# [08/20 22:58:53 d2.evaluation.evaluator]: Inference done 2879/3226. 0.0653 s / img. ETA=0:00:23
# [08/20 22:58:58 d2.evaluation.evaluator]: Inference done 2955/3226. 0.0653 s / img. ETA=0:00:18
# [08/20 22:59:03 d2.evaluation.evaluator]: Inference done 3030/3226. 0.0653 s / img. ETA=0:00:13
# [08/20 22:59:08 d2.evaluation.evaluator]: Inference done 3106/3226. 0.0653 s / img. ETA=0:00:08
# [08/20 22:59:13 d2.evaluation.evaluator]: Inference done 3179/3226. 0.0653 s / img. ETA=0:00:03
# [08/20 22:59:16 d2.evaluation.evaluator]: Total inference time: 0:03:35.083149 (0.066775 s / img per device, on 1 devices)
# [08/20 22:59:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:03:30 (0.065315 s / img per device, on 1 devices)
# [08/20 22:59:16 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:59:16 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/faster_rcnn_R_50_FPN_3x/coco_instances_results.json
# [08/20 22:59:16 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.75 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# [08/20 22:59:17 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.965 | 50.158 | 28.701 | 16.475 | 55.024 | 64.621 |
# [08/20 22:59:17 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 22:59:17 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/faster_rcnn_R_50_FPN_3x/coco_instances_results.json
# [08/20 22:59:18 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.23 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# [08/20 22:59:19 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.965 | 50.158 | 28.701 | 16.475 | 55.024 | 64.621 |
# scratch_faster_rcnn_R_50_FPN_gn
# ./drive/My Drive/OUTPUT_DIR_VAL/scratch_faster_rcnn_R_50_FPN_gn
# [08/20 22:59:24 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/20 22:59:24 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/20 22:59:24 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/20 22:59:24 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/20 22:59:25 d2.evaluation.evaluator]: Inference done 11/3226. 0.0737 s / img. ETA=0:04:00
# [08/20 22:59:30 d2.evaluation.evaluator]: Inference done 80/3226. 0.0721 s / img. ETA=0:03:51
# [08/20 22:59:35 d2.evaluation.evaluator]: Inference done 148/3226. 0.0723 s / img. ETA=0:03:46
# [08/20 22:59:40 d2.evaluation.evaluator]: Inference done 215/3226. 0.0728 s / img. ETA=0:03:43
# [08/20 22:59:45 d2.evaluation.evaluator]: Inference done 282/3226. 0.0731 s / img. ETA=0:03:39
# [08/20 22:59:50 d2.evaluation.evaluator]: Inference done 350/3226. 0.0731 s / img. ETA=0:03:34
# [08/20 22:59:55 d2.evaluation.evaluator]: Inference done 418/3226. 0.0729 s / img. ETA=0:03:28
# [08/20 23:00:00 d2.evaluation.evaluator]: Inference done 486/3226. 0.0729 s / img. ETA=0:03:23
# [08/20 23:00:06 d2.evaluation.evaluator]: Inference done 553/3226. 0.0730 s / img. ETA=0:03:18
# [08/20 23:00:11 d2.evaluation.evaluator]: Inference done 620/3226. 0.0731 s / img. ETA=0:03:14
# [08/20 23:00:16 d2.evaluation.evaluator]: Inference done 688/3226. 0.0730 s / img. ETA=0:03:08
# [08/20 23:00:21 d2.evaluation.evaluator]: Inference done 757/3226. 0.0728 s / img. ETA=0:03:03
# [08/20 23:00:26 d2.evaluation.evaluator]: Inference done 824/3226. 0.0729 s / img. ETA=0:02:58
# [08/20 23:00:31 d2.evaluation.evaluator]: Inference done 890/3226. 0.0731 s / img. ETA=0:02:54
# [08/20 23:00:36 d2.evaluation.evaluator]: Inference done 958/3226. 0.0731 s / img. ETA=0:02:48
# [08/20 23:00:41 d2.evaluation.evaluator]: Inference done 1027/3226. 0.0730 s / img. ETA=0:02:43
# [08/20 23:00:46 d2.evaluation.evaluator]: Inference done 1096/3226. 0.0729 s / img. ETA=0:02:38
# [08/20 23:00:51 d2.evaluation.evaluator]: Inference done 1164/3226. 0.0729 s / img. ETA=0:02:33
# [08/20 23:00:56 d2.evaluation.evaluator]: Inference done 1231/3226. 0.0730 s / img. ETA=0:02:28
# [08/20 23:01:01 d2.evaluation.evaluator]: Inference done 1300/3226. 0.0729 s / img. ETA=0:02:23
# [08/20 23:01:06 d2.evaluation.evaluator]: Inference done 1367/3226. 0.0729 s / img. ETA=0:02:18
# [08/20 23:01:11 d2.evaluation.evaluator]: Inference done 1435/3226. 0.0729 s / img. ETA=0:02:13
# [08/20 23:01:16 d2.evaluation.evaluator]: Inference done 1507/3226. 0.0727 s / img. ETA=0:02:07
# [08/20 23:01:21 d2.evaluation.evaluator]: Inference done 1577/3226. 0.0726 s / img. ETA=0:02:02
# [08/20 23:01:26 d2.evaluation.evaluator]: Inference done 1645/3226. 0.0726 s / img. ETA=0:01:57
# [08/20 23:01:31 d2.evaluation.evaluator]: Inference done 1713/3226. 0.0726 s / img. ETA=0:01:52
# [08/20 23:01:36 d2.evaluation.evaluator]: Inference done 1781/3226. 0.0726 s / img. ETA=0:01:46
# [08/20 23:01:41 d2.evaluation.evaluator]: Inference done 1849/3226. 0.0726 s / img. ETA=0:01:41
# [08/20 23:01:46 d2.evaluation.evaluator]: Inference done 1917/3226. 0.0726 s / img. ETA=0:01:36
# [08/20 23:01:51 d2.evaluation.evaluator]: Inference done 1985/3226. 0.0726 s / img. ETA=0:01:31
# [08/20 23:01:56 d2.evaluation.evaluator]: Inference done 2052/3226. 0.0726 s / img. ETA=0:01:26
# [08/20 23:02:01 d2.evaluation.evaluator]: Inference done 2119/3226. 0.0727 s / img. ETA=0:01:22
# [08/20 23:02:06 d2.evaluation.evaluator]: Inference done 2187/3226. 0.0727 s / img. ETA=0:01:17
# [08/20 23:02:12 d2.evaluation.evaluator]: Inference done 2256/3226. 0.0727 s / img. ETA=0:01:11
# [08/20 23:02:17 d2.evaluation.evaluator]: Inference done 2323/3226. 0.0727 s / img. ETA=0:01:06
# [08/20 23:02:22 d2.evaluation.evaluator]: Inference done 2390/3226. 0.0727 s / img. ETA=0:01:01
# [08/20 23:02:27 d2.evaluation.evaluator]: Inference done 2457/3226. 0.0727 s / img. ETA=0:00:57
# [08/20 23:02:32 d2.evaluation.evaluator]: Inference done 2525/3226. 0.0728 s / img. ETA=0:00:52
# [08/20 23:02:37 d2.evaluation.evaluator]: Inference done 2594/3226. 0.0727 s / img. ETA=0:00:46
# [08/20 23:02:42 d2.evaluation.evaluator]: Inference done 2662/3226. 0.0727 s / img. ETA=0:00:41
# [08/20 23:02:47 d2.evaluation.evaluator]: Inference done 2729/3226. 0.0728 s / img. ETA=0:00:36
# [08/20 23:02:52 d2.evaluation.evaluator]: Inference done 2797/3226. 0.0728 s / img. ETA=0:00:31
# [08/20 23:02:57 d2.evaluation.evaluator]: Inference done 2865/3226. 0.0727 s / img. ETA=0:00:26
# [08/20 23:03:02 d2.evaluation.evaluator]: Inference done 2932/3226. 0.0728 s / img. ETA=0:00:21
# [08/20 23:03:07 d2.evaluation.evaluator]: Inference done 2999/3226. 0.0728 s / img. ETA=0:00:16
# [08/20 23:03:12 d2.evaluation.evaluator]: Inference done 3067/3226. 0.0728 s / img. ETA=0:00:11
# [08/20 23:03:17 d2.evaluation.evaluator]: Inference done 3135/3226. 0.0728 s / img. ETA=0:00:06
# [08/20 23:03:22 d2.evaluation.evaluator]: Inference done 3201/3226. 0.0728 s / img. ETA=0:00:01
# [08/20 23:03:24 d2.evaluation.evaluator]: Total inference time: 0:03:59.144391 (0.074245 s / img per device, on 1 devices)
# [08/20 23:03:24 d2.evaluation.evaluator]: Total inference pure compute time: 0:03:54 (0.072788 s / img per device, on 1 devices)
# [08/20 23:03:24 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 23:03:24 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/scratch_faster_rcnn_R_50_FPN_gn/coco_instances_results.json
# [08/20 23:03:24 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.81 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.314
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [08/20 23:03:25 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.400 | 57.145 | 31.569 | 21.638 | 53.464 | 61.378 |
# [08/20 23:03:25 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/20 23:03:25 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/OUTPUT_DIR_VAL/scratch_faster_rcnn_R_50_FPN_gn/coco_instances_results.json
# [08/20 23:03:26 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.79 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.09 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.314
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [08/20 23:03:27 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.400 | 57.145 | 31.569 | 21.638 | 53.464 | 61.378 |

# %%
output_file_name = "AP_VAL_COCOEvaluator"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(AP_VAL, output_file)

# %% [markdown]
# Porównanie wyników

# %%
AP_WIDER = {}
for item in AP_VAL.keys():
  AP_WIDER[item] = AP_VAL[item]['bbox']

df_AP_WIDER = pd.DataFrame.from_dict(AP_WIDER, orient='index').sort_values(by=['AP'], ascending=False)

# %%
df_AP_WIDER
# Out:
#                                         AP       AP50  ...        APm        APl
# scratch_faster_rcnn_R_50_FPN_gn  31.400140  57.145298  ...  53.463648  61.377793
# BN_Mish_V2_250+F_2_50k           30.202843  54.445577  ...  55.288928  63.485808
# BN_Mish_V3_80+_30k               29.157098  51.745406  ...  53.954390  62.016662
# faster_rcnn_R_50_FPN_3x          27.965053  50.158303  ...  55.023554  64.620984
# BN_800k                          27.766038  49.522419  ...  52.528106  60.480344
# 800k                             23.100826  42.814369  ...  45.492286  40.228140
#
# [6 rows x 6 columns]

# %% [markdown]
# Zapis wyników na Google drive

# %%
df_AP_WIDER_results = df_AP_WIDER.to_json(orient="table")

output_file_name = "df_AP_WIDERB.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(df_AP_WIDER_results, f, indent=4)

# %% [markdown]
# Wybór modelu do testu na zbiorze testowym

# %% [markdown]
# Ewaluacja modelu na zbiorze testowym

# %%
AP_TEST = {}
drive.mount('/content/drive')
OUTPUT_DIR_NAME = "OUTPUT_DIR_TEST" #TEST
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)

for model in selected_models:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = set_predictor(model, cfg_DATASETS_TEST="face_test") # test
  print(cfg.DATASETS.TEST) 
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator))
  AP_TEST[model] = evaluator.evaluate()

# %% [markdown]
# Wyniki
