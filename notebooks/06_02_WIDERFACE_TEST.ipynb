# %% [markdown]
# <a href="https://colab.research.google.com/github/DarekGit/FACES_DNN/blob/master/notebooks/06_02_WIDERFACE_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [Spis treści](https://github.com/DarekGit/FACES_DNN/blob/master/notebooks/Praca_Dyplomowa.ipynb)

# %% [markdown]
# ## [6. Porównanie modeli](06_00_Porownanie.ipynb)

# %% [markdown]
# ### 6.2. Ewaluacja modeli na zbiorze walidacyjnym WIDER FACE

# %% [markdown]
# Instalacja Detectron2, pobranie datasetu i narzędzi

# %%
import os

os.makedirs('WIDER/', exist_ok=True)

# Download WIDER FACE VAL
# !gdown https://drive.google.com/uc?id=1-5A_pa_jDS7gk8mHVCBB7ApV5KN8jWDr -O WIDER/tempv.zip
# !unzip -q WIDER/tempv.zip -d WIDER
# !rm WIDER/tempv.zip  

# Download WIDER FACE test
# !gdown https://drive.google.com/uc?id=1tTpUJZEQMKDVxKT6100V5FwDuGX_8sDi -O WIDER/tempt.zip
# !unzip -q WIDER/tempt.zip -d WIDER
# !rm WIDER/tempt.zip

# Download face annotations (wider_face_split.zip)
# !wget mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/bbx_annotation/wider_face_split.zip -O WIDER/wider_face_split.zip
# !unzip -q WIDER/wider_face_split.zip -d WIDER
# !rm WIDER/wider_face_split.zip

### WIDER FACE - Examples and formats of the submissions
# !wget mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/example/Submission_example.zip -O WIDER/Submission_example.zip
# !unzip -q WIDER/Submission_example.zip -d WIDER
# !rm WIDER/Submission_example.zip

# eval_tools

# !wget shuoyang1213.me/WIDERFACE/support/eval_script/eval_tools.zip
# !unzip eval_tools.zip

# Download tools

# !gdown https://drive.google.com/uc?id=1_9ydMZlTNFXBOMl16xsU8FSBmK2PW4lN -O WIDER/tools.py
# !wget -q -O WIDER/mAP.py https://drive.google.com/uc?id=1PtEsobTFah3eiCDbSsYblOGbe2fmkjGR

# mobilenet
# !gdown https://drive.google.com/uc?id=1U0SVkSaSio4TBiXvF1QfTZI65WYpXpZ9
# !unzip -qo mobilenet.zip
# !rm -f mobilenet.zip

# install detectron2:

# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -q -e detectron2_repo

# %% [markdown]
# Restart runtime to continue...

# %%
# !nvidia-smi
from psutil import virtual_memory
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(virtual_memory().total / 1e9))
# Out:
# Fri Aug 21 15:54:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 27.4 gigabytes of available RAM

# %%
# !pip install facenet-pytorch
from facenet_pytorch import MTCNN
# Out:
# Collecting facenet-pytorch
#   Downloading https://files.pythonhosted.org/packages/5b/69/8639b8c090c22bf1a83bfc120b831e8f41b6819e257e5c879aa0ec42b417/facenet_pytorch-2.3.1-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 2.7MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from facenet-pytorch) (7.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from facenet-pytorch) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from facenet-pytorch) (2.23.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from facenet-pytorch) (0.7.0+cu101)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->facenet-pytorch) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->facenet-pytorch) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->facenet-pytorch) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->facenet-pytorch) (3.0.4)
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.6/dist-packages (from torchvision->facenet-pytorch) (1.6.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchvision->facenet-pytorch) (0.16.0)
# Installing collected packages: facenet-pytorch
# Successfully installed facenet-pytorch-2.3.1

# %%
import time
from tqdm.notebook import tqdm
import torch, torchvision
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()


import gdown
from google.colab import drive
import os
import cv2
import random
import itertools
import shutil
import glob
import json
import numpy as np
import pandas as pd
from PIL import ImageDraw, Image
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib import collections as mc

from google.colab.patches import cv2_imshow

from detectron2 import model_zoo
import detectron2.utils.comm as comm
from detectron2.engine import DefaultPredictor, DefaultTrainer, HookBase
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_train_loader
from detectron2.structures import BoxMode
from detectron2.data import build_detection_test_loader
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

from mobilenet.utils import  add_mobilenet_config, build_mobilenetv2_fpn_backbone
from WIDER.mAP import mAP, plot_mAP
from WIDER.tools import annotations,output_Files

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %% [markdown]
# Zapis danych na Google drive

# %%
OUTPUT_DIR_NAME = "WIDERFACE_OUTPUT_DIR"
drive.mount('/content/drive')
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)
  print("\ncfg.OUTPUT_DIR =",OUTPUT_DIR_PATH) 
else: 
  print("\ncfg.OUTPUT_DIR =",OUTPUT_DIR_PATH)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
#
# cfg.OUTPUT_DIR = ./drive/My Drive/WIDERFACE_OUTPUT_DIR

# %% [markdown]
# ## Modele do testu

# %% [markdown]
# MobileNetV2

# %%
models_mnv2 = {
    # '800k' - parametry domyślne - jako punkt odniesienia
    '800k': {
        'config': 'FrozenBN',
        'pth': 'https://drive.google.com/uc?id=1-tqNKwZIFmkAbfJ1L2sibIO4PT_MwnVA',
        'weights_name': 'model_0799999.pth'},

    # 'BN_800k' - dodano BN - pokazanie wpływu BN przy małym batchu=2
    'BN_800k': {
        'config': 'BN',
        'pth': 'https://drive.google.com/uc?id=1-kRDjqkMk9qXbNfzVx09VE35YzgkP1AO',
        'weights_name': 'model_0799999.pth'},

    #'BN_Mish_V2_250+F_2_50k' - najlepszy wynik uczenie z Mish BN 250k + 50k z FrozenBN
    'BN_Mish_V2_250+F_2_50k': {
        'config': 'BN_Mish_V2F',
        'pth': 'https://drive.google.com/uc?id=1-I6YSAs9NrORI4cFISfK_-4Yhm1twfDi',
        'weights_name': 'model_0049999.pth'},
    
    # 'BN_Mish_V3_80+30k' - najszybsze uczenie 110k iteracji
    'BN_Mish_V3_80+_30k': {
        'config': 'BN_Mish_V3',
        'pth': 'https://drive.google.com/uc?id=1--bP5VPyqIrfrBxVZ5eLSsupIvBlQ8ef',
        'weights_name': 'model_0029999.pth'},
    }

# %% [markdown]
# Faster R-CNN

# %%
faster_rcnn_model = {
    'faster_rcnn_R_50_FPN_3x' : {
        'config': 'https://drive.google.com/uc?id=173XKeFyCXK909QA652WpEhQ3imlyDFKX',
        'config_file' : "faster_rcnn_R_50_FPN_3x.yaml",
        'pth': 'https://drive.google.com/uc?id=1-XGz6HOqJQWmDCJiJDbBl-FnK7ZxZu5z',
        'weights_name': 'model_0269999.pth' 
    },
    'scratch_faster_rcnn_R_50_FPN_gn' : {
        'config': 'https://drive.google.com/uc?id=1-IX6Dshhs-rin7m1lGtTl1xNaUQXK3kN',
        'config_file' : "scratch_faster_rcnn_R_50_FPN_gn.yaml",
        'pth': 'https://drive.google.com/uc?id=1-dqOloknew4wN0cD5xcFhbRlrA8rSHGt',
        'weights_name': 'model_0539999.pth' 
    }
}

# %% [markdown]
# MTCNN

# %%
mtcnn = MTCNN(image_size=224, margin=0, keep_all=True, device=device)

# %% [markdown]
# ## Zestawy konfiguracji podstawowych dla modeli opartych na MobileNetV2

# %%
cfg_set = {
    'FrozenBN':'https://drive.google.com/uc?id=1rZFzJaR_g7uYuTguTdbUuCQYD4eXLeqw',
    'BN': 'https://drive.google.com/uc?id=1-doXtwe5iZHoqPzKGc2ZZbxj6Ebhxsn4',
    'BN_V2':'https://drive.google.com/uc?id=1wywB8UAaOO5KZx3IS35kV-rLsvJMIse6',
    'BN_Mish':'https://drive.google.com/uc?id=1-axV3KKg8-YiZZ7uDBh_2v181JoC9Nj3',
    'BN_Mish_V2':'https://drive.google.com/uc?id=1WoESx5RYvpapNicpSrmMoNJeE2GVm3zK',
    'BN_Mish_V3':'https://drive.google.com/uc?id=1-Kgd_2AS4EsD_ZPqP7SxkscyDjP-Qhnr',
    'BN_Mish_V2F':'https://drive.google.com/uc?id=1pCwyYCjIoduro2vIKMZi5HhlpaypH0_x',
    'R50_C4':'https://drive.google.com/uc?id=1-5P5Xyx5GM26p7g89CY-SSX0aluB7H9U',}

# %% [markdown]
# ## DefaultPredictor dla modeli opartych na MobileNetV2

# %%
def cfg_write(cfg,cfg_all):
  for key in cfg_all.keys():
    if isinstance(cfg_all[key],dict): 
      cfg_write(cfg[key],cfg_all[key])
    else: cfg[key]=cfg_all[key]
  return cfg

def set_predictor(model_name=None, models_dict=models_mnv2, cfg_dict=cfg_set ,device='cuda', cfg_DATASETS_TEST=None):
  url = models_dict[model_name]['pth'] 
  out = models_dict[model_name]['weights_name']
  gdown.download(url, out, True)
  # model configuration
  url_cfg = cfg_dict[models_dict[model_name]['config']] 
  gdown.download(url_cfg, "temporary.json", True)
  with open('temporary.json','r') as f:
    cfg_all=json.load(f)
  cfg = get_cfg()
  add_mobilenet_config(cfg)
  cfg = cfg_write(cfg,cfg_all)
  cfg.MODEL.WEIGHTS = models_dict[model_name]['weights_name']
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
  cfg.MODEL.DEVICE=device
  if cfg_DATASETS_TEST is not None:
    cfg.DATASETS.TEST = (cfg_DATASETS_TEST, )

  return DefaultPredictor(cfg), cfg

# %% [markdown]
# ## DefaultPredictor dla Faster-RCNN

# %%
def faster_predictor(model_name=None, models_dict=faster_rcnn_model, cfg_DATASETS_TEST=None):
  url = models_dict[model_name]['pth'] 
  out = models_dict[model_name]['weights_name']
  gdown.download(url, out, True)
  config = models_dict[model_name]['config']
  config_file = models_dict[model_name]['config_file']
  gdown.download(config, config_file, True)

  cfg = get_cfg()

  cfg.merge_from_file(config_file)
  cfg.MODEL.WEIGHTS = out
  cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
  cfg.MODEL.DEVICE='cuda'
  if cfg_DATASETS_TEST is not None:
    cfg.DATASETS.TEST = (cfg_DATASETS_TEST, )
  return DefaultPredictor(cfg), cfg

# %% [markdown]
# ## Funkcja pomiaru czasu ewaluacji modelu

# %%
def time_measurement(predictor, dataset):
  time_ = []
  for item in tqdm(dataset):
    start_ = time.time()
    img = cv2.imread(item["file_name"])
    if str(predictor) == "mtcnn":
      outputs = mtcnn.detect(img)
    else :
      outputs = predictor(img)
    diff = time.time() - start_
    time_.append(diff)
  # Total time
  total_time = np.array(time_).sum()
  # Mean time
  mean_diff = np.array(time_).mean()
  # Frames per second 
  fps = 1 / mean_diff
  print("Total time(sec): {:.2f}, Average(sec):{:.2f}, fps:{:.2f}\n".format(total_time, mean_diff, fps))
  return {"total_time": total_time, "mean_diff": mean_diff, "fps": fps}

# %% [markdown]
# ## Funkcja do ewaluacji modelu na zbiorze walidacyjnym WIDER FACE

# %%
def predict_on_val(dataset, predictor, model_name):
    gbxs=[]
    dbxs=[]
    dset=dataset
    if 'annotations' in dataset[0].keys():  
      dset=[]
      for r in dataset:
        dset.append({'path' : r['file_name'],'marks' : [b['bbox'] for b in r['annotations']],
                     'persons': ['' for b in r['annotations']]})

    for item in tqdm(dset):
        im = cv2.imread(item["path"])
        outputs = predictor(im)
        pbxs = outputs['instances'].pred_boxes.tensor.tolist()
        pconfs = outputs['instances'].scores.tolist()
        dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
        dbxs.append(dbx)
        gbxs.append(item['marks'])
    
    return {'gbxs':gbxs,'dbxs':dbxs,'metric':dset}

# %% [markdown]
# ## Funkcja do ewaluacji MTCNN na zbiorze walidacyjnym

# %%
def mtcnn_detect(dataset, model, model_name = "MTCNN"):
    gbxs=[]
    dbxs=[]
    dset=dataset
    if 'annotations' in dataset[0].keys():  
      dset=[]
      for r in dataset:
        dset.append({'path' : r['file_name'],'marks' : [b['bbox'] for b in r['annotations']],
                     'persons': ['' for b in r['annotations']]})

    for item in tqdm(dset):
        im = cv2.imread(item["path"])
        pbxs, pconfs  = model.detect(im)

        if type(pbxs)!=np.ndarray: 
          pbxs=[]
          pconfs=[]

        dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
        dbxs.append(dbx)
        gbxs.append(item['marks'])
    
    return {'gbxs':gbxs,'dbxs':dbxs,'metric':dset}

# %% [markdown]
# ## Funkcje do ewaluacji modelu na zbiorze testowym WIDER FACE i umożliwiające zapis wyników do pliku

# %%
def read_wider_face_test_filelist(path='WIDER/wider_face_split/'):
  full_path = path+"wider_face_test_filelist.txt"
  if os.path.exists(full_path):
    test_files = []
    with open(full_path, 'r') as f:
      for row in f:
        test_files.append(row.split('\n')[0])
    return test_files

# %%
def predict_on_test(file_list, predictor, model_name, path="WIDER/WIDER_test/images/"):
  output_list = []
  for item in tqdm(file_list):
    if os.path.exists(path+item):
      record = {}
      img = cv2.imread(path+item)
      outputs = predictor(img)
      pbxs = outputs['instances'].pred_boxes.tensor.tolist()
      pconfs = outputs['instances'].scores.tolist()
      dbx=[[*(np.array(bx)+0.5).astype('int'),pconfs[i]] for i,bx in enumerate(pbxs)]
      record['file_name'] = item
      record['faces'] = len(dbx)
      record["bbox"] = dbx
    output_list.append(record)
  return output_list

# %%
def save_predictions_to_files(preds, model_name, wider_path = 'WIDER/WIDER_test/'):
  """The function saves the results as shown in the example 
  mmlab.ie.cuhk.edu.hk/projects/WIDERFace/support/example/Submission_example.zip
  """
  if not os.path.isdir(wider_path+model_name): # 
    os.makedirs(wider_path+model_name)
  for item in tqdm(preds):
    subdirectory = os.path.split(item["file_name"])[0]
    if not os.path.isdir(wider_path+model_name+"/"+subdirectory):
      os.makedirs(wider_path+model_name+"/"+subdirectory)
    output_file = os.path.split(item["file_name"])[1][:-4]
    output_file = wider_path+model_name+"/"+subdirectory+"/"+output_file
    with open(output_file + '.txt', 'w') as f:
      f.write(output_file + os.linesep)
      f.write(str(item["faces"]) + os.linesep)
      for row in item['bbox']:
        row[-1] = round(row[-1],3)
        f.write(" ".join([str(i) for i in row]) + os.linesep)

# %%
def dict_to_file(dic, path):
    f = open(path,'w')
    f.write(str(dic))
    f.close()

def dict_from_file(filename):
    f = open(filename,'r')
    data=f.read()
    f.close()
    return eval(data)

# %% [markdown]
# ## Pomiar czasu interferencji modeli na zbiorze walidacyjnym

# %%
WIDERFACE_VAL = annotations('val')

# %%
time_measurement_results = {}
for model in models_mnv2:
  print(model)
  predictor, _ = set_predictor(model)
  time_measurement_results[model] = time_measurement(predictor, dataset=WIDERFACE_VAL)

print(time_measurement_results)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 248.57, Average(sec):0.08, fps:12.98
#
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 244.90, Average(sec):0.08, fps:13.17
#
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 314.01, Average(sec):0.10, fps:10.27
#
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 311.97, Average(sec):0.10, fps:10.34
#
# {'800k': {'total_time': 248.56552147865295, 'mean_diff': 0.07705068861706539, 'fps': 12.978469342044496}, 'BN_800k': {'total_time': 244.89701414108276, 'mean_diff': 0.0759135195725613, 'fps': 13.172884166491034}, 'BN_Mish_V2_250+F_2_50k': {'total_time': 314.00685453414917, 'mean_diff': 0.09733628472850253, 'fps': 10.27366107910604}, 'BN_Mish_V3_80+_30k': {'total_time': 311.9675250053406, 'mean_diff': 0.09670413050382536, 'fps': 10.340819929717922}}

# %%
for model in faster_rcnn_model:
  print(model)
  predictor, _ = faster_predictor(model)
  time_measurement_results[model] = time_measurement(predictor, dataset=WIDERFACE_VAL)
# Out:
# faster_rcnn_R_50_FPN_3x
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 307.45, Average(sec):0.10, fps:10.49
#
# scratch_faster_rcnn_R_50_FPN_gn
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 332.27, Average(sec):0.10, fps:9.71

# %%
time_measurement_results["MTCNN"] = time_measurement(mtcnn, dataset=WIDERFACE_VAL)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# Total time(sec): 329.38, Average(sec):0.10, fps:9.79

# %%
time_measurement_results
# Out:
# {'800k': {'fps': 12.978469342044496,
#   'mean_diff': 0.07705068861706539,
#   'total_time': 248.56552147865295},
#  'BN_800k': {'fps': 13.172884166491034,
#   'mean_diff': 0.0759135195725613,
#   'total_time': 244.89701414108276},
#  'BN_Mish_V2_250+F_2_50k': {'fps': 10.27366107910604,
#   'mean_diff': 0.09733628472850253,
#   'total_time': 314.00685453414917},
#  'BN_Mish_V3_80+_30k': {'fps': 10.340819929717922,
#   'mean_diff': 0.09670413050382536,
#   'total_time': 311.9675250053406},
#  'MTCNN': {'fps': 9.794156230663534,
#   'mean_diff': 0.10210169987580973,
#   'total_time': 329.3800837993622},
#  'faster_rcnn_R_50_FPN_3x': {'fps': 10.492657361001115,
#   'mean_diff': 0.09530474174414373,
#   'total_time': 307.45309686660767},
#  'scratch_faster_rcnn_R_50_FPN_gn': {'fps': 9.708874541128022,
#   'mean_diff': 0.10299855001358534,
#   'total_time': 332.2733223438263}}

# %% [markdown]
# Porównanie wyników

# %%
df_time_measurement_results = pd.DataFrame.from_dict(time_measurement_results, orient='index').sort_values(by=['total_time'])
df_time_measurement_results
# Out:
#                                  total_time  mean_diff        fps
# BN_800k                          244.897014   0.075914  13.172884
# 800k                             248.565521   0.077051  12.978469
# faster_rcnn_R_50_FPN_3x          307.453097   0.095305  10.492657
# BN_Mish_V3_80+_30k               311.967525   0.096704  10.340820
# BN_Mish_V2_250+F_2_50k           314.006855   0.097336  10.273661
# MTCNN                            329.380084   0.102102   9.794156
# scratch_faster_rcnn_R_50_FPN_gn  332.273322   0.102999   9.708875

# %% [markdown]
# Zapis wyników

# %%
time_measurement_results = df_time_measurement_results.to_json(orient="table")

output_file_name = "time_measurement_results.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(time_measurement_results, f, indent=4)

# %% [markdown]
# ## Ewaluacja modeli na zbiorze walidacyjnym i mAP liczone funkcją Darka

# %%
WIDERFACE_VAL = annotations('val')

# %%
pred = {}
for model in models_mnv2:
  print(model)
  predictor, cfg = set_predictor(model)
  pred[model] = predict_on_val(WIDERFACE_VAL ,predictor, model)
  # save to Google drive 
  output_file_name = f"unified_mAP_{model}"
  output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
  dict_to_file(pred[model], output_file)
# Out:
# 800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_800k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_Mish_V2_250+F_2_50k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# BN_Mish_V3_80+_30k
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %%
for model in faster_rcnn_model:
  print(model)
  predictor, cfg = faster_predictor(model)
  pred[model] = predict_on_val(WIDERFACE_VAL ,predictor, model)
    
  # save to Google drive 
  output_file_name = f"unified_mAP_{model}"
  output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
  dict_to_file(pred[model], output_file)
# Out:
# faster_rcnn_R_50_FPN_3x
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))
# scratch_faster_rcnn_R_50_FPN_gn
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %%
model = "MTCNN"
pred[model] = mtcnn_detect(WIDERFACE_VAL , mtcnn , model)
output_file_name = f"unified_mAP_{model}"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(pred[model], output_file)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3226.0), HTML(value='')))

# %% [markdown]
# ## Wykresy mAP dla testowanych modeli

# %%
def model_mAP(pdict, model_name, title=""):
  m, d = mAP(gbxs=pdict[model_name]['gbxs'], dbxs=pdict[model_name]['dbxs'], data=True)
  output_file_name = f"unified_mAP_{title}_{model_name}"
  plot_mAP(m,d,['All 0.50','mAP','large','medium','small'],1,title+model_name,file=f"unified_mAP_{title}_{model_name}")
  return m,d

# %%
all_models_mAP = {}
pred.keys()
# Out:
# dict_keys(['800k', 'BN_800k', 'BN_Mish_V2_250+F_2_50k', 'BN_Mish_V3_80+_30k', 'faster_rcnn_R_50_FPN_3x', 'scratch_faster_rcnn_R_50_FPN_gn', 'MTCNN'])

# %% [markdown]
# ## Model: 800k

# %%
modelshow = list(pred.keys())[0]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: 800k
# All 0.50:   AP: 43.35%   Recall: 45.21%   IoU: 0.5
# large   :   AP: 68.67%   Recall: 70.94%   IoU: 0.5
# medium  :   AP: 74.95%   Recall: 76.37%   IoU: 0.5
# small   :   AP: 31.04%   Recall: 33.19%   IoU: 0.5
# mAP     :   AP: 23.83%   Recall: 26.97%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_800k

# %%
modelshow = list(pred.keys())[1]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_800k
# All 0.50:   AP: 50.31%   Recall: 51.33%   IoU: 0.5
# large   :   AP: 90.83%   Recall: 91.30%   IoU: 0.5
# medium  :   AP: 83.83%   Recall: 84.47%   IoU: 0.5
# small   :   AP: 36.10%   Recall: 37.50%   IoU: 0.5
# mAP     :   AP: 28.49%   Recall: 31.47%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_Mish_V2_250+F_2_50k

# %%
modelshow = list(pred.keys())[2]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_Mish_V2_250+F_2_50k
# All 0.50:   AP: 55.34%   Recall: 56.37%   IoU: 0.5
# large   :   AP: 93.72%   Recall: 93.98%   IoU: 0.5
# medium  :   AP: 87.79%   Recall: 88.30%   IoU: 0.5
# small   :   AP: 41.59%   Recall: 43.11%   IoU: 0.5
# mAP     :   AP: 31.21%   Recall: 34.48%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: BN_Mish_V3_80+_30k

# %%
modelshow = list(pred.keys())[3]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: BN_Mish_V3_80+_30k
# All 0.50:   AP: 52.61%   Recall: 53.39%   IoU: 0.5
# large   :   AP: 92.25%   Recall: 92.53%   IoU: 0.5
# medium  :   AP: 85.83%   Recall: 86.27%   IoU: 0.5
# small   :   AP: 38.57%   Recall: 39.71%   IoU: 0.5
# mAP     :   AP: 29.95%   Recall: 33.14%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: faster_rcnn_R_50_FPN_3x

# %%
modelshow = list(pred.keys())[4]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: faster_rcnn_R_50_FPN_3x
# All 0.50:   AP: 50.92%   Recall: 52.26%   IoU: 0.5
# large   :   AP: 95.18%   Recall: 95.42%   IoU: 0.5
# medium  :   AP: 87.23%   Recall: 87.79%   IoU: 0.5
# small   :   AP: 35.15%   Recall: 37.40%   IoU: 0.5
# mAP     :   AP: 28.73%   Recall: 31.90%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: scratch_faster_rcnn_R_50_FPN_gn

# %%
modelshow = list(pred.keys())[5]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: scratch_faster_rcnn_R_50_FPN_gn
# All 0.50:   AP: 58.03%   Recall: 59.27%   IoU: 0.5
# large   :   AP: 92.46%   Recall: 92.87%   IoU: 0.5
# medium  :   AP: 87.53%   Recall: 88.17%   IoU: 0.5
# small   :   AP: 45.43%   Recall: 47.31%   IoU: 0.5
# mAP     :   AP: 32.45%   Recall: 36.76%   IoU: 0.5 - 0.95

# %% [markdown]
# ## Model: MTCNN

# %%
modelshow = list(pred.keys())[6]
print("Model:", modelshow)
all_models_mAP[modelshow] = model_mAP(pred, modelshow, title="WIDERFACE_mAP_model_")
# Out:
# Model: MTCNN
# All 0.50:   AP: 22.86%   Recall: 23.11%   IoU: 0.5
# large   :   AP: 61.74%   Recall: 62.11%   IoU: 0.5
# medium  :   AP: 51.87%   Recall: 52.18%   IoU: 0.5
# small   :   AP: 10.38%   Recall: 10.64%   IoU: 0.5
# mAP     :   AP: 13.33%   Recall: 15.03%   IoU: 0.5 - 0.95

# %%
# !mv unified_mAP*.png ./drive/'My Drive'/WIDERFACE_OUTPUT_DIR/

# %% [markdown]
# Zapis wyników

# %%
output_file_name = "all_models_mAP"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(all_models_mAP, output_file)

# %%
modeldict = {}
DD_mAP = {}

for item in all_models_mAP.keys():
  for i in all_models_mAP[item][0].keys():
    modeldict[i] =  {
        "AP" : all_models_mAP[item][0][i][0],
        "Recall" : all_models_mAP[item][0][i][1],
        "IoU" : all_models_mAP[item][0][i][2],
    }
  DD_mAP[item] = modeldict

# %%
output_file_name = "DD_mAP_all_models"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(DD_mAP, output_file)

# %%
from collections import OrderedDict

DD_mAP2 = OrderedDict()

for item in all_models_mAP.keys():
  DD_mAP2[item] = ({i:all_models_mAP[item][0][i][0] for i in ['mAP', 'All 0.50','large','medium','small']})

df_unified_mAP = pd.DataFrame.from_dict(DD_mAP2, orient='index').sort_values(by=['All 0.50'], ascending=False)
df_unified_mAP
# Out:
#                                       mAP  All 0.50  ...    medium     small
# scratch_faster_rcnn_R_50_FPN_gn  0.324501  0.580318  ...  0.875298  0.454291
# BN_Mish_V2_250+F_2_50k           0.312105  0.553373  ...  0.877947  0.415864
# BN_Mish_V3_80+_30k               0.299488  0.526117  ...  0.858282  0.385726
# faster_rcnn_R_50_FPN_3x          0.287271  0.509173  ...  0.872292  0.351544
# BN_800k                          0.284875  0.503125  ...  0.838339  0.361031
# 800k                             0.238252  0.433512  ...  0.749513  0.310390
# MTCNN                            0.133329  0.228585  ...  0.518723  0.103795
#
# [7 rows x 5 columns]

# %%
df_unified_mAP_results = df_unified_mAP.to_json(orient="table")

output_file_name = "unified_mAP_dataframe.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(df_unified_mAP_results, f, indent=4)

# %%
with open(output_file) as data_file:
    data_loaded = json.load(data_file)
pd.read_json(data_loaded, orient="table" )
# Out:
#                                       mAP  All 0.50  ...    medium     small
# scratch_faster_rcnn_R_50_FPN_gn  0.324501  0.580318  ...  0.875298  0.454291
# BN_Mish_V2_250+F_2_50k           0.312105  0.553373  ...  0.877947  0.415864
# BN_Mish_V3_80+_30k               0.299488  0.526117  ...  0.858282  0.385726
# faster_rcnn_R_50_FPN_3x          0.287271  0.509173  ...  0.872292  0.351544
# BN_800k                          0.284875  0.503125  ...  0.838339  0.361031
# 800k                             0.238252  0.433512  ...  0.749513  0.310390
# MTCNN                            0.133329  0.228585  ...  0.518723  0.103795
#
# [7 rows x 5 columns]

# %% [markdown]
# # Ewaluacja na WIDER FACE z wykorzystaniem COCOEvaluator i inference_on_dataset

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# %%
val = annotations('val')
test = annotations('test')

# %%
for d in ["test", "val"]:
  DatasetCatalog.register("face_" + d, lambda d=d: test if d == "test" else val)
  MetadataCatalog.get("face_" + d).set(thing_classes = ['face'])

faces_metadata = MetadataCatalog.get("face_test")

# %%
dataset_dicts = annotations('val')
for d in random.sample(dataset_dicts, 1):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=faces_metadata, scale=0.9)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=921x1376 at 0x7F9635BBE588>

# %%
AP_VAL = {}
drive.mount('/content/drive')
OUTPUT_DIR_NAME = "WIDERFACE_OUTPUT_DIR"
OUTPUT_DIR_PATH = os.path.join("./drive/My Drive", OUTPUT_DIR_NAME)

if not os.path.exists(OUTPUT_DIR_PATH):
  os.makedirs(OUTPUT_DIR_PATH)

for model in models_mnv2:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = set_predictor(model, cfg_DATASETS_TEST="face_val")
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator)
  AP_VAL[model] = evaluator.evaluate()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 800k
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/800k
# [08/21 15:56:19 d2.evaluation.coco_evaluation]: 'face_val' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# [08/21 15:56:19 d2.data.datasets.coco]: Converting annotations of dataset 'face_val' to COCO format ...)
# [08/21 15:56:19 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [08/21 15:56:28 d2.data.datasets.coco]: Conversion finished, #images: 3226, #annotations: 39708
# [08/21 15:56:28 d2.data.datasets.coco]: Caching COCO format annotations at './drive/My Drive/WIDERFACE_OUTPUT_DIR/800k/face_val_coco_format.json' ...
# [08/21 15:56:30 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    face    | 39708        |
# |            |              |
# [08/21 15:56:30 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 15:56:30 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 15:56:30 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 15:56:30 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 15:56:31 d2.evaluation.evaluator]: Inference done 11/3226. 0.0490 s / img. ETA=0:02:42
# [08/21 15:56:36 d2.evaluation.evaluator]: Inference done 112/3226. 0.0477 s / img. ETA=0:02:34
# [08/21 15:56:41 d2.evaluation.evaluator]: Inference done 212/3226. 0.0480 s / img. ETA=0:02:30
# [08/21 15:56:46 d2.evaluation.evaluator]: Inference done 312/3226. 0.0481 s / img. ETA=0:02:25
# [08/21 15:56:51 d2.evaluation.evaluator]: Inference done 413/3226. 0.0480 s / img. ETA=0:02:20
# [08/21 15:56:56 d2.evaluation.evaluator]: Inference done 513/3226. 0.0481 s / img. ETA=0:02:15
# [08/21 15:57:01 d2.evaluation.evaluator]: Inference done 612/3226. 0.0482 s / img. ETA=0:02:10
# [08/21 15:57:06 d2.evaluation.evaluator]: Inference done 713/3226. 0.0482 s / img. ETA=0:02:05
# [08/21 15:57:11 d2.evaluation.evaluator]: Inference done 814/3226. 0.0481 s / img. ETA=0:02:00
# [08/21 15:57:16 d2.evaluation.evaluator]: Inference done 914/3226. 0.0482 s / img. ETA=0:01:55
# [08/21 15:57:21 d2.evaluation.evaluator]: Inference done 1015/3226. 0.0481 s / img. ETA=0:01:50
# [08/21 15:57:26 d2.evaluation.evaluator]: Inference done 1117/3226. 0.0481 s / img. ETA=0:01:45
# [08/21 15:57:31 d2.evaluation.evaluator]: Inference done 1218/3226. 0.0481 s / img. ETA=0:01:40
# [08/21 15:57:36 d2.evaluation.evaluator]: Inference done 1319/3226. 0.0481 s / img. ETA=0:01:35
# [08/21 15:57:41 d2.evaluation.evaluator]: Inference done 1420/3226. 0.0481 s / img. ETA=0:01:30
# [08/21 15:57:46 d2.evaluation.evaluator]: Inference done 1523/3226. 0.0480 s / img. ETA=0:01:24
# [08/21 15:57:51 d2.evaluation.evaluator]: Inference done 1625/3226. 0.0480 s / img. ETA=0:01:19
# [08/21 15:57:56 d2.evaluation.evaluator]: Inference done 1725/3226. 0.0480 s / img. ETA=0:01:14
# [08/21 15:58:01 d2.evaluation.evaluator]: Inference done 1826/3226. 0.0480 s / img. ETA=0:01:09
# [08/21 15:58:06 d2.evaluation.evaluator]: Inference done 1927/3226. 0.0480 s / img. ETA=0:01:04
# [08/21 15:58:11 d2.evaluation.evaluator]: Inference done 2028/3226. 0.0480 s / img. ETA=0:00:59
# [08/21 15:58:16 d2.evaluation.evaluator]: Inference done 2128/3226. 0.0480 s / img. ETA=0:00:54
# [08/21 15:58:21 d2.evaluation.evaluator]: Inference done 2230/3226. 0.0480 s / img. ETA=0:00:49
# [08/21 15:58:26 d2.evaluation.evaluator]: Inference done 2330/3226. 0.0480 s / img. ETA=0:00:44
# [08/21 15:58:31 d2.evaluation.evaluator]: Inference done 2428/3226. 0.0480 s / img. ETA=0:00:39
# [08/21 15:58:36 d2.evaluation.evaluator]: Inference done 2528/3226. 0.0480 s / img. ETA=0:00:34
# [08/21 15:58:41 d2.evaluation.evaluator]: Inference done 2626/3226. 0.0481 s / img. ETA=0:00:29
# [08/21 15:58:46 d2.evaluation.evaluator]: Inference done 2727/3226. 0.0481 s / img. ETA=0:00:24
# [08/21 15:58:51 d2.evaluation.evaluator]: Inference done 2829/3226. 0.0480 s / img. ETA=0:00:19
# [08/21 15:58:57 d2.evaluation.evaluator]: Inference done 2930/3226. 0.0480 s / img. ETA=0:00:14
# [08/21 15:59:02 d2.evaluation.evaluator]: Inference done 3028/3226. 0.0480 s / img. ETA=0:00:09
# [08/21 15:59:07 d2.evaluation.evaluator]: Inference done 3129/3226. 0.0480 s / img. ETA=0:00:04
# [08/21 15:59:12 d2.evaluation.evaluator]: Total inference time: 0:02:41.102460 (0.050016 s / img per device, on 1 devices)
# [08/21 15:59:12 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:34 (0.048063 s / img per device, on 1 devices)
# [08/21 15:59:12 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 15:59:12 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/800k/coco_instances_results.json
# [08/21 15:59:12 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.26s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.91 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# [08/21 15:59:13 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 23.101 | 42.814 | 22.892 | 14.973 | 45.492 | 40.228 |
# [08/21 15:59:14 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 15:59:14 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/800k/coco_instances_results.json
# [08/21 15:59:14 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.90 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
# [08/21 15:59:15 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 23.101 | 42.814 | 22.892 | 14.973 | 45.492 | 40.228 |
# BN_800k
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_800k
# [08/21 15:59:18 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 15:59:18 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 15:59:18 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 15:59:18 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 15:59:19 d2.evaluation.evaluator]: Inference done 11/3226. 0.0485 s / img. ETA=0:02:40
# [08/21 15:59:24 d2.evaluation.evaluator]: Inference done 113/3226. 0.0477 s / img. ETA=0:02:34
# [08/21 15:59:29 d2.evaluation.evaluator]: Inference done 212/3226. 0.0482 s / img. ETA=0:02:30
# [08/21 15:59:34 d2.evaluation.evaluator]: Inference done 312/3226. 0.0483 s / img. ETA=0:02:26
# [08/21 15:59:39 d2.evaluation.evaluator]: Inference done 412/3226. 0.0484 s / img. ETA=0:02:21
# [08/21 15:59:44 d2.evaluation.evaluator]: Inference done 512/3226. 0.0484 s / img. ETA=0:02:16
# [08/21 15:59:49 d2.evaluation.evaluator]: Inference done 611/3226. 0.0485 s / img. ETA=0:02:11
# [08/21 15:59:54 d2.evaluation.evaluator]: Inference done 711/3226. 0.0485 s / img. ETA=0:02:06
# [08/21 15:59:59 d2.evaluation.evaluator]: Inference done 811/3226. 0.0484 s / img. ETA=0:02:01
# [08/21 16:00:04 d2.evaluation.evaluator]: Inference done 910/3226. 0.0485 s / img. ETA=0:01:56
# [08/21 16:00:09 d2.evaluation.evaluator]: Inference done 1009/3226. 0.0485 s / img. ETA=0:01:51
# [08/21 16:00:14 d2.evaluation.evaluator]: Inference done 1109/3226. 0.0485 s / img. ETA=0:01:46
# [08/21 16:00:19 d2.evaluation.evaluator]: Inference done 1209/3226. 0.0485 s / img. ETA=0:01:41
# [08/21 16:00:24 d2.evaluation.evaluator]: Inference done 1309/3226. 0.0485 s / img. ETA=0:01:36
# [08/21 16:00:29 d2.evaluation.evaluator]: Inference done 1409/3226. 0.0485 s / img. ETA=0:01:31
# [08/21 16:00:34 d2.evaluation.evaluator]: Inference done 1511/3226. 0.0484 s / img. ETA=0:01:26
# [08/21 16:00:39 d2.evaluation.evaluator]: Inference done 1612/3226. 0.0484 s / img. ETA=0:01:21
# [08/21 16:00:45 d2.evaluation.evaluator]: Inference done 1711/3226. 0.0484 s / img. ETA=0:01:16
# [08/21 16:00:50 d2.evaluation.evaluator]: Inference done 1811/3226. 0.0484 s / img. ETA=0:01:11
# [08/21 16:00:55 d2.evaluation.evaluator]: Inference done 1911/3226. 0.0484 s / img. ETA=0:01:06
# [08/21 16:01:00 d2.evaluation.evaluator]: Inference done 2011/3226. 0.0484 s / img. ETA=0:01:01
# [08/21 16:01:05 d2.evaluation.evaluator]: Inference done 2110/3226. 0.0484 s / img. ETA=0:00:56
# [08/21 16:01:10 d2.evaluation.evaluator]: Inference done 2211/3226. 0.0484 s / img. ETA=0:00:51
# [08/21 16:01:15 d2.evaluation.evaluator]: Inference done 2311/3226. 0.0484 s / img. ETA=0:00:45
# [08/21 16:01:20 d2.evaluation.evaluator]: Inference done 2410/3226. 0.0484 s / img. ETA=0:00:41
# [08/21 16:01:25 d2.evaluation.evaluator]: Inference done 2510/3226. 0.0484 s / img. ETA=0:00:36
# [08/21 16:01:30 d2.evaluation.evaluator]: Inference done 2608/3226. 0.0484 s / img. ETA=0:00:31
# [08/21 16:01:35 d2.evaluation.evaluator]: Inference done 2708/3226. 0.0484 s / img. ETA=0:00:26
# [08/21 16:01:40 d2.evaluation.evaluator]: Inference done 2809/3226. 0.0484 s / img. ETA=0:00:20
# [08/21 16:01:45 d2.evaluation.evaluator]: Inference done 2908/3226. 0.0484 s / img. ETA=0:00:15
# [08/21 16:01:50 d2.evaluation.evaluator]: Inference done 3006/3226. 0.0484 s / img. ETA=0:00:11
# [08/21 16:01:55 d2.evaluation.evaluator]: Inference done 3106/3226. 0.0484 s / img. ETA=0:00:06
# [08/21 16:02:00 d2.evaluation.evaluator]: Inference done 3203/3226. 0.0485 s / img. ETA=0:00:01
# [08/21 16:02:01 d2.evaluation.evaluator]: Total inference time: 0:02:42.334016 (0.050399 s / img per device, on 1 devices)
# [08/21 16:02:01 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:36 (0.048458 s / img per device, on 1 devices)
# [08/21 16:02:01 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:02:01 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_800k/coco_instances_results.json
# [08/21 16:02:01 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.95 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.649
# [08/21 16:02:03 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.766 | 49.522 | 28.706 | 17.278 | 52.528 | 60.480 |
# [08/21 16:02:03 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:02:03 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_800k/coco_instances_results.json
# [08/21 16:02:03 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.93 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.649
# [08/21 16:02:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.766 | 49.522 | 28.706 | 17.278 | 52.528 | 60.480 |
# BN_Mish_V2_250+F_2_50k
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V2_250+F_2_50k
# [08/21 16:02:08 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 16:02:08 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 16:02:08 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 16:02:08 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 16:02:08 d2.evaluation.evaluator]: Inference done 11/3226. 0.0527 s / img. ETA=0:02:53
# [08/21 16:02:13 d2.evaluation.evaluator]: Inference done 105/3226. 0.0516 s / img. ETA=0:02:46
# [08/21 16:02:19 d2.evaluation.evaluator]: Inference done 198/3226. 0.0519 s / img. ETA=0:02:42
# [08/21 16:02:24 d2.evaluation.evaluator]: Inference done 290/3226. 0.0523 s / img. ETA=0:02:38
# [08/21 16:02:29 d2.evaluation.evaluator]: Inference done 383/3226. 0.0523 s / img. ETA=0:02:33
# [08/21 16:02:34 d2.evaluation.evaluator]: Inference done 476/3226. 0.0522 s / img. ETA=0:02:28
# [08/21 16:02:39 d2.evaluation.evaluator]: Inference done 569/3226. 0.0523 s / img. ETA=0:02:23
# [08/21 16:02:44 d2.evaluation.evaluator]: Inference done 662/3226. 0.0523 s / img. ETA=0:02:18
# [08/21 16:02:49 d2.evaluation.evaluator]: Inference done 756/3226. 0.0522 s / img. ETA=0:02:13
# [08/21 16:02:54 d2.evaluation.evaluator]: Inference done 848/3226. 0.0523 s / img. ETA=0:02:08
# [08/21 16:02:59 d2.evaluation.evaluator]: Inference done 941/3226. 0.0523 s / img. ETA=0:02:03
# [08/21 16:03:04 d2.evaluation.evaluator]: Inference done 1034/3226. 0.0523 s / img. ETA=0:01:58
# [08/21 16:03:09 d2.evaluation.evaluator]: Inference done 1128/3226. 0.0523 s / img. ETA=0:01:53
# [08/21 16:03:14 d2.evaluation.evaluator]: Inference done 1221/3226. 0.0523 s / img. ETA=0:01:48
# [08/21 16:03:19 d2.evaluation.evaluator]: Inference done 1315/3226. 0.0522 s / img. ETA=0:01:43
# [08/21 16:03:24 d2.evaluation.evaluator]: Inference done 1408/3226. 0.0522 s / img. ETA=0:01:38
# [08/21 16:03:29 d2.evaluation.evaluator]: Inference done 1506/3226. 0.0521 s / img. ETA=0:01:32
# [08/21 16:03:34 d2.evaluation.evaluator]: Inference done 1601/3226. 0.0520 s / img. ETA=0:01:27
# [08/21 16:03:39 d2.evaluation.evaluator]: Inference done 1693/3226. 0.0521 s / img. ETA=0:01:22
# [08/21 16:03:44 d2.evaluation.evaluator]: Inference done 1785/3226. 0.0521 s / img. ETA=0:01:17
# [08/21 16:03:49 d2.evaluation.evaluator]: Inference done 1878/3226. 0.0521 s / img. ETA=0:01:12
# [08/21 16:03:54 d2.evaluation.evaluator]: Inference done 1972/3226. 0.0521 s / img. ETA=0:01:07
# [08/21 16:03:59 d2.evaluation.evaluator]: Inference done 2064/3226. 0.0521 s / img. ETA=0:01:02
# [08/21 16:04:04 d2.evaluation.evaluator]: Inference done 2156/3226. 0.0521 s / img. ETA=0:00:57
# [08/21 16:04:09 d2.evaluation.evaluator]: Inference done 2250/3226. 0.0521 s / img. ETA=0:00:52
# [08/21 16:04:14 d2.evaluation.evaluator]: Inference done 2343/3226. 0.0521 s / img. ETA=0:00:47
# [08/21 16:04:19 d2.evaluation.evaluator]: Inference done 2435/3226. 0.0521 s / img. ETA=0:00:42
# [08/21 16:04:24 d2.evaluation.evaluator]: Inference done 2528/3226. 0.0521 s / img. ETA=0:00:37
# [08/21 16:04:29 d2.evaluation.evaluator]: Inference done 2621/3226. 0.0521 s / img. ETA=0:00:32
# [08/21 16:04:34 d2.evaluation.evaluator]: Inference done 2713/3226. 0.0521 s / img. ETA=0:00:27
# [08/21 16:04:39 d2.evaluation.evaluator]: Inference done 2807/3226. 0.0521 s / img. ETA=0:00:22
# [08/21 16:04:44 d2.evaluation.evaluator]: Inference done 2900/3226. 0.0521 s / img. ETA=0:00:17
# [08/21 16:04:49 d2.evaluation.evaluator]: Inference done 2992/3226. 0.0522 s / img. ETA=0:00:12
# [08/21 16:04:54 d2.evaluation.evaluator]: Inference done 3085/3226. 0.0522 s / img. ETA=0:00:07
# [08/21 16:04:59 d2.evaluation.evaluator]: Inference done 3177/3226. 0.0522 s / img. ETA=0:00:02
# [08/21 16:05:02 d2.evaluation.evaluator]: Total inference time: 0:02:53.822593 (0.053965 s / img per device, on 1 devices)
# [08/21 16:05:02 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:48 (0.052178 s / img per device, on 1 devices)
# [08/21 16:05:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:05:02 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [08/21 16:05:02 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.99 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.12 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.680
# [08/21 16:05:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 30.203 | 54.446 | 31.129 | 19.484 | 55.289 | 63.486 |
# [08/21 16:05:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:05:04 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V2_250+F_2_50k/coco_instances_results.json
# [08/21 16:05:04 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.99 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.12 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.680
# [08/21 16:05:05 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 30.203 | 54.446 | 31.129 | 19.484 | 55.289 | 63.486 |
# BN_Mish_V3_80+_30k
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V3_80+_30k
# [08/21 16:05:09 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 16:05:09 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 16:05:09 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 16:05:09 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 16:05:10 d2.evaluation.evaluator]: Inference done 11/3226. 0.0523 s / img. ETA=0:02:52
# [08/21 16:05:15 d2.evaluation.evaluator]: Inference done 104/3226. 0.0521 s / img. ETA=0:02:48
# [08/21 16:05:20 d2.evaluation.evaluator]: Inference done 197/3226. 0.0521 s / img. ETA=0:02:42
# [08/21 16:05:25 d2.evaluation.evaluator]: Inference done 289/3226. 0.0523 s / img. ETA=0:02:38
# [08/21 16:05:30 d2.evaluation.evaluator]: Inference done 383/3226. 0.0522 s / img. ETA=0:02:33
# [08/21 16:05:35 d2.evaluation.evaluator]: Inference done 477/3226. 0.0521 s / img. ETA=0:02:27
# [08/21 16:05:40 d2.evaluation.evaluator]: Inference done 570/3226. 0.0521 s / img. ETA=0:02:23
# [08/21 16:05:45 d2.evaluation.evaluator]: Inference done 663/3226. 0.0521 s / img. ETA=0:02:18
# [08/21 16:05:50 d2.evaluation.evaluator]: Inference done 757/3226. 0.0521 s / img. ETA=0:02:12
# [08/21 16:05:55 d2.evaluation.evaluator]: Inference done 850/3226. 0.0521 s / img. ETA=0:02:07
# [08/21 16:06:00 d2.evaluation.evaluator]: Inference done 943/3226. 0.0521 s / img. ETA=0:02:02
# [08/21 16:06:05 d2.evaluation.evaluator]: Inference done 1036/3226. 0.0521 s / img. ETA=0:01:57
# [08/21 16:06:10 d2.evaluation.evaluator]: Inference done 1130/3226. 0.0521 s / img. ETA=0:01:52
# [08/21 16:06:15 d2.evaluation.evaluator]: Inference done 1223/3226. 0.0521 s / img. ETA=0:01:47
# [08/21 16:06:20 d2.evaluation.evaluator]: Inference done 1317/3226. 0.0521 s / img. ETA=0:01:42
# [08/21 16:06:25 d2.evaluation.evaluator]: Inference done 1410/3226. 0.0521 s / img. ETA=0:01:37
# [08/21 16:06:30 d2.evaluation.evaluator]: Inference done 1508/3226. 0.0519 s / img. ETA=0:01:32
# [08/21 16:06:35 d2.evaluation.evaluator]: Inference done 1603/3226. 0.0519 s / img. ETA=0:01:26
# [08/21 16:06:40 d2.evaluation.evaluator]: Inference done 1697/3226. 0.0519 s / img. ETA=0:01:21
# [08/21 16:06:45 d2.evaluation.evaluator]: Inference done 1791/3226. 0.0519 s / img. ETA=0:01:16
# [08/21 16:06:50 d2.evaluation.evaluator]: Inference done 1885/3226. 0.0518 s / img. ETA=0:01:11
# [08/21 16:06:55 d2.evaluation.evaluator]: Inference done 1979/3226. 0.0518 s / img. ETA=0:01:06
# [08/21 16:07:00 d2.evaluation.evaluator]: Inference done 2072/3226. 0.0519 s / img. ETA=0:01:01
# [08/21 16:07:05 d2.evaluation.evaluator]: Inference done 2165/3226. 0.0519 s / img. ETA=0:00:56
# [08/21 16:07:10 d2.evaluation.evaluator]: Inference done 2259/3226. 0.0519 s / img. ETA=0:00:51
# [08/21 16:07:15 d2.evaluation.evaluator]: Inference done 2352/3226. 0.0519 s / img. ETA=0:00:46
# [08/21 16:07:20 d2.evaluation.evaluator]: Inference done 2444/3226. 0.0519 s / img. ETA=0:00:41
# [08/21 16:07:25 d2.evaluation.evaluator]: Inference done 2538/3226. 0.0519 s / img. ETA=0:00:36
# [08/21 16:07:30 d2.evaluation.evaluator]: Inference done 2631/3226. 0.0519 s / img. ETA=0:00:31
# [08/21 16:07:35 d2.evaluation.evaluator]: Inference done 2724/3226. 0.0519 s / img. ETA=0:00:26
# [08/21 16:07:40 d2.evaluation.evaluator]: Inference done 2818/3226. 0.0519 s / img. ETA=0:00:21
# [08/21 16:07:45 d2.evaluation.evaluator]: Inference done 2911/3226. 0.0519 s / img. ETA=0:00:16
# [08/21 16:07:50 d2.evaluation.evaluator]: Inference done 3004/3226. 0.0519 s / img. ETA=0:00:11
# [08/21 16:07:55 d2.evaluation.evaluator]: Inference done 3099/3226. 0.0519 s / img. ETA=0:00:06
# [08/21 16:08:00 d2.evaluation.evaluator]: Inference done 3190/3226. 0.0520 s / img. ETA=0:00:01
# [08/21 16:08:02 d2.evaluation.evaluator]: Total inference time: 0:02:52.998378 (0.053710 s / img per device, on 1 devices)
# [08/21 16:08:02 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:47 (0.051955 s / img per device, on 1 devices)
# [08/21 16:08:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:08:02 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V3_80+_30k/coco_instances_results.json
# [08/21 16:08:03 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.92 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.668
# [08/21 16:08:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 29.157 | 51.745 | 30.291 | 18.596 | 53.954 | 62.017 |
# [08/21 16:08:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:08:04 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/BN_Mish_V3_80+_30k/coco_instances_results.json
# [08/21 16:08:05 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.89 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.10 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.668
# [08/21 16:08:06 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 29.157 | 51.745 | 30.291 | 18.596 | 53.954 | 62.017 |

# %%
for model in faster_rcnn_model:
  print(model)
  destination = os.path.join(OUTPUT_DIR_PATH, model)
  if not os.path.exists(destination):
    os.makedirs(destination)
  predictor, cfg = faster_predictor(model, cfg_DATASETS_TEST="face_val")
  print(destination)

  evaluator = COCOEvaluator(cfg.DATASETS.TEST[0], cfg, True, output_dir=destination)
  val_loader = build_detection_test_loader(cfg, cfg.DATASETS.TEST[0])
  inference_on_dataset(predictor.model, val_loader, evaluator)
  AP_VAL[model] = evaluator.evaluate()
# Out:
# faster_rcnn_R_50_FPN_3x
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/faster_rcnn_R_50_FPN_3x
# [08/21 16:08:12 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 16:08:12 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 16:08:12 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 16:08:12 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 16:08:13 d2.evaluation.evaluator]: Inference done 11/3226. 0.0679 s / img. ETA=0:03:42
# [08/21 16:08:18 d2.evaluation.evaluator]: Inference done 84/3226. 0.0671 s / img. ETA=0:03:36
# [08/21 16:08:23 d2.evaluation.evaluator]: Inference done 156/3226. 0.0674 s / img. ETA=0:03:32
# [08/21 16:08:28 d2.evaluation.evaluator]: Inference done 228/3226. 0.0677 s / img. ETA=0:03:28
# [08/21 16:08:33 d2.evaluation.evaluator]: Inference done 299/3226. 0.0680 s / img. ETA=0:03:24
# [08/21 16:08:38 d2.evaluation.evaluator]: Inference done 372/3226. 0.0679 s / img. ETA=0:03:18
# [08/21 16:08:43 d2.evaluation.evaluator]: Inference done 444/3226. 0.0679 s / img. ETA=0:03:13
# [08/21 16:08:48 d2.evaluation.evaluator]: Inference done 516/3226. 0.0679 s / img. ETA=0:03:08
# [08/21 16:08:53 d2.evaluation.evaluator]: Inference done 587/3226. 0.0680 s / img. ETA=0:03:04
# [08/21 16:08:58 d2.evaluation.evaluator]: Inference done 659/3226. 0.0680 s / img. ETA=0:02:59
# [08/21 16:09:03 d2.evaluation.evaluator]: Inference done 732/3226. 0.0679 s / img. ETA=0:02:53
# [08/21 16:09:08 d2.evaluation.evaluator]: Inference done 804/3226. 0.0679 s / img. ETA=0:02:48
# [08/21 16:09:13 d2.evaluation.evaluator]: Inference done 875/3226. 0.0680 s / img. ETA=0:02:44
# [08/21 16:09:18 d2.evaluation.evaluator]: Inference done 948/3226. 0.0680 s / img. ETA=0:02:38
# [08/21 16:09:23 d2.evaluation.evaluator]: Inference done 1021/3226. 0.0679 s / img. ETA=0:02:33
# [08/21 16:09:28 d2.evaluation.evaluator]: Inference done 1094/3226. 0.0678 s / img. ETA=0:02:28
# [08/21 16:09:33 d2.evaluation.evaluator]: Inference done 1166/3226. 0.0678 s / img. ETA=0:02:23
# [08/21 16:09:38 d2.evaluation.evaluator]: Inference done 1237/3226. 0.0679 s / img. ETA=0:02:18
# [08/21 16:09:44 d2.evaluation.evaluator]: Inference done 1310/3226. 0.0679 s / img. ETA=0:02:13
# [08/21 16:09:49 d2.evaluation.evaluator]: Inference done 1382/3226. 0.0679 s / img. ETA=0:02:08
# [08/21 16:09:54 d2.evaluation.evaluator]: Inference done 1455/3226. 0.0678 s / img. ETA=0:02:03
# [08/21 16:09:59 d2.evaluation.evaluator]: Inference done 1531/3226. 0.0677 s / img. ETA=0:01:57
# [08/21 16:10:04 d2.evaluation.evaluator]: Inference done 1605/3226. 0.0676 s / img. ETA=0:01:52
# [08/21 16:10:09 d2.evaluation.evaluator]: Inference done 1677/3226. 0.0676 s / img. ETA=0:01:47
# [08/21 16:10:14 d2.evaluation.evaluator]: Inference done 1749/3226. 0.0676 s / img. ETA=0:01:42
# [08/21 16:10:19 d2.evaluation.evaluator]: Inference done 1821/3226. 0.0676 s / img. ETA=0:01:37
# [08/21 16:10:24 d2.evaluation.evaluator]: Inference done 1894/3226. 0.0676 s / img. ETA=0:01:32
# [08/21 16:10:29 d2.evaluation.evaluator]: Inference done 1967/3226. 0.0676 s / img. ETA=0:01:27
# [08/21 16:10:34 d2.evaluation.evaluator]: Inference done 2039/3226. 0.0676 s / img. ETA=0:01:22
# [08/21 16:10:39 d2.evaluation.evaluator]: Inference done 2110/3226. 0.0677 s / img. ETA=0:01:17
# [08/21 16:10:44 d2.evaluation.evaluator]: Inference done 2183/3226. 0.0677 s / img. ETA=0:01:12
# [08/21 16:10:49 d2.evaluation.evaluator]: Inference done 2256/3226. 0.0677 s / img. ETA=0:01:07
# [08/21 16:10:54 d2.evaluation.evaluator]: Inference done 2328/3226. 0.0677 s / img. ETA=0:01:02
# [08/21 16:10:59 d2.evaluation.evaluator]: Inference done 2400/3226. 0.0677 s / img. ETA=0:00:57
# [08/21 16:11:04 d2.evaluation.evaluator]: Inference done 2471/3226. 0.0677 s / img. ETA=0:00:52
# [08/21 16:11:09 d2.evaluation.evaluator]: Inference done 2544/3226. 0.0677 s / img. ETA=0:00:47
# [08/21 16:11:14 d2.evaluation.evaluator]: Inference done 2616/3226. 0.0677 s / img. ETA=0:00:42
# [08/21 16:11:19 d2.evaluation.evaluator]: Inference done 2688/3226. 0.0677 s / img. ETA=0:00:37
# [08/21 16:11:24 d2.evaluation.evaluator]: Inference done 2761/3226. 0.0677 s / img. ETA=0:00:32
# [08/21 16:11:29 d2.evaluation.evaluator]: Inference done 2834/3226. 0.0677 s / img. ETA=0:00:27
# [08/21 16:11:34 d2.evaluation.evaluator]: Inference done 2906/3226. 0.0677 s / img. ETA=0:00:22
# [08/21 16:11:39 d2.evaluation.evaluator]: Inference done 2979/3226. 0.0677 s / img. ETA=0:00:17
# [08/21 16:11:44 d2.evaluation.evaluator]: Inference done 3051/3226. 0.0677 s / img. ETA=0:00:12
# [08/21 16:11:50 d2.evaluation.evaluator]: Inference done 3124/3226. 0.0677 s / img. ETA=0:00:07
# [08/21 16:11:55 d2.evaluation.evaluator]: Inference done 3194/3226. 0.0678 s / img. ETA=0:00:02
# [08/21 16:11:57 d2.evaluation.evaluator]: Total inference time: 0:03:44.160070 (0.069593 s / img per device, on 1 devices)
# [08/21 16:11:57 d2.evaluation.evaluator]: Total inference pure compute time: 0:03:38 (0.067775 s / img per device, on 1 devices)
# [08/21 16:11:57 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:11:57 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/faster_rcnn_R_50_FPN_3x/coco_instances_results.json
# [08/21 16:11:57 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.93 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# [08/21 16:11:58 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.965 | 50.158 | 28.701 | 16.475 | 55.024 | 64.621 |
# [08/21 16:11:59 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:11:59 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/faster_rcnn_R_50_FPN_3x/coco_instances_results.json
# [08/21 16:11:59 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.92 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# [08/21 16:12:00 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.965 | 50.158 | 28.701 | 16.475 | 55.024 | 64.621 |
# scratch_faster_rcnn_R_50_FPN_gn
# ./drive/My Drive/WIDERFACE_OUTPUT_DIR/scratch_faster_rcnn_R_50_FPN_gn
# [08/21 16:12:05 d2.data.common]: Serializing 3226 elements to byte tensors and concatenating them all ...
# [08/21 16:12:05 d2.data.common]: Serialized dataset takes 3.16 MiB
# [08/21 16:12:05 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/21 16:12:05 d2.evaluation.evaluator]: Start inference on 3226 images
# [08/21 16:12:06 d2.evaluation.evaluator]: Inference done 11/3226. 0.0763 s / img. ETA=0:04:09
# [08/21 16:12:11 d2.evaluation.evaluator]: Inference done 77/3226. 0.0747 s / img. ETA=0:04:00
# [08/21 16:12:16 d2.evaluation.evaluator]: Inference done 143/3226. 0.0748 s / img. ETA=0:03:55
# [08/21 16:12:21 d2.evaluation.evaluator]: Inference done 208/3226. 0.0752 s / img. ETA=0:03:52
# [08/21 16:12:26 d2.evaluation.evaluator]: Inference done 272/3226. 0.0757 s / img. ETA=0:03:48
# [08/21 16:12:31 d2.evaluation.evaluator]: Inference done 337/3226. 0.0757 s / img. ETA=0:03:43
# [08/21 16:12:36 d2.evaluation.evaluator]: Inference done 402/3226. 0.0758 s / img. ETA=0:03:38
# [08/21 16:12:41 d2.evaluation.evaluator]: Inference done 468/3226. 0.0757 s / img. ETA=0:03:33
# [08/21 16:12:46 d2.evaluation.evaluator]: Inference done 533/3226. 0.0757 s / img. ETA=0:03:28
# [08/21 16:12:51 d2.evaluation.evaluator]: Inference done 597/3226. 0.0758 s / img. ETA=0:03:23
# [08/21 16:12:56 d2.evaluation.evaluator]: Inference done 662/3226. 0.0758 s / img. ETA=0:03:18
# [08/21 16:13:01 d2.evaluation.evaluator]: Inference done 729/3226. 0.0756 s / img. ETA=0:03:13
# [08/21 16:13:06 d2.evaluation.evaluator]: Inference done 794/3226. 0.0756 s / img. ETA=0:03:08
# [08/21 16:13:11 d2.evaluation.evaluator]: Inference done 858/3226. 0.0757 s / img. ETA=0:03:03
# [08/21 16:13:17 d2.evaluation.evaluator]: Inference done 922/3226. 0.0758 s / img. ETA=0:02:58
# [08/21 16:13:22 d2.evaluation.evaluator]: Inference done 988/3226. 0.0757 s / img. ETA=0:02:53
# [08/21 16:13:27 d2.evaluation.evaluator]: Inference done 1053/3226. 0.0757 s / img. ETA=0:02:48
# [08/21 16:13:32 d2.evaluation.evaluator]: Inference done 1119/3226. 0.0756 s / img. ETA=0:02:43
# [08/21 16:13:37 d2.evaluation.evaluator]: Inference done 1184/3226. 0.0757 s / img. ETA=0:02:38
# [08/21 16:13:42 d2.evaluation.evaluator]: Inference done 1249/3226. 0.0757 s / img. ETA=0:02:33
# [08/21 16:13:47 d2.evaluation.evaluator]: Inference done 1315/3226. 0.0756 s / img. ETA=0:02:27
# [08/21 16:13:52 d2.evaluation.evaluator]: Inference done 1380/3226. 0.0756 s / img. ETA=0:02:22
# [08/21 16:13:57 d2.evaluation.evaluator]: Inference done 1446/3226. 0.0756 s / img. ETA=0:02:17
# [08/21 16:14:02 d2.evaluation.evaluator]: Inference done 1515/3226. 0.0754 s / img. ETA=0:02:12
# [08/21 16:14:07 d2.evaluation.evaluator]: Inference done 1581/3226. 0.0753 s / img. ETA=0:02:06
# [08/21 16:14:12 d2.evaluation.evaluator]: Inference done 1646/3226. 0.0753 s / img. ETA=0:02:01
# [08/21 16:14:17 d2.evaluation.evaluator]: Inference done 1711/3226. 0.0753 s / img. ETA=0:01:56
# [08/21 16:14:22 d2.evaluation.evaluator]: Inference done 1776/3226. 0.0753 s / img. ETA=0:01:51
# [08/21 16:14:27 d2.evaluation.evaluator]: Inference done 1841/3226. 0.0754 s / img. ETA=0:01:46
# [08/21 16:14:32 d2.evaluation.evaluator]: Inference done 1906/3226. 0.0754 s / img. ETA=0:01:41
# [08/21 16:14:37 d2.evaluation.evaluator]: Inference done 1972/3226. 0.0753 s / img. ETA=0:01:36
# [08/21 16:14:42 d2.evaluation.evaluator]: Inference done 2037/3226. 0.0754 s / img. ETA=0:01:31
# [08/21 16:14:47 d2.evaluation.evaluator]: Inference done 2100/3226. 0.0754 s / img. ETA=0:01:26
# [08/21 16:14:52 d2.evaluation.evaluator]: Inference done 2165/3226. 0.0754 s / img. ETA=0:01:21
# [08/21 16:14:57 d2.evaluation.evaluator]: Inference done 2231/3226. 0.0754 s / img. ETA=0:01:16
# [08/21 16:15:02 d2.evaluation.evaluator]: Inference done 2297/3226. 0.0754 s / img. ETA=0:01:11
# [08/21 16:15:07 d2.evaluation.evaluator]: Inference done 2361/3226. 0.0754 s / img. ETA=0:01:06
# [08/21 16:15:12 d2.evaluation.evaluator]: Inference done 2425/3226. 0.0755 s / img. ETA=0:01:01
# [08/21 16:15:17 d2.evaluation.evaluator]: Inference done 2490/3226. 0.0755 s / img. ETA=0:00:56
# [08/21 16:15:22 d2.evaluation.evaluator]: Inference done 2556/3226. 0.0755 s / img. ETA=0:00:51
# [08/21 16:15:28 d2.evaluation.evaluator]: Inference done 2621/3226. 0.0755 s / img. ETA=0:00:46
# [08/21 16:15:33 d2.evaluation.evaluator]: Inference done 2686/3226. 0.0755 s / img. ETA=0:00:41
# [08/21 16:15:38 d2.evaluation.evaluator]: Inference done 2750/3226. 0.0755 s / img. ETA=0:00:36
# [08/21 16:15:43 d2.evaluation.evaluator]: Inference done 2816/3226. 0.0755 s / img. ETA=0:00:31
# [08/21 16:15:48 d2.evaluation.evaluator]: Inference done 2881/3226. 0.0755 s / img. ETA=0:00:26
# [08/21 16:15:53 d2.evaluation.evaluator]: Inference done 2946/3226. 0.0755 s / img. ETA=0:00:21
# [08/21 16:15:58 d2.evaluation.evaluator]: Inference done 3010/3226. 0.0755 s / img. ETA=0:00:16
# [08/21 16:16:03 d2.evaluation.evaluator]: Inference done 3075/3226. 0.0755 s / img. ETA=0:00:11
# [08/21 16:16:08 d2.evaluation.evaluator]: Inference done 3140/3226. 0.0755 s / img. ETA=0:00:06
# [08/21 16:16:13 d2.evaluation.evaluator]: Inference done 3203/3226. 0.0755 s / img. ETA=0:00:01
# [08/21 16:16:14 d2.evaluation.evaluator]: Total inference time: 0:04:09.086436 (0.077332 s / img per device, on 1 devices)
# [08/21 16:16:14 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:03 (0.075518 s / img per device, on 1 devices)
# [08/21 16:16:15 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:16:15 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/scratch_faster_rcnn_R_50_FPN_gn/coco_instances_results.json
# [08/21 16:16:15 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.24 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.11 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.314
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [08/21 16:16:16 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.400 | 57.145 | 31.569 | 21.638 | 53.464 | 61.378 |
# [08/21 16:16:17 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/21 16:16:17 d2.evaluation.coco_evaluation]: Saving results to ./drive/My Drive/WIDERFACE_OUTPUT_DIR/scratch_faster_rcnn_R_50_FPN_gn/coco_instances_results.json
# [08/21 16:16:17 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.12 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.314
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [08/21 16:16:18 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.400 | 57.145 | 31.569 | 21.638 | 53.464 | 61.378 |

# %%
output_file_name = "AP_VAL_COCOEvaluator"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)
dict_to_file(AP_VAL, output_file)

# %% [markdown]
# Porównanie wyników

# %%
AP_WIDER = {}
for item in AP_VAL.keys():
  AP_WIDER[item] = AP_VAL[item]['bbox']

df_AP_WIDER = pd.DataFrame.from_dict(AP_WIDER, orient='index').sort_values(by=['AP'], ascending=False)

# %%
df_AP_WIDER
# Out:
#                                         AP       AP50  ...        APm        APl
# scratch_faster_rcnn_R_50_FPN_gn  31.400140  57.145298  ...  53.463648  61.377793
# BN_Mish_V2_250+F_2_50k           30.202843  54.445577  ...  55.288928  63.485808
# BN_Mish_V3_80+_30k               29.157098  51.745406  ...  53.954390  62.016662
# faster_rcnn_R_50_FPN_3x          27.965053  50.158303  ...  55.023554  64.620984
# BN_800k                          27.766038  49.522419  ...  52.528106  60.480344
# 800k                             23.100826  42.814369  ...  45.492286  40.228140
#
# [6 rows x 6 columns]

# %% [markdown]
# Zapis wyników na Google drive

# %%
df_AP_WIDER_results = df_AP_WIDER.to_json(orient="table")

output_file_name = "df_AP_WIDERB.json"
output_file = os.path.join(OUTPUT_DIR_PATH, output_file_name)

with open(output_file, 'w') as f:
  json.dump(df_AP_WIDER_results, f, indent=4)
